# %% [markdown]
# # Continuous Control
#
# ---
#
# Congratulations for completing the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program!  In this notebook, you will learn how to control an agent in a more challenging environment, where the goal is to train a creature with four arms to walk forward.  **Note that this exercise is optional!**
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Crawler.app"`
# - **Windows** (x86): `"path/to/Crawler_Windows_x86/Crawler.exe"`
# - **Windows** (x86_64): `"path/to/Crawler_Windows_x86_64/Crawler.exe"`
# - **Linux** (x86): `"path/to/Crawler_Linux/Crawler.x86"`
# - **Linux** (x86_64): `"path/to/Crawler_Linux/Crawler.x86_64"`
# - **Linux** (x86, headless): `"path/to/Crawler_Linux_NoVis/Crawler.x86"`
# - **Linux** (x86_64, headless): `"path/to/Crawler_Linux_NoVis/Crawler.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Crawler.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Crawler.app")
# ```

# %%
env = UnityEnvironment(file_name='C:/Users/Turan/Desktop/drl project/deep-reinforcement-learning/p2_continuous-control/Crawler_Windows_x86_64/Crawler.exe')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: CrawlerBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 129
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 20
#         Vector Action descriptions: , , , , , , , , , , , , , , , , , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 12
# Size of each action: 20
# There are 12 agents. Each observes a state with length: 129
# The state for the first agent looks like: [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  2.25000000e+00
#   1.00000000e+00  0.00000000e+00  1.78813934e-07  0.00000000e+00
#   1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093168e-01 -1.42857209e-01 -6.06078804e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339906e+00 -1.42857209e-01
#  -1.33341408e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093347e-01 -1.42857209e-01 -6.06078625e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339953e+00 -1.42857209e-01
#  -1.33341372e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093168e-01 -1.42857209e-01  6.06078804e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339906e+00 -1.42857209e-01
#   1.33341408e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093347e-01 -1.42857209e-01  6.06078625e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339953e+00 -1.42857209e-01
#   1.33341372e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
#env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
#states = env_info.vector_observations                  # get the current state (for each agent)
#scores = np.zeros(num_agents)                          # initialize the score (for each agent)
#while True:
#    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
#    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
#    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#    next_states = env_info.vector_observations         # get next state (for each agent)
#    rewards = env_info.rewards                         # get reward (for each agent)
#    dones = env_info.local_done                        # see if episode finished
#    scores += env_info.rewards                         # update the score (for each agent)
#    states = next_states                               # roll over states to next time step
#    if np.any(dones):                                  # exit loop if episode finished
#        break
#print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
#env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
from  collections  import deque
from itertools import count
import torch
import time
#from ddpg_agent import Agent
from ppo_agent_combined import Agent
import matplotlib.pyplot as plt
# %matplotlib inline
env_info = env.reset(train_mode=True)[brain_name]
agent = Agent(state_size=state_size, action_size=action_size, random_seed=8, n_agent=num_agents, \
              fc1_units=128, fc2_units=128)

print("Smoothness used:", agent.USE_SMOOTHNESS)
print("Symmetry used:", agent.USE_SYMMETRY)
print("Magnitude used:", agent.USE_MAGNITUDE)
# Out:
# Smoothness used: False
# Symmetry used: True
# Magnitude used: False

# %%
def ppo(env, agent, n_episodes=500, print_every=10, n_agent = 12):
    """
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        print_every (int): number of episodes to print result
        n_agent (int): number of identical agents in environment
    """
    scores_deque = deque(maxlen=100)
    scores_global = []    
    scores = []
    max_t = 2000
        
    time_start = time.time()
    
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        states = env_info.vector_observations
        agent_scores = np.zeros(n_agent)
        t_max = 0
        for t in range(max_t):
            actions, log_probs, _, values = agent.act(states)
            # get needed information from environment
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations
            rewards = env_info.rewards
            dones = np.array([1 if t else 0 for t in env_info.local_done])
            agent.save_step([states, values.detach(), actions, log_probs.detach(), rewards, 1 - dones])
            states = next_states
            agent_scores += rewards
            t_max = t
            if all(dones) or t == max_t-1:
                agent.step(next_states)
                break
                
        score = np.mean(agent_scores)
        scores_deque.append(score)
        scores.append(score)

        print('Episode: {}, Score: {:.2f}, Max: {:.2f}, Min: {:.2f}, T-max: {}   '\
              .format(i_episode, score, np.max(scores), np.min(scores), t_max))
        
        if i_episode % print_every == 0:
            torch.save(agent.actor_critic.actor.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.actor_critic.critic.state_dict(), 'checkpoint_critic.pth')
            s = (int)(time.time() - time_start) 
            print('*** Episode {} \t Average Score (over agents): {:.2f} \t Average Score on 100 Episode: {:.2f}, Time: {:02}:{:02}:{:02}***'\
                  .format(i_episode, score, np.mean(scores_deque), s//3600, s%3600//60, s%60))
            
        if len(scores_deque) == 100 and np.mean(scores_deque) >= 800: # 650: # 500:   
            break


    print('\n End of PPO!')
    return scores

scores = ppo(env=env, agent=agent)
# Out:
# c:\Users\Turan\miniconda3\envs\drlnd\lib\site-packages\torch\nn\functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Episode: 1, Score: 47.94, Max: 47.94, Min: 47.94, T-max: 1000
# Episode: 2, Score: 49.67, Max: 49.67, Min: 47.94, T-max: 1000
# Episode: 3, Score: 43.91, Max: 49.67, Min: 43.91, T-max: 1000
# Episode: 4, Score: 48.80, Max: 49.67, Min: 43.91, T-max: 1000
# Episode: 5, Score: 38.50, Max: 49.67, Min: 38.50, T-max: 1000
# Episode: 6, Score: 44.95, Max: 49.67, Min: 38.50, T-max: 1000
# Episode: 7, Score: 51.27, Max: 51.27, Min: 38.50, T-max: 1000
# Episode: 8, Score: 48.95, Max: 51.27, Min: 38.50, T-max: 1000
# Episode: 9, Score: 49.96, Max: 51.27, Min: 38.50, T-max: 1000
# Episode: 10, Score: 48.34, Max: 51.27, Min: 38.50, T-max: 1000
# *** Episode 10 	 Average Score (over agents): 48.34 	 Average Score on 100 Episode: 47.23, Time: 00:01:20***
# Episode: 11, Score: 46.17, Max: 51.27, Min: 38.50, T-max: 1000
# Episode: 12, Score: 47.63, Max: 51.27, Min: 38.50, T-max: 1000
# Episode: 13, Score: 53.56, Max: 53.56, Min: 38.50, T-max: 1000
# Episode: 14, Score: 51.37, Max: 53.56, Min: 38.50, T-max: 1000
# Episode: 15, Score: 51.52, Max: 53.56, Min: 38.50, T-max: 1000
# Episode: 16, Score: 52.30, Max: 53.56, Min: 38.50, T-max: 1000
# Episode: 17, Score: 55.68, Max: 55.68, Min: 38.50, T-max: 1000
# Episode: 18, Score: 56.68, Max: 56.68, Min: 38.50, T-max: 1000
# Episode: 19, Score: 56.53, Max: 56.68, Min: 38.50, T-max: 1000
# Episode: 20, Score: 56.29, Max: 56.68, Min: 38.50, T-max: 1000
# *** Episode 20 	 Average Score (over agents): 56.29 	 Average Score on 100 Episode: 50.00, Time: 00:02:56***
# Episode: 21, Score: 57.76, Max: 57.76, Min: 38.50, T-max: 1000
# Episode: 22, Score: 54.40, Max: 57.76, Min: 38.50, T-max: 1000
# Episode: 23, Score: 55.64, Max: 57.76, Min: 38.50, T-max: 1000
# Episode: 24, Score: 53.61, Max: 57.76, Min: 38.50, T-max: 1000
# Episode: 25, Score: 56.51, Max: 57.76, Min: 38.50, T-max: 1000
# Episode: 26, Score: 59.77, Max: 59.77, Min: 38.50, T-max: 1000
# Episode: 27, Score: 57.53, Max: 59.77, Min: 38.50, T-max: 1000
# Episode: 28, Score: 64.22, Max: 64.22, Min: 38.50, T-max: 1000
# Episode: 29, Score: 63.48, Max: 64.22, Min: 38.50, T-max: 1000
# Episode: 30, Score: 63.05, Max: 64.22, Min: 38.50, T-max: 1000
# *** Episode 30 	 Average Score (over agents): 63.05 	 Average Score on 100 Episode: 52.87, Time: 00:04:34***
# Episode: 31, Score: 64.70, Max: 64.70, Min: 38.50, T-max: 1000
# Episode: 32, Score: 58.09, Max: 64.70, Min: 38.50, T-max: 1000
# Episode: 33, Score: 63.07, Max: 64.70, Min: 38.50, T-max: 1000
# Episode: 34, Score: 63.17, Max: 64.70, Min: 38.50, T-max: 1000
# Episode: 35, Score: 65.37, Max: 65.37, Min: 38.50, T-max: 1000
# Episode: 36, Score: 66.93, Max: 66.93, Min: 38.50, T-max: 1000
# Episode: 37, Score: 66.54, Max: 66.93, Min: 38.50, T-max: 1000
# Episode: 38, Score: 67.82, Max: 67.82, Min: 38.50, T-max: 1000
# Episode: 39, Score: 69.17, Max: 69.17, Min: 38.50, T-max: 1000
# Episode: 40, Score: 68.67, Max: 69.17, Min: 38.50, T-max: 1000
# *** Episode 40 	 Average Score (over agents): 68.67 	 Average Score on 100 Episode: 55.99, Time: 00:06:15***
# Episode: 41, Score: 67.59, Max: 69.17, Min: 38.50, T-max: 1000
# Episode: 42, Score: 66.18, Max: 69.17, Min: 38.50, T-max: 1000
# Episode: 43, Score: 69.22, Max: 69.22, Min: 38.50, T-max: 1000
# Episode: 44, Score: 67.57, Max: 69.22, Min: 38.50, T-max: 1000
# Episode: 45, Score: 69.90, Max: 69.90, Min: 38.50, T-max: 1000
# Episode: 46, Score: 71.87, Max: 71.87, Min: 38.50, T-max: 1000
# Episode: 47, Score: 74.95, Max: 74.95, Min: 38.50, T-max: 1000
# Episode: 48, Score: 68.65, Max: 74.95, Min: 38.50, T-max: 1000
# Episode: 49, Score: 73.94, Max: 74.95, Min: 38.50, T-max: 1000
# Episode: 50, Score: 68.80, Max: 74.95, Min: 38.50, T-max: 1000
# *** Episode 50 	 Average Score (over agents): 68.80 	 Average Score on 100 Episode: 58.76, Time: 00:07:56***
# Episode: 51, Score: 73.21, Max: 74.95, Min: 38.50, T-max: 1000
# Episode: 52, Score: 73.85, Max: 74.95, Min: 38.50, T-max: 1000
# Episode: 53, Score: 72.19, Max: 74.95, Min: 38.50, T-max: 1000
# Episode: 54, Score: 67.36, Max: 74.95, Min: 38.50, T-max: 1000
# Episode: 55, Score: 72.33, Max: 74.95, Min: 38.50, T-max: 1000
# Episode: 56, Score: 76.00, Max: 76.00, Min: 38.50, T-max: 1000
# Episode: 57, Score: 75.66, Max: 76.00, Min: 38.50, T-max: 1000
# Episode: 58, Score: 79.87, Max: 79.87, Min: 38.50, T-max: 1000
# Episode: 59, Score: 77.23, Max: 79.87, Min: 38.50, T-max: 1000
# Episode: 60, Score: 75.96, Max: 79.87, Min: 38.50, T-max: 1000
# *** Episode 60 	 Average Score (over agents): 75.96 	 Average Score on 100 Episode: 61.36, Time: 00:09:41***
# Episode: 61, Score: 86.02, Max: 86.02, Min: 38.50, T-max: 1000
# Episode: 62, Score: 83.98, Max: 86.02, Min: 38.50, T-max: 1000
# Episode: 63, Score: 82.86, Max: 86.02, Min: 38.50, T-max: 1000
# Episode: 64, Score: 80.86, Max: 86.02, Min: 38.50, T-max: 1000
# Episode: 65, Score: 78.09, Max: 86.02, Min: 38.50, T-max: 1000
# Episode: 66, Score: 87.04, Max: 87.04, Min: 38.50, T-max: 1000
# Episode: 67, Score: 84.85, Max: 87.04, Min: 38.50, T-max: 1000
# Episode: 68, Score: 85.65, Max: 87.04, Min: 38.50, T-max: 1000
# Episode: 69, Score: 80.98, Max: 87.04, Min: 38.50, T-max: 1000
# Episode: 70, Score: 86.73, Max: 87.04, Min: 38.50, T-max: 1000
# *** Episode 70 	 Average Score (over agents): 86.73 	 Average Score on 100 Episode: 64.56, Time: 00:11:22***
# Episode: 71, Score: 90.00, Max: 90.00, Min: 38.50, T-max: 1000
# Episode: 72, Score: 91.05, Max: 91.05, Min: 38.50, T-max: 1000
# Episode: 73, Score: 85.52, Max: 91.05, Min: 38.50, T-max: 1000
# Episode: 74, Score: 88.39, Max: 91.05, Min: 38.50, T-max: 1000
# Episode: 75, Score: 90.01, Max: 91.05, Min: 38.50, T-max: 1000
# Episode: 76, Score: 81.49, Max: 91.05, Min: 38.50, T-max: 1000
# Episode: 77, Score: 96.93, Max: 96.93, Min: 38.50, T-max: 1000
# Episode: 78, Score: 92.85, Max: 96.93, Min: 38.50, T-max: 1000
# Episode: 79, Score: 96.14, Max: 96.93, Min: 38.50, T-max: 1000
# Episode: 80, Score: 98.27, Max: 98.27, Min: 38.50, T-max: 1000
# *** Episode 80 	 Average Score (over agents): 98.27 	 Average Score on 100 Episode: 67.87, Time: 00:13:04***
# Episode: 81, Score: 93.33, Max: 98.27, Min: 38.50, T-max: 1000
# Episode: 82, Score: 101.29, Max: 101.29, Min: 38.50, T-max: 1000
# Episode: 83, Score: 96.75, Max: 101.29, Min: 38.50, T-max: 1000
# Episode: 84, Score: 94.95, Max: 101.29, Min: 38.50, T-max: 1000
# Episode: 85, Score: 95.55, Max: 101.29, Min: 38.50, T-max: 1000
# Episode: 86, Score: 90.27, Max: 101.29, Min: 38.50, T-max: 1000
# Episode: 87, Score: 93.13, Max: 101.29, Min: 38.50, T-max: 1000
# Episode: 88, Score: 91.66, Max: 101.29, Min: 38.50, T-max: 1000
# Episode: 89, Score: 95.06, Max: 101.29, Min: 38.50, T-max: 1000
# Episode: 90, Score: 97.76, Max: 101.29, Min: 38.50, T-max: 1000
# *** Episode 90 	 Average Score (over agents): 97.76 	 Average Score on 100 Episode: 70.88, Time: 00:14:46***
# Episode: 91, Score: 102.57, Max: 102.57, Min: 38.50, T-max: 1000
# Episode: 92, Score: 100.56, Max: 102.57, Min: 38.50, T-max: 1000
# Episode: 93, Score: 105.76, Max: 105.76, Min: 38.50, T-max: 1000
# Episode: 94, Score: 104.58, Max: 105.76, Min: 38.50, T-max: 1000
# Episode: 95, Score: 96.75, Max: 105.76, Min: 38.50, T-max: 1000
# Episode: 96, Score: 93.86, Max: 105.76, Min: 38.50, T-max: 1000
# Episode: 97, Score: 110.20, Max: 110.20, Min: 38.50, T-max: 1000
# Episode: 98, Score: 100.90, Max: 110.20, Min: 38.50, T-max: 1000
# Episode: 99, Score: 100.24, Max: 110.20, Min: 38.50, T-max: 1000
# Episode: 100, Score: 109.75, Max: 110.20, Min: 38.50, T-max: 1000
# *** Episode 100 	 Average Score (over agents): 109.75 	 Average Score on 100 Episode: 74.04, Time: 00:16:28***
# Episode: 101, Score: 111.33, Max: 111.33, Min: 38.50, T-max: 1000
# Episode: 102, Score: 105.18, Max: 111.33, Min: 38.50, T-max: 1000
# Episode: 103, Score: 98.84, Max: 111.33, Min: 38.50, T-max: 1000
# Episode: 104, Score: 122.75, Max: 122.75, Min: 38.50, T-max: 1000
# Episode: 105, Score: 111.03, Max: 122.75, Min: 38.50, T-max: 1000
# Episode: 106, Score: 118.83, Max: 122.75, Min: 38.50, T-max: 1000
# Episode: 107, Score: 102.96, Max: 122.75, Min: 38.50, T-max: 1000
# Episode: 108, Score: 113.86, Max: 122.75, Min: 38.50, T-max: 1000
# Episode: 109, Score: 102.15, Max: 122.75, Min: 38.50, T-max: 1000
# Episode: 110, Score: 117.28, Max: 122.75, Min: 38.50, T-max: 1000
# *** Episode 110 	 Average Score (over agents): 117.28 	 Average Score on 100 Episode: 80.36, Time: 00:18:09***
# Episode: 111, Score: 118.27, Max: 122.75, Min: 38.50, T-max: 1000
# Episode: 112, Score: 121.55, Max: 122.75, Min: 38.50, T-max: 1000
# Episode: 113, Score: 117.72, Max: 122.75, Min: 38.50, T-max: 1000
# Episode: 114, Score: 116.07, Max: 122.75, Min: 38.50, T-max: 1000
# Episode: 115, Score: 121.29, Max: 122.75, Min: 38.50, T-max: 1000
# Episode: 150, Score: 164.72, Max: 167.75, Min: 38.50, T-max: 1000
# *** Episode 150 	 Average Score (over agents): 164.72 	 Average Score on 100 Episode: 110.76, Time: 00:24:56***
# Episode: 151, Score: 165.73, Max: 167.75, Min: 38.50, T-max: 1000
# Episode: 152, Score: 154.69, Max: 167.75, Min: 38.50, T-max: 1000
# Episode: 153, Score: 173.29, Max: 173.29, Min: 38.50, T-max: 1000
# Episode: 154, Score: 172.86, Max: 173.29, Min: 38.50, T-max: 1000
# Episode: 155, Score: 164.05, Max: 173.29, Min: 38.50, T-max: 1000
# Episode: 156, Score: 168.38, Max: 173.29, Min: 38.50, T-max: 1000
# Episode: 157, Score: 182.75, Max: 182.75, Min: 38.50, T-max: 1000
# Episode: 158, Score: 175.82, Max: 182.75, Min: 38.50, T-max: 1000
# Episode: 159, Score: 182.47, Max: 182.75, Min: 38.50, T-max: 1000
# Episode: 160, Score: 182.19, Max: 182.75, Min: 38.50, T-max: 1000
# *** Episode 160 	 Average Score (over agents): 182.19 	 Average Score on 100 Episode: 120.55, Time: 00:26:37***
# Episode: 161, Score: 177.24, Max: 182.75, Min: 38.50, T-max: 1000
# Episode: 162, Score: 155.33, Max: 182.75, Min: 38.50, T-max: 1000
# Episode: 163, Score: 177.28, Max: 182.75, Min: 38.50, T-max: 1000
# Episode: 164, Score: 159.27, Max: 182.75, Min: 38.50, T-max: 1000
# Episode: 165, Score: 176.38, Max: 182.75, Min: 38.50, T-max: 1000
# Episode: 166, Score: 186.02, Max: 186.02, Min: 38.50, T-max: 1000
# Episode: 167, Score: 179.61, Max: 186.02, Min: 38.50, T-max: 1000
# Episode: 168, Score: 165.53, Max: 186.02, Min: 38.50, T-max: 1000
# Episode: 169, Score: 196.58, Max: 196.58, Min: 38.50, T-max: 1000
# Episode: 170, Score: 197.83, Max: 197.83, Min: 38.50, T-max: 1000
# *** Episode 170 	 Average Score (over agents): 197.83 	 Average Score on 100 Episode: 129.89, Time: 00:28:20***
# Episode: 171, Score: 184.09, Max: 197.83, Min: 38.50, T-max: 1000
# Episode: 172, Score: 193.47, Max: 197.83, Min: 38.50, T-max: 1000
# Episode: 173, Score: 187.91, Max: 197.83, Min: 38.50, T-max: 1000
# Episode: 174, Score: 186.45, Max: 197.83, Min: 38.50, T-max: 1000
# Episode: 175, Score: 212.43, Max: 212.43, Min: 38.50, T-max: 1000
# Episode: 176, Score: 193.93, Max: 212.43, Min: 38.50, T-max: 1000
# Episode: 177, Score: 198.61, Max: 212.43, Min: 38.50, T-max: 1000
# Episode: 178, Score: 208.66, Max: 212.43, Min: 38.50, T-max: 1000
# Episode: 179, Score: 209.21, Max: 212.43, Min: 38.50, T-max: 1000
# Episode: 180, Score: 207.73, Max: 212.43, Min: 38.50, T-max: 1000
# *** Episode 180 	 Average Score (over agents): 207.73 	 Average Score on 100 Episode: 140.61, Time: 00:30:05***
# Episode: 181, Score: 213.73, Max: 213.73, Min: 38.50, T-max: 1000
# Episode: 182, Score: 206.78, Max: 213.73, Min: 38.50, T-max: 1000
# Episode: 217, Score: 307.41, Max: 307.41, Min: 38.50, T-max: 1000
# Episode: 218, Score: 271.97, Max: 307.41, Min: 38.50, T-max: 1000
# Episode: 219, Score: 277.04, Max: 307.41, Min: 38.50, T-max: 1000
# Episode: 220, Score: 287.44, Max: 307.41, Min: 38.50, T-max: 1000
# *** Episode 220 	 Average Score (over agents): 287.44 	 Average Score on 100 Episode: 196.18, Time: 00:35:49***
# Episode: 221, Score: 288.21, Max: 307.41, Min: 38.50, T-max: 1000
# Episode: 222, Score: 298.45, Max: 307.41, Min: 38.50, T-max: 1000
# Episode: 223, Score: 306.15, Max: 307.41, Min: 38.50, T-max: 1000
# Episode: 224, Score: 305.93, Max: 307.41, Min: 38.50, T-max: 1000
# Episode: 225, Score: 284.16, Max: 307.41, Min: 38.50, T-max: 1000
# Episode: 226, Score: 299.68, Max: 307.41, Min: 38.50, T-max: 1000
# Episode: 227, Score: 299.30, Max: 307.41, Min: 38.50, T-max: 1000
# Episode: 228, Score: 306.03, Max: 307.41, Min: 38.50, T-max: 1000
# Episode: 229, Score: 329.18, Max: 329.18, Min: 38.50, T-max: 1000
# Episode: 230, Score: 299.47, Max: 329.18, Min: 38.50, T-max: 1000
# *** Episode 230 	 Average Score (over agents): 299.47 	 Average Score on 100 Episode: 213.16, Time: 00:37:29***
# Episode: 231, Score: 330.62, Max: 330.62, Min: 38.50, T-max: 1000
# Episode: 232, Score: 313.11, Max: 330.62, Min: 38.50, T-max: 1000
# Episode: 233, Score: 323.43, Max: 330.62, Min: 38.50, T-max: 1000
# Episode: 234, Score: 330.24, Max: 330.62, Min: 38.50, T-max: 1000
# Episode: 235, Score: 345.76, Max: 345.76, Min: 38.50, T-max: 1000
# Episode: 236, Score: 334.29, Max: 345.76, Min: 38.50, T-max: 1000
# Episode: 237, Score: 323.52, Max: 345.76, Min: 38.50, T-max: 1000
# Episode: 238, Score: 327.50, Max: 345.76, Min: 38.50, T-max: 1000
# Episode: 239, Score: 339.90, Max: 345.76, Min: 38.50, T-max: 1000
# Episode: 240, Score: 328.67, Max: 345.76, Min: 38.50, T-max: 1000
# *** Episode 240 	 Average Score (over agents): 328.67 	 Average Score on 100 Episode: 231.85, Time: 00:39:11***
# Episode: 241, Score: 365.71, Max: 365.71, Min: 38.50, T-max: 1000
# Episode: 242, Score: 336.14, Max: 365.71, Min: 38.50, T-max: 1000
# Episode: 243, Score: 323.31, Max: 365.71, Min: 38.50, T-max: 1000
# Episode: 244, Score: 362.52, Max: 365.71, Min: 38.50, T-max: 1000
# Episode: 245, Score: 365.51, Max: 365.71, Min: 38.50, T-max: 1000
# Episode: 246, Score: 364.64, Max: 365.71, Min: 38.50, T-max: 1000
# Episode: 247, Score: 346.77, Max: 365.71, Min: 38.50, T-max: 1000
# Episode: 248, Score: 350.39, Max: 365.71, Min: 38.50, T-max: 1000
# Episode: 249, Score: 336.57, Max: 365.71, Min: 38.50, T-max: 1000
# Episode: 250, Score: 371.44, Max: 371.44, Min: 38.50, T-max: 1000
# *** Episode 250 	 Average Score (over agents): 371.44 	 Average Score on 100 Episode: 251.30, Time: 00:40:52***
# Episode: 251, Score: 361.07, Max: 371.44, Min: 38.50, T-max: 1000
# Episode: 252, Score: 373.97, Max: 373.97, Min: 38.50, T-max: 1000
# Episode: 253, Score: 344.05, Max: 373.97, Min: 38.50, T-max: 1000
# Episode: 254, Score: 375.01, Max: 375.01, Min: 38.50, T-max: 1000
# Episode: 255, Score: 374.11, Max: 375.01, Min: 38.50, T-max: 1000
# Episode: 256, Score: 343.49, Max: 375.01, Min: 38.50, T-max: 1000
# Episode: 257, Score: 384.48, Max: 384.48, Min: 38.50, T-max: 1000
# Episode: 258, Score: 382.13, Max: 384.48, Min: 38.50, T-max: 1000
# Episode: 259, Score: 391.15, Max: 391.15, Min: 38.50, T-max: 1000
# Episode: 260, Score: 397.43, Max: 397.43, Min: 38.50, T-max: 1000
# *** Episode 260 	 Average Score (over agents): 397.43 	 Average Score on 100 Episode: 271.34, Time: 00:42:37***
# Episode: 261, Score: 388.62, Max: 397.43, Min: 38.50, T-max: 1000
# Episode: 262, Score: 336.41, Max: 397.43, Min: 38.50, T-max: 1000
# Episode: 263, Score: 347.47, Max: 397.43, Min: 38.50, T-max: 1000
# Episode: 264, Score: 337.31, Max: 397.43, Min: 38.50, T-max: 1000
# Episode: 265, Score: 395.57, Max: 397.43, Min: 38.50, T-max: 1000
# Episode: 266, Score: 385.75, Max: 397.43, Min: 38.50, T-max: 1000
# Episode: 267, Score: 397.13, Max: 397.43, Min: 38.50, T-max: 1000
# Episode: 268, Score: 398.68, Max: 398.68, Min: 38.50, T-max: 1000
# Episode: 269, Score: 397.83, Max: 398.68, Min: 38.50, T-max: 1000
# Episode: 270, Score: 406.15, Max: 406.15, Min: 38.50, T-max: 1000
# *** Episode 270 	 Average Score (over agents): 406.15 	 Average Score on 100 Episode: 291.54, Time: 00:44:12***
# Episode: 271, Score: 400.96, Max: 406.15, Min: 38.50, T-max: 1000
# Episode: 272, Score: 416.26, Max: 416.26, Min: 38.50, T-max: 1000
# Episode: 273, Score: 421.10, Max: 421.10, Min: 38.50, T-max: 1000
# Episode: 274, Score: 416.91, Max: 421.10, Min: 38.50, T-max: 1000
# Episode: 275, Score: 422.05, Max: 422.05, Min: 38.50, T-max: 1000
# Episode: 276, Score: 418.39, Max: 422.05, Min: 38.50, T-max: 1000
# Episode: 277, Score: 833.72, Max: 833.72, Min: 38.50, T-max: 1999
# Episode: 278, Score: 398.47, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 279, Score: 426.26, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 280, Score: 399.48, Max: 833.72, Min: 38.50, T-max: 1000
# *** Episode 280 	 Average Score (over agents): 399.48 	 Average Score on 100 Episode: 317.25, Time: 00:46:01***
# Episode: 281, Score: 424.77, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 282, Score: 440.21, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 283, Score: 426.66, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 284, Score: 437.77, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 285, Score: 413.90, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 286, Score: 408.27, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 287, Score: 414.55, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 288, Score: 446.67, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 289, Score: 436.29, Max: 833.72, Min: 38.50, T-max: 1000
# Episode:
Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 364, Score: 607.17, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 365, Score: 589.37, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 366, Score: 600.83, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 367, Score: 570.04, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 368, Score: 602.87, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 369, Score: 600.05, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 370, Score: 605.98, Max: 833.72, Min: 38.50, T-max: 1000
# *** Episode 370 	 Average Score (over agents): 605.98 	 Average Score on 100 Episode: 515.94, Time: 01:00:38***
# Episode: 371, Score: 601.13, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 372, Score: 606.10, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 373, Score: 606.52, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 374, Score: 608.23, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 375, Score: 605.89, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 376, Score: 604.89, Max: 833.72, Min: 38.50, T-max: 1000
# Episode: 377, Score: 1207.75, Max: 1207.75, Min: 38.50, T-max: 1999
# Episode: 378, Score: 616.56, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 379, Score: 616.80, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 380, Score: 619.49, Max: 1207.75, Min: 38.50, T-max: 1000
# *** Episode 380 	 Average Score (over agents): 619.49 	 Average Score on 100 Episode: 537.34, Time: 01:02:29***
# Episode: 381, Score: 620.21, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 382, Score: 617.64, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 383, Score: 612.50, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 384, Score: 626.36, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 385, Score: 621.58, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 386, Score: 618.28, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 387, Score: 637.24, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 388, Score: 583.31, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 389, Score: 632.85, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 390, Score: 635.83, Max: 1207.75, Min: 38.50, T-max: 1000
# *** Episode 390 	 Average Score (over agents): 635.83 	 Average Score on 100 Episode: 556.46, Time: 01:04:08***
# Episode: 391, Score: 634.42, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 392, Score: 639.53, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 393, Score: 641.29, Max: 1207.75, Min: 38.50, T-max: 1000
# Episode: 394, Score: 1281.95, Max: 1281.95, Min: 38.50, T-max: 1999
# Episode: 395, Score: 643.61, Max: 1281.95, Min: 38.50, T-max: 1000
# Episode: 396, Score: 645.09, Max: 1281.95, Min: 38.50, T-max: 1000
# Episode: 397, Score: 650.47, Max: 1281.95, Min: 38.50, T-max: 1000
# Episode: 398, Score: 658.91, Max: 1281.95, Min: 38.50, T-max: 1000
# Episode: 399, Score: 1302.40, Max: 1302.40, Min: 38.50, T-max: 1999
# Episode: 400, Score: 656.83, Max: 1302.40, Min: 38.50, T-max: 1000
# *** Episode 400 	 Average Score (over agents): 656.83 	 Average Score on 100 Episode: 588.53, Time: 01:06:08***
# Episode: 401, Score: 659.92, Max: 1302.40, Min: 38.50, T-max: 1000
# Episode: 402, Score: 664.09, Max: 1302.40, Min: 38.50, T-max: 1000
# Episode: 403, Score: 672.84, Max: 1302.40, Min: 38.50, T-max: 1000
# Episode: 404, Score: 673.64, Max: 1302.40, Min: 38.50, T-max: 1000
# Episode: 405, Score: 1340.38, Max: 1340.38, Min: 38.50, T-max: 1999
# Episode: 406, Score: 674.69, Max: 1340.38, Min: 38.50, T-max: 1000
# Episode: 407, Score: 657.78, Max: 1340.38, Min: 38.50, T-max: 1000
# Episode: 408, Score: 682.86, Max: 1340.38, Min: 38.50, T-max: 1000
# Episode: 409, Score: 684.71, Max: 1340.38, Min: 38.50, T-max: 1000
# Episode: 410, Score: 677.17, Max: 1340.38, Min: 38.50, T-max: 1000
# *** Episode 410 	 Average Score (over agents): 677.17 	 Average Score on 100 Episode: 613.78, Time: 01:07:57***
# Episode: 411, Score: 682.82, Max: 1340.38, Min: 38.50, T-max: 1000
# Episode: 412, Score: 690.10, Max: 1340.38, Min: 38.50, T-max: 1000
# Episode: 413, Score: 681.41, Max: 1340.38, Min: 38.50, T-max: 1000
# Episode: 414, Score: 686.72, Max: 1340.38, Min: 38.50, T-max: 1000
# Episode: 415, Score: 688.68, Max: 1340.38, Min: 38.50, T-max: 1000
# Episode: 416, Score: 690.89, Max: 1340.38, Min: 38.50, T-max: 1000
# Episode: 417, Score: 1365.34, Max: 1365.34, Min: 38.50, T-max: 1999
# Episode: 418, Score: 1368.69, Max: 1368.69, Min: 38.50, T-max: 1999
# Episode: 419, Score: 638.22, Max: 1368.69, Min: 38.50, T-max: 1000
# Episode: 420, Score: 695.18, Max: 1368.69, Min: 38.50, T-max: 1000
# *** Episode 420 	 Average Score (over agents): 695.18 	 Average Score on 100 Episode: 645.79, Time: 01:09:58***
# Episode: 421, Score: 683.59, Max: 1368.69, Min: 38.50, T-max: 1000
# Episode: 422, Score: 699.42, Max: 1368.69, Min: 38.50, T-max: 1000
# Episode: 423, Score: 1389.11, Max: 1389.11, Min: 38.50, T-max: 1999
# Episode: 424, Score: 687.65, Max: 1389.11, Min: 38.50, T-max: 1000
# Episode: 425, Score: 1377.78, Max: 1389.11, Min: 38.50, T-max: 1999
# Episode: 426, Score: 694.60, Max: 1389.11, Min: 38.50, T-max: 1000
# Episode: 427, Score: 1395.81, Max: 1395.81, Min: 38.50, T-max: 1999
# Episode: 428, Score: 706.67, Max: 1395.81, Min: 38.50, T-max: 1000
# Episode: 429, Score: 1413.15, Max: 1413.15, Min: 38.50, T-max: 1999
# Episode: 430, Score: 1413.82, Max: 1413.82, Min: 38.50, T-max: 1999
# *** Episode 430 	 Average Score (over agents): 1413.82 	 Average Score on 100 Episode: 697.65, Time: 01:12:24***
# Episode: 431, Score: 698.80, Max: 1413.82, Min: 38.50, T-max: 1000
# Episode: 432, Score: 701.79, Max: 1413.82, Min: 38.50, T-max: 1000
# Episode: 433, Score: 699.68, Max: 1413.82, Min: 38.50, T-max: 1000
# Episode: 434, Score: 1398.48, Max: 1413.82, Min: 38.50, T-max: 1999
# Episode: 435, Score: 706.55, Max: 1413.82, Min: 38.50, T-max: 1000
# Episode: 436, Score: 693.78, Max: 1413.82, Min: 38.50, T-max: 1000
# Episode: 437, Score: 1384.91, Max: 1413.82, Min: 38.50, T-max: 1999
# Episode: 438, Score: 711.61, Max: 1413.82, Min: 38.50, T-max: 1000
# Episode: 439, Score: 1422.90, Max: 1422.90, Min: 38.50, T-max: 1999
# Episode: 440, Score: 713.27, Max: 1422.90, Min: 38.50, T-max: 1000
# *** Episode 440 	 Average Score (over agents): 713.27 	 Average Score on 100 Episode: 733.39, Time: 01:14:36***
# Episode: 441, Score: 713.76, Max: 1422.90, Min: 38.50, T-max: 1000
# Episode: 442, Score: 707.46, Max: 1422.90, Min: 38.50, T-max: 1000
# Episode: 443, Score: 712.63, Max: 1422.90, Min: 38.50, T-max: 1000
# Episode: 444, Score: 715.18, Max: 1422.90, Min: 38.50, T-max: 1000
# Episode: 445, Score: 721.42, Max: 1422.90, Min: 38.50, T-max: 1000
# Episode: 446, Score: 700.97, Max: 1422.90, Min: 38.50, T-max: 1000
# Episode: 447, Score: 653.73, Max: 1422.90, Min: 38.50, T-max: 1000
# Episode: 448, Score: 716.16, Max: 1422.90, Min: 38.50, T-max: 1000
# Episode: 449, Score: 717.22, Max: 1422.90, Min: 38.50, T-max: 1000
# Episode: 450, Score: 719.81, Max: 1422.90, Min: 38.50, T-max: 1000
# *** Episode 450 	 Average Score (over agents): 719.81 	 Average Score on 100 Episode: 747.21, Time: 01:16:15***
# Episode: 451, Score: 1423.67, Max: 1423.67, Min: 38.50, T-max: 1999
# Episode: 452, Score: 730.22, Max: 1423.67, Min: 38.50, T-max: 1000
# Episode: 453, Score: 732.59, Max: 1423.67, Min: 38.50, T-max: 1000
# Episode: 454, Score: 1445.47, Max: 1445.47, Min: 38.50, T-max: 1999
# Episode: 455, Score: 1463.12, Max: 1463.12, Min: 38.50, T-max: 1999
# Episode: 456, Score: 721.66, Max: 1463.12, Min: 38.50, T-max: 1000
# Episode: 457, Score: 731.23, Max: 1463.12, Min: 38.50, T-max: 1000
# Episode: 458, Score: 735.93, Max: 1463.12, Min: 38.50, T-max: 1000
# Episode: 459, Score: 723.85, Max: 1463.12, Min: 38.50, T-max: 1000
# Episode: 460, Score: 663.53, Max: 1463.12, Min: 38.50, T-max: 1000
# *** Episode 460 	 Average Score (over agents): 663.53 	 Average Score on 100 Episode: 782.36, Time: 01:19:02***
# Episode: 461, Score: 732.45, Max: 1463.12, Min: 38.50, T-max: 1000
# Episode: 462, Score: 719.51, Max: 1463.12, Min: 38.50, T-max: 1000
# Episode: 463, Score: 1485.81, Max: 1485.81, Min: 38.50, T-max: 1999
# Episode: 464, Score: 739.40, Max: 1485.81, Min: 38.50, T-max: 1000
# Episode: 465, Score: 741.47, Max: 1485.81, Min: 38.50, T-max: 1000
# Episode: 466, Score: 743.28, Max: 1485.81, Min: 38.50, T-max: 1000
# Episode: 467, Score: 741.20, Max: 1485.81, Min: 38.50, T-max: 1000
# Episode: 468, Score: 738.81, Max: 1485.81, Min: 38.50, T-max: 1000
#
#  End of PPO!

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %%
env.close()
