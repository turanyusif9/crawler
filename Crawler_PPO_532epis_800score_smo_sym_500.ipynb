# %% [markdown]
# # Continuous Control
#
# ---
#
# Congratulations for completing the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program!  In this notebook, you will learn how to control an agent in a more challenging environment, where the goal is to train a creature with four arms to walk forward.  **Note that this exercise is optional!**
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Crawler.app"`
# - **Windows** (x86): `"path/to/Crawler_Windows_x86/Crawler.exe"`
# - **Windows** (x86_64): `"path/to/Crawler_Windows_x86_64/Crawler.exe"`
# - **Linux** (x86): `"path/to/Crawler_Linux/Crawler.x86"`
# - **Linux** (x86_64): `"path/to/Crawler_Linux/Crawler.x86_64"`
# - **Linux** (x86, headless): `"path/to/Crawler_Linux_NoVis/Crawler.x86"`
# - **Linux** (x86_64, headless): `"path/to/Crawler_Linux_NoVis/Crawler.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Crawler.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Crawler.app")
# ```

# %%
env = UnityEnvironment(file_name='C:/Users/Turan/Desktop/drl project/deep-reinforcement-learning/p2_continuous-control/Crawler_Windows_x86_64/Crawler.exe')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: CrawlerBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 129
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 20
#         Vector Action descriptions: , , , , , , , , , , , , , , , , , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 12
# Size of each action: 20
# There are 12 agents. Each observes a state with length: 129
# The state for the first agent looks like: [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  2.25000000e+00
#   1.00000000e+00  0.00000000e+00  1.78813934e-07  0.00000000e+00
#   1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093168e-01 -1.42857209e-01 -6.06078804e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339906e+00 -1.42857209e-01
#  -1.33341408e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093347e-01 -1.42857209e-01 -6.06078625e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339953e+00 -1.42857209e-01
#  -1.33341372e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093168e-01 -1.42857209e-01  6.06078804e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339906e+00 -1.42857209e-01
#   1.33341408e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093347e-01 -1.42857209e-01  6.06078625e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339953e+00 -1.42857209e-01
#   1.33341372e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
#env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
#states = env_info.vector_observations                  # get the current state (for each agent)
#scores = np.zeros(num_agents)                          # initialize the score (for each agent)
#while True:
#    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
#    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
#    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#    next_states = env_info.vector_observations         # get next state (for each agent)
#    rewards = env_info.rewards                         # get reward (for each agent)
#    dones = env_info.local_done                        # see if episode finished
#    scores += env_info.rewards                         # update the score (for each agent)
#    states = next_states                               # roll over states to next time step
#    if np.any(dones):                                  # exit loop if episode finished
#        break
#print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
#env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
from  collections  import deque
from itertools import count
import torch
import time
#from ddpg_agent import Agent
from ppo_agent_combined import Agent
import matplotlib.pyplot as plt
# %matplotlib inline
env_info = env.reset(train_mode=True)[brain_name]
agent = Agent(state_size=state_size, action_size=action_size, random_seed=8, n_agent=num_agents, \
              fc1_units=128, fc2_units=128)

print("Smoothness used:", agent.USE_SMOOTHNESS)
print("Symmetry used:", agent.USE_SYMMETRY)
print("Magnitude used:", agent.USE_MAGNITUDE)
# Out:
# Smoothness used: True
# Symmetry used: True
# Magnitude used: False

# %%
def ppo(env, agent, n_episodes=500, print_every=10, n_agent = 12):
    """
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        print_every (int): number of episodes to print result
        n_agent (int): number of identical agents in environment
    """
    scores_deque = deque(maxlen=100)
    scores_global = []    
    scores = []
    max_t = 2000
        
    time_start = time.time()
    
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        states = env_info.vector_observations
        agent_scores = np.zeros(n_agent)
        t_max = 0
        for t in range(max_t):
            actions, log_probs, _, values = agent.act(states)
            # get needed information from environment
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations
            rewards = env_info.rewards
            dones = np.array([1 if t else 0 for t in env_info.local_done])
            agent.save_step([states, values.detach(), actions, log_probs.detach(), rewards, 1 - dones])
            states = next_states
            agent_scores += rewards
            t_max = t
            if all(dones) or t == max_t-1:
                agent.step(next_states)
                break
                
        score = np.mean(agent_scores)
        scores_deque.append(score)
        scores.append(score)

        print('Episode: {}, Score: {:.2f}, Max: {:.2f}, Min: {:.2f}, T-max: {}   '\
              .format(i_episode, score, np.max(scores), np.min(scores), t_max))
        
        if i_episode % print_every == 0:
            torch.save(agent.actor_critic.actor.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.actor_critic.critic.state_dict(), 'checkpoint_critic.pth')
            s = (int)(time.time() - time_start) 
            print('*** Episode {} \t Average Score (over agents): {:.2f} \t Average Score on 100 Episode: {:.2f}, Time: {:02}:{:02}:{:02}***'\
                  .format(i_episode, score, np.mean(scores_deque), s//3600, s%3600//60, s%60))
            
        if len(scores_deque) == 100 and np.mean(scores_deque) >= 800: # 650: # 500:   
            break


    print('\n End of PPO!')
    return scores

scores = ppo(env=env, agent=agent)
# Out:
# c:\Users\Turan\miniconda3\envs\drlnd\lib\site-packages\torch\nn\functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Episode: 1, Score: 47.94, Max: 47.94, Min: 47.94, T-max: 1000
# Episode: 2, Score: 49.67, Max: 49.67, Min: 47.94, T-max: 1000
# Episode: 3, Score: 43.91, Max: 49.67, Min: 43.91, T-max: 1000
# Episode: 4, Score: 48.87, Max: 49.67, Min: 43.91, T-max: 1000
# Episode: 5, Score: 37.56, Max: 49.67, Min: 37.56, T-max: 1000
# Episode: 6, Score: 46.39, Max: 49.67, Min: 37.56, T-max: 1000
# Episode: 7, Score: 50.92, Max: 50.92, Min: 37.56, T-max: 1000
# Episode: 8, Score: 49.39, Max: 50.92, Min: 37.56, T-max: 1000
# Episode: 9, Score: 49.48, Max: 50.92, Min: 37.56, T-max: 1000
# Episode: 10, Score: 49.52, Max: 50.92, Min: 37.56, T-max: 1000
# *** Episode 10 	 Average Score (over agents): 49.52 	 Average Score on 100 Episode: 47.36, Time: 00:01:15***
# Episode: 11, Score: 45.55, Max: 50.92, Min: 37.56, T-max: 1000
# Episode: 12, Score: 45.39, Max: 50.92, Min: 37.56, T-max: 1000
# Episode: 13, Score: 53.86, Max: 53.86, Min: 37.56, T-max: 1000
# Episode: 14, Score: 49.31, Max: 53.86, Min: 37.56, T-max: 1000
# Episode: 15, Score: 52.48, Max: 53.86, Min: 37.56, T-max: 1000
# Episode: 16, Score: 51.30, Max: 53.86, Min: 37.56, T-max: 1000
# Episode: 17, Score: 53.80, Max: 53.86, Min: 37.56, T-max: 1000
# Episode: 18, Score: 54.09, Max: 54.09, Min: 37.56, T-max: 1000
# Episode: 19, Score: 55.08, Max: 55.08, Min: 37.56, T-max: 1000
# Episode: 20, Score: 54.25, Max: 55.08, Min: 37.56, T-max: 1000
# *** Episode 20 	 Average Score (over agents): 54.25 	 Average Score on 100 Episode: 49.44, Time: 00:02:32***
# Episode: 21, Score: 57.11, Max: 57.11, Min: 37.56, T-max: 1000
# Episode: 22, Score: 52.01, Max: 57.11, Min: 37.56, T-max: 1000
# Episode: 23, Score: 54.09, Max: 57.11, Min: 37.56, T-max: 1000
# Episode: 24, Score: 51.68, Max: 57.11, Min: 37.56, T-max: 1000
# Episode: 25, Score: 53.40, Max: 57.11, Min: 37.56, T-max: 1000
# Episode: 26, Score: 56.82, Max: 57.11, Min: 37.56, T-max: 1000
# Episode: 27, Score: 59.12, Max: 59.12, Min: 37.56, T-max: 1000
# Episode: 28, Score: 60.59, Max: 60.59, Min: 37.56, T-max: 1000
# Episode: 29, Score: 58.20, Max: 60.59, Min: 37.56, T-max: 1000
# Episode: 30, Score: 58.85, Max: 60.59, Min: 37.56, T-max: 1000
# *** Episode 30 	 Average Score (over agents): 58.85 	 Average Score on 100 Episode: 51.69, Time: 00:03:55***
# Episode: 31, Score: 60.80, Max: 60.80, Min: 37.56, T-max: 1000
# Episode: 32, Score: 55.66, Max: 60.80, Min: 37.56, T-max: 1000
# Episode: 33, Score: 58.85, Max: 60.80, Min: 37.56, T-max: 1000
# Episode: 34, Score: 59.41, Max: 60.80, Min: 37.56, T-max: 1000
# Episode: 35, Score: 61.03, Max: 61.03, Min: 37.56, T-max: 1000
# Episode: 36, Score: 62.67, Max: 62.67, Min: 37.56, T-max: 1000
# Episode: 37, Score: 63.29, Max: 63.29, Min: 37.56, T-max: 1000
# Episode: 38, Score: 60.71, Max: 63.29, Min: 37.56, T-max: 1000
# Episode: 39, Score: 63.88, Max: 63.88, Min: 37.56, T-max: 1000
# Episode: 40, Score: 61.98, Max: 63.88, Min: 37.56, T-max: 1000
# *** Episode 40 	 Average Score (over agents): 61.98 	 Average Score on 100 Episode: 53.97, Time: 00:05:10***
# Episode: 41, Score: 62.42, Max: 63.88, Min: 37.56, T-max: 1000
# Episode: 42, Score: 59.97, Max: 63.88, Min: 37.56, T-max: 1000
# Episode: 43, Score: 64.76, Max: 64.76, Min: 37.56, T-max: 1000
# Episode: 44, Score: 63.50, Max: 64.76, Min: 37.56, T-max: 1000
# Episode: 45, Score: 64.77, Max: 64.77, Min: 37.56, T-max: 1000
# Episode: 46, Score: 66.75, Max: 66.75, Min: 37.56, T-max: 1000
# Episode: 47, Score: 66.37, Max: 66.75, Min: 37.56, T-max: 1000
# Episode: 48, Score: 60.33, Max: 66.75, Min: 37.56, T-max: 1000
# Episode: 49, Score: 63.23, Max: 66.75, Min: 37.56, T-max: 1000
# Episode: 50, Score: 65.00, Max: 66.75, Min: 37.56, T-max: 1000
# *** Episode 50 	 Average Score (over agents): 65.00 	 Average Score on 100 Episode: 55.92, Time: 00:13:32***
# Episode: 51, Score: 69.49, Max: 69.49, Min: 37.56, T-max: 1000
# Episode: 52, Score: 67.90, Max: 69.49, Min: 37.56, T-max: 1000
# Episode: 53, Score: 64.84, Max: 69.49, Min: 37.56, T-max: 1000
# Episode: 54, Score: 61.77, Max: 69.49, Min: 37.56, T-max: 1000
# Episode: 55, Score: 69.28, Max: 69.49, Min: 37.56, T-max: 1000
# Episode: 56, Score: 69.37, Max: 69.49, Min: 37.56, T-max: 1000
# Episode: 57, Score: 70.91, Max: 70.91, Min: 37.56, T-max: 1000
# Episode: 58, Score: 71.24, Max: 71.24, Min: 37.56, T-max: 1000
# Episode: 59, Score: 70.38, Max: 71.24, Min: 37.56, T-max: 1000
# Episode: 60, Score: 69.47, Max: 71.24, Min: 37.56, T-max: 1000
# *** Episode 60 	 Average Score (over agents): 69.47 	 Average Score on 100 Episode: 58.01, Time: 00:14:50***
# Episode: 61, Score: 75.58, Max: 75.58, Min: 37.56, T-max: 1000
# Episode: 62, Score: 75.46, Max: 75.58, Min: 37.56, T-max: 1000
# Episode: 63, Score: 73.37, Max: 75.58, Min: 37.56, T-max: 1000
# Episode: 64, Score: 73.96, Max: 75.58, Min: 37.56, T-max: 1000
# Episode: 65, Score: 70.42, Max: 75.58, Min: 37.56, T-max: 1000
# Episode: 66, Score: 78.64, Max: 78.64, Min: 37.56, T-max: 1000
# Episode: 67, Score: 79.94, Max: 79.94, Min: 37.56, T-max: 1000
# Episode: 68, Score: 74.48, Max: 79.94, Min: 37.56, T-max: 1000
# Episode: 69, Score: 73.76, Max: 79.94, Min: 37.56, T-max: 1000
# Episode: 70, Score: 76.62, Max: 79.94, Min: 37.56, T-max: 1000
# *** Episode 70 	 Average Score (over agents): 76.62 	 Average Score on 100 Episode: 60.47, Time: 00:16:04***
# Episode: 71, Score: 81.39, Max: 81.39, Min: 37.56, T-max: 1000
# Episode: 72, Score: 79.27, Max: 81.39, Min: 37.56, T-max: 1000
# Episode: 73, Score: 72.47, Max: 81.39, Min: 37.56, T-max: 1000
# Episode: 74, Score: 81.47, Max: 81.47, Min: 37.56, T-max: 1000
# Episode: 75, Score: 77.40, Max: 81.47, Min: 37.56, T-max: 1000
# Episode: 76, Score: 76.20, Max: 81.47, Min: 37.56, T-max: 1000
# Episode: 77, Score: 84.77, Max: 84.77, Min: 37.56, T-max: 1000
# Episode: 78, Score: 80.33, Max: 84.77, Min: 37.56, T-max: 1000
# Episode: 79, Score: 86.23, Max: 86.23, Min: 37.56, T-max: 1000
# Episode: 80, Score: 82.13, Max: 86.23, Min: 37.56, T-max: 1000
# *** Episode 80 	 Average Score (over agents): 82.13 	 Average Score on 100 Episode: 62.93, Time: 00:17:11***
# Episode: 81, Score: 81.71, Max: 86.23, Min: 37.56, T-max: 1000
# Episode: 82, Score: 86.33, Max: 86.33, Min: 37.56, T-max: 1000
# Episode: 83, Score: 81.73, Max: 86.33, Min: 37.56, T-max: 1000
# Episode: 84, Score: 82.17, Max: 86.33, Min: 37.56, T-max: 1000
# Episode: 85, Score: 87.88, Max: 87.88, Min: 37.56, T-max: 1000
# Episode: 86, Score: 80.50, Max: 87.88, Min: 37.56, T-max: 1000
# Episode: 87, Score: 78.49, Max: 87.88, Min: 37.56, T-max: 1000
# Episode: 88, Score: 86.16, Max: 87.88, Min: 37.56, T-max: 1000
# Episode: 89, Score: 80.84, Max: 87.88, Min: 37.56, T-max: 1000
# Episode: 90, Score: 90.87, Max: 90.87, Min: 37.56, T-max: 1000
# *** Episode 90 	 Average Score (over agents): 90.87 	 Average Score on 100 Episode: 65.24, Time: 00:18:19***
# Episode: 91, Score: 91.67, Max: 91.67, Min: 37.56, T-max: 1000
# Episode: 92, Score: 91.68, Max: 91.68, Min: 37.56, T-max: 1000
# Episode: 93, Score: 94.71, Max: 94.71, Min: 37.56, T-max: 1000
# Episode: 94, Score: 95.34, Max: 95.34, Min: 37.56, T-max: 1000
# Episode: 95, Score: 87.45, Max: 95.34, Min: 37.56, T-max: 1000
# Episode: 96, Score: 86.92, Max: 95.34, Min: 37.56, T-max: 1000
# Episode: 97, Score: 90.63, Max: 95.34, Min: 37.56, T-max: 1000
# Episode: 98, Score: 92.22, Max: 95.34, Min: 37.56, T-max: 1000
# Episode: 99, Score: 85.13, Max: 95.34, Min: 37.56, T-max: 1000
# Episode: 100, Score: 101.48, Max: 101.48, Min: 37.56, T-max: 1000
# *** Episode 100 	 Average Score (over agents): 101.48 	 Average Score on 100 Episode: 67.88, Time: 00:19:31***
# Episode: 101, Score: 96.35, Max: 101.48, Min: 37.56, T-max: 1000
# Episode: 102, Score: 92.96, Max: 101.48, Min: 37.56, T-max: 1000
# Episode: 103, Score: 85.35, Max: 101.48, Min: 37.56, T-max: 1000
# Episode: 104, Score: 99.41, Max: 101.48, Min: 37.56, T-max: 1000
# Episode: 105, Score: 103.56, Max: 103.56, Min: 37.56, T-max: 1000
# Episode: 106, Score: 106.48, Max: 106.48, Min: 37.56, T-max: 1000
# Episode: 107, Score: 92.33, Max: 106.48, Min: 37.56, T-max: 1000
# Episode: 108, Score: 100.87, Max: 106.48, Min: 37.56, T-max: 1000
# Episode: 109, Score: 101.76, Max: 106.48, Min: 37.56, T-max: 1000
# Episode: 110, Score: 104.07, Max: 106.48, Min: 37.56, T-max: 1000
# *** Episode 110 	 Average Score (over agents): 104.07 	 Average Score on 100 Episode: 72.98, Time: 00:20:54***
# Episode: 111, Score: 103.92, Max: 106.48, Min: 37.56, T-max: 1000
# Episode: 112, Score: 107.79, Max: 107.79, Min: 37.56, T-max: 1000
# Episode: 113, Score: 109.46, Max: 109.46, Min: 37.56, T-max: 1000
# Episode: 114, Score: 106.94, Max: 109.46, Min: 37.56, T-max: 1000
# Episode: 115, Score: 121.79, Max: 121.79, Min: 37.56, T-max: 1000
# Episode: 116, Score: 118.22, Max: 121.79, Min: 37.56, T-max: 1000
# Episode: 117, Score: 114.01, Max: 121.79, Min: 37.56, T-max: 1000
# Episode: 118, Score: 117.94, Max: 121.79, Min: 37.56, T-max: 1000
# Episode: 119, Score: 111.37, Max: 121.79, Min: 37.56, T-max: 1000
# Episode: 120, Score: 120.47, Max: 121.79, Min: 37.56, T-max: 1000
# *** Episode 120 	 Average Score (over agents): 120.47 	 Average Score on 100 Episode: 79.15, Time: 00:22:13***
# Episode: 121, Score: 136.01, Max: 136.01, Min: 37.56, T-max: 1000
# Episode: 122, Score: 128.42, Max: 136.01, Min: 37.56, T-max: 1000
# Episode: 123, Score: 134.80, Max: 136.01, Min: 37.56, T-max: 1000
# Episode: 124, Score: 133.51, Max: 136.01, Min: 37.56, T-max: 1000
# Episode: 125, Score: 133.89, Max: 136.01, Min: 37.56, T-max: 1000
# Episode: 126, Score: 136.42, Max: 136.42, Min: 37.56, T-max: 1000
# Episode: 127, Score: 139.85, Max: 139.85, Min: 37.56, T-max: 1000
# Episode: 128, Score: 129.30, Max: 139.85, Min: 37.56, T-max: 1000
# Episode: 129, Score: 139.64, Max: 139.85, Min: 37.56, T-max: 1000
# Episode: 130, Score: 150.26, Max: 150.26, Min: 37.56, T-max: 1000
# *** Episode 130 	 Average Score (over agents): 150.26 	 Average Score on 100 Episode: 87.15, Time: 00:23:47***
# Episode: 131, Score: 141.32, Max: 150.26, Min: 37.56, T-max: 1000
# Episode: 132, Score: 148.85, Max: 150.26, Min: 37.56, T-max: 1000
# Episode: 133, Score: 142.90, Max: 150.26, Min: 37.56, T-max: 1000
# Episode: 134, Score: 139.41, Max: 150.26, Min: 37.56, T-max: 1000
# Episode: 135, Score: 147.38, Max: 150.26, Min: 37.56, T-max: 1000
# Episode: 136, Score: 151.39, Max: 151.39, Min: 37.56, T-max: 1000
# Episode: 137, Score: 142.21, Max: 151.39, Min: 37.56, T-max: 1000
# Episode: 138, Score: 156.76, Max: 156.76, Min: 37.56, T-max: 1000
# Episode: 139, Score: 163.29, Max: 163.29, Min: 37.56, T-max: 1000
# Episode: 140, Score: 159.88, Max: 163.29, Min: 37.56, T-max: 1000
# *** Episode 140 	 Average Score (over agents): 159.88 	 Average Score on 100 Episode: 96.00, Time: 00:25:44***
# Episode: 141, Score: 150.65, Max: 163.29, Min: 37.56, T-max: 1000
# Episode: 142, Score: 164.05, Max: 164.05, Min: 37.56, T-max: 1000
# Episode: 143, Score: 157.11, Max: 164.05, Min: 37.56, T-max: 1000
# Episode: 144, Score: 162.22, Max: 164.05, Min: 37.56, T-max: 1000
# Episode: 145, Score: 177.64, Max: 177.64, Min: 37.56, T-max: 1000
# Episode: 146, Score: 159.53, Max: 177.64, Min: 37.56, T-max: 1000
# Episode: 147, Score: 176.55, Max: 177.64, Min: 37.56, T-max: 1000
# Episode: 148, Score: 171.90, Max: 177.64, Min: 37.56, T-max: 1000
# Episode: 149, Score: 167.73, Max: 177.64, Min: 37.56, T-max: 1000
# Episode: 150, Score: 177.78, Max: 177.78, Min: 37.56, T-max: 1000
# *** Episode 150 	 Average Score (over agents): 177.78 	 Average Score on 100 Episode: 106.28, Time: 00:27:23***
# Episode: 151, Score: 179.62, Max: 179.62, Min: 37.56, T-max: 1000
# Episode: 152, Score: 175.40, Max: 179.62, Min: 37.56, T-max: 1000
# Episode: 153, Score: 180.60, Max: 180.60, Min: 37.56, T-max: 1000
# Episode: 154, Score: 186.36, Max: 186.36, Min: 37.56, T-max: 1000
# Episode: 155, Score: 186.91, Max: 186.91, Min: 37.56, T-max: 1000
# Episode: 156, Score: 175.87, Max: 186.91, Min: 37.56, T-max: 1000
# Episode: 157, Score: 190.23, Max: 190.23, Min: 37.56, T-max: 1000
# Episode: 158, Score: 190.29, Max: 190.29, Min: 37.56, T-max: 1000
# Episode: 159, Score: 188.50, Max: 190.29, Min: 37.56, T-max: 1000
# Episode: 160, Score: 184.31, Max: 190.29, Min: 37.56, T-max: 1000
# *** Episode 160 	 Average Score (over agents): 184.31 	 Average Score on 100 Episode: 117.82, Time: 00:28:50***
# Episode: 161, Score: 200.75, Max: 200.75, Min: 37.56, T-max: 1000
# Episode: 162, Score: 176.61, Max: 200.75, Min: 37.56, T-max: 1000
# Episode: 163, Score: 202.04, Max: 202.04, Min: 37.56, T-max: 1000
# Episode: 164, Score: 201.93, Max: 202.04, Min: 37.56, T-max: 1000
# Episode: 165, Score: 207.41, Max: 207.41, Min: 37.56, T-max: 1000
# Episode: 166, Score: 218.64, Max: 218.64, Min: 37.56, T-max: 1000
# Episode: 167, Score: 207.89, Max: 218.64, Min: 37.56, T-max: 1000
# Episode: 168, Score: 203.35, Max: 218.64, Min: 37.56, T-max: 1000
# Episode: 169, Score: 215.94, Max: 218.64, Min: 37.56, T-max: 1000
# Episode: 170, Score: 210.23, Max: 218.64, Min: 37.56, T-max: 1000
# *** Episode 170 	 Average Score (over agents): 210.23 	 Average Score on 100 Episode: 130.74, Time: 00:30:31***
# Episode: 171, Score: 214.89, Max: 218.64, Min: 37.56, T-max: 1000
# Episode: 172, Score: 210.90, Max: 218.64, Min: 37.56, T-max: 1000
# Episode: 173, Score: 197.86, Max: 218.64, Min: 37.56, T-max: 1000
# Episode: 174, Score: 227.73, Max: 227.73, Min: 37.56, T-max: 1000
# Episode: 175, Score: 219.29, Max: 227.73, Min: 37.56, T-max: 1000
# Episode: 176, Score: 201.94, Max: 227.73, Min: 37.56, T-max: 1000
# Episode: 177, Score: 235.77, Max: 235.77, Min: 37.56, T-max: 1000
# Episode: 178, Score: 223.15, Max: 235.77, Min: 37.56, T-max: 1000
# Episode: 179, Score: 231.28, Max: 235.77, Min: 37.56, T-max: 1000
# Episode: 180, Score: 213.22, Max: 235.77, Min: 37.56, T-max: 1000
# *** Episode 180 	 Average Score (over agents): 213.22 	 Average Score on 100 Episode: 144.48, Time: 00:32:10***
# Episode: 181, Score: 250.66, Max: 250.66, Min: 37.56, T-max: 1000
# Episode: 182, Score: 238.52, Max: 250.66, Min: 37.56, T-max: 1000
# Episode: 183, Score: 240.94, Max: 250.66, Min: 37.56, T-max: 1000
# Episode: 184, Score: 255.61, Max: 255.61, Min: 37.56, T-max: 1000
# Episode: 185, Score: 221.95, Max: 255.61, Min: 37.56, T-max: 1000
# Episode: 186, Score: 252.88, Max: 255.61, Min: 37.56, T-max: 1000
# Episode: 187, Score: 240.87, Max: 255.61, Min: 37.56, T-max: 1000
# Episode: 188, Score: 245.43, Max: 255.61, Min: 37.56, T-max: 1000
# Episode: 189, Score: 258.08, Max: 258.08, Min: 37.56, T-max: 1000
# Episode: 190, Score: 259.53, Max: 259.53, Min: 37.56, T-max: 1000
# *** Episode 190 	 Average Score (over agents): 259.53 	 Average Score on 100 Episode: 160.76, Time: 00:33:48***
# Episode: 191, Score: 267.79, Max: 267.79, Min: 37.56, T-max: 1000
# Episode: 192, Score: 262.57, Max: 267.79, Min: 37.56, T-max: 1000
# Episode: 193, Score: 271.00, Max: 271.00, Min: 37.56, T-max: 1000
# Episode: 194, Score: 278.50, Max: 278.50, Min: 37.56, T-max: 1000
# Episode: 195, Score: 282.78, Max: 282.78, Min: 37.56, T-max: 1000
# Episode: 196, Score: 267.29, Max: 282.78, Min: 37.56, T-max: 1000
# Episode: 197, Score: 261.97, Max: 282.78, Min: 37.56, T-max: 1000
# Episode: 198, Score: 290.35, Max: 290.35, Min: 37.56, T-max: 1000
# Episode: 199, Score: 297.79, Max: 297.79, Min: 37.56, T-max: 1000
# Episode: 200, Score: 258.68, Max: 297.79, Min: 37.56, T-max: 1000
# *** Episode 200 	 Average Score (over agents): 258.68 	 Average Score on 100 Episode: 178.98, Time: 00:35:53***
# Episode: 201, Score: 273.02, Max: 297.79, Min: 37.56, T-max: 1000
# Episode: 202, Score: 293.64, Max: 297.79, Min: 37.56, T-max: 1000
# Episode: 203, Score: 285.79, Max: 297.79, Min: 37.56, T-max: 1000
# Episode: 204, Score: 294.08, Max: 297.79, Min: 37.56, T-max: 1000
# Episode: 205, Score: 292.36, Max: 297.79, Min: 37.56, T-max: 1000
# Episode: 206, Score: 300.16, Max: 300.16, Min: 37.56, T-max: 1000
# Episode: 207, Score: 280.07, Max: 300.16, Min: 37.56, T-max: 1000
# Episode: 208, Score: 314.14, Max: 314.14, Min: 37.56, T-max: 1000
# Episode: 209, Score: 311.23, Max: 314.14, Min: 37.56, T-max: 1000
# Episode: 210, Score: 291.82, Max: 314.14, Min: 37.56, T-max: 1000
# *** Episode 210 	 Average Score (over agents): 291.82 	 Average Score on 100 Episode: 198.51, Time: 00:37:38***
# Episode: 211, Score: 323.67, Max: 323.67, Min: 37.56, T-max: 1000
# Episode: 212, Score: 301.64, Max: 323.67, Min: 37.56, T-max: 1000
# Episode: 213, Score: 302.93, Max: 323.67, Min: 37.56, T-max: 1000
# Episode: 214, Score: 301.06, Max: 323.67, Min: 37.56, T-max: 1000
# Episode: 215, Score: 332.09, Max: 332.09, Min: 37.56, T-max: 1000
# Episode: 216, Score: 305.86, Max: 332.09, Min: 37.56, T-max: 1000
# Episode: 217, Score: 340.60, Max: 340.60, Min: 37.56, T-max: 1000
# Episode: 218, Score: 334.28, Max: 340.60, Min: 37.56, T-max: 1000
# Episode: 219, Score: 342.72, Max: 342.72, Min: 37.56, T-max: 1000
# Episode: 220, Score: 342.42, Max: 342.72, Min: 37.56, T-max: 1000
# *** Episode 220 	 Average Score (over agents): 342.42 	 Average Score on 100 Episode: 219.46, Time: 00:39:22***
# Episode: 221, Score: 349.34, Max: 349.34, Min: 37.56, T-max: 1000
# Episode: 222, Score: 333.03, Max: 349.34, Min: 37.56, T-max: 1000
# Episode: 223, Score: 330.95, Max: 349.34, Min: 37.56, T-max: 1000
# Episode: 224, Score: 344.27, Max: 349.34, Min: 37.56, T-max: 1000
# Episode: 225, Score: 339.37, Max: 349.34, Min: 37.56, T-max: 1000
# Episode: 226, Score: 352.02, Max: 352.02, Min: 37.56, T-max: 1000
# Episode: 227, Score: 355.12, Max: 355.12, Min: 37.56, T-max: 1000
# Episode: 228, Score: 349.81, Max: 355.12, Min: 37.56, T-max: 1000
# Episode: 229, Score: 357.92, Max: 357.92, Min: 37.56, T-max: 1000
# Episode: 230, Score: 343.41, Max: 357.92, Min: 37.56, T-max: 1000
# *** Episode 230 	 Average Score (over agents): 343.41 	 Average Score on 100 Episode: 240.39, Time: 00:41:04***
# Episode: 231, Score: 363.85, Max: 363.85, Min: 37.56, T-max: 1000
# Episode: 232, Score: 370.98, Max: 370.98, Min: 37.56, T-max: 1000
# Episode: 233, Score: 350.55, Max: 370.98, Min: 37.56, T-max: 1000
# Episode: 234, Score: 337.58, Max: 370.98, Min: 37.56, T-max: 1000
# Episode: 235, Score: 398.15, Max: 398.15, Min: 37.56, T-max: 1000
# Episode: 236, Score: 360.03, Max: 398.15, Min: 37.56, T-max: 1000
# Episode: 237, Score: 372.65, Max: 398.15, Min: 37.56, T-max: 1000
# Episode: 238, Score: 385.81, Max: 398.15, Min: 37.56, T-max: 1000
# Episode: 239, Score: 364.25, Max: 398.15, Min: 37.56, T-max: 1000
# Episode: 240, Score: 390.09, Max: 398.15, Min: 37.56, T-max: 1000
# *** Episode 240 	 Average Score (over agents): 390.09 	 Average Score on 100 Episode: 262.40, Time: 00:42:48***
# Episode: 241, Score: 365.78, Max: 398.15, Min: 37.56, T-max: 1000
# Episode: 242, Score: 367.26, Max: 398.15, Min: 37.56, T-max: 1000
# Episode: 243, Score: 404.75, Max: 404.75, Min: 37.56, T-max: 1000
# Episode: 244, Score: 364.47, Max: 404.75, Min: 37.56, T-max: 1000
# Episode: 245, Score: 420.47, Max: 420.47, Min: 37.56, T-max: 1000
# Episode: 246, Score: 406.73, Max: 420.47, Min: 37.56, T-max: 1000
# Episode: 247, Score: 394.08, Max: 420.47, Min: 37.56, T-max: 1000
# Episode: 248, Score: 417.83, Max: 420.47, Min: 37.56, T-max: 1000
# Episode: 249, Score: 374.19, Max: 420.47, Min: 37.56, T-max: 1000
# Episode: 250, Score: 397.51, Max: 420.47, Min: 37.56, T-max: 1000
# *** Episode 250 	 Average Score (over agents): 397.51 	 Average Score on 100 Episode: 284.88, Time: 00:44:31***
# Episode: 251, Score: 404.34, Max: 420.47, Min: 37.56, T-max: 1000
# Episode: 252, Score: 405.84, Max: 420.47, Min: 37.56, T-max: 1000
# Episode: 253, Score: 423.26, Max: 423.26, Min: 37.56, T-max: 1000
# Episode: 254, Score: 395.01, Max: 423.26, Min: 37.56, T-max: 1000
# Episode: 255, Score: 431.71, Max: 431.71, Min: 37.56, T-max: 1000
# Episode: 256, Score: 419.44, Max: 431.71, Min: 37.56, T-max: 1000
# Episode: 257, Score: 372.97, Max: 431.71, Min: 37.56, T-max: 1000
# Episode: 258, Score: 421.25, Max: 431.71, Min: 37.56, T-max: 1000
# Episode: 259, Score: 412.13, Max: 431.71, Min: 37.56, T-max: 1000
# Episode: 260, Score: 448.97, Max: 448.97, Min: 37.56, T-max: 1000
# *** Episode 260 	 Average Score (over agents): 448.97 	 Average Score on 100 Episode: 307.85, Time: 00:46:14***
# Episode: 261, Score: 433.94, Max: 448.97, Min: 37.56, T-max: 1000
# Episode: 262, Score: 432.78, Max: 448.97, Min: 37.56, T-max: 1000
# Episode: 263, Score: 441.93, Max: 448.97, Min: 37.56, T-max: 1000
# Episode: 264, Score: 454.62, Max: 454.62, Min: 37.56, T-max: 1000
# Episode: 265, Score: 445.10, Max: 454.62, Min: 37.56, T-max: 1000
# Episode: 266, Score: 419.85, Max: 454.62, Min: 37.56, T-max: 1000
# Episode: 267, Score: 407.72, Max: 454.62, Min: 37.56, T-max: 1000
# Episode: 268, Score: 471.42, Max: 471.42, Min: 37.56, T-max: 1000
# Episode: 269, Score: 431.86, Max: 471.42, Min: 37.56, T-max: 1000
# Episode: 270, Score: 430.75, Max: 471.42, Min: 37.56, T-max: 1000
# *** Episode 270 	 Average Score (over agents): 430.75 	 Average Score on 100 Episode: 331.10, Time: 00:47:59***
# Episode: 271, Score: 429.70, Max: 471.42, Min: 37.56, T-max: 1000
# Episode: 272, Score: 433.91, Max: 471.42, Min: 37.56, T-max: 1000
# Episode: 273, Score: 436.83, Max: 471.42, Min: 37.56, T-max: 1000
# Episode: 274, Score: 472.50, Max: 472.50, Min: 37.56, T-max: 1000
# Episode: 275, Score: 450.57, Max: 472.50, Min: 37.56, T-max: 1000
# Episode: 276, Score: 485.89, Max: 485.89, Min: 37.56, T-max: 1000
# Episode: 277, Score: 447.73, Max: 485.89, Min: 37.56, T-max: 1000
# Episode: 278, Score: 424.73, Max: 485.89, Min: 37.56, T-max: 1000
# Episode: 279, Score: 454.13, Max: 485.89, Min: 37.56, T-max: 1000
# Episode: 280, Score: 462.70, Max: 485.89, Min: 37.56, T-max: 1000
# *** Episode 280 	 Average Score (over agents): 462.70 	 Average Score on 100 Episode: 354.33, Time: 00:49:41***
# Episode: 281, Score: 450.39, Max: 485.89, Min: 37.56, T-max: 1000
# Episode: 282, Score: 428.94, Max: 485.89, Min: 37.56, T-max: 1000
# Episode: 283, Score: 466.62, Max: 485.89, Min: 37.56, T-max: 1000
# Episode: 284, Score: 1006.11, Max: 1006.11, Min: 37.56, T-max: 1999
# Episode: 285, Score: 479.96, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 286, Score: 436.32, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 287, Score: 447.11, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 288, Score: 461.49, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 289, Score: 487.94, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 290, Score: 463.79, Max: 1006.11, Min: 37.56, T-max: 1000
# *** Episode 290 	 Average Score (over agents): 463.79 	 Average Score on 100 Episode: 380.97, Time: 00:51:34***
# Episode: 291, Score: 505.11, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 292, Score: 1001.32, Max: 1006.11, Min: 37.56, T-max: 1999
# Episode: 293, Score: 456.16, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 294, Score: 431.30, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 295, Score: 486.86, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 296, Score: 501.51, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 297, Score: 472.02, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 298, Score: 471.47, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 299, Score: 500.88, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 300, Score: 515.48, Max: 1006.11, Min: 37.56, T-max: 1000
# *** Episode 300 	 Average Score (over agents): 515.48 	 Average Score on 100 Episode: 407.00, Time: 00:53:27***
# Episode: 301, Score: 523.14, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 302, Score: 519.98, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 303, Score: 521.50, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 304, Score: 515.28, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 305, Score: 532.97, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 306, Score: 541.95, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 307, Score: 525.64, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 308, Score: 981.72, Max: 1006.11, Min: 37.56, T-max: 1999
# Episode: 309, Score: 543.42, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 310, Score: 551.64, Max: 1006.11, Min: 37.56, T-max: 1000
# *** Episode 310 	 Average Score (over agents): 551.64 	 Average Score on 100 Episode: 435.21, Time: 00:55:25***
# Episode: 311, Score: 548.77, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 312, Score: 553.40, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 313, Score: 566.50, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 314, Score: 558.53, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 315, Score: 557.68, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 316, Score: 566.59, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 317, Score: 558.62, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 318, Score: 538.25, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 319, Score: 574.49, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 320, Score: 574.74, Max: 1006.11, Min: 37.56, T-max: 1000
# *** Episode 320 	 Average Score (over agents): 574.74 	 Average Score on 100 Episode: 458.91, Time: 00:57:08***
# Episode: 321, Score: 525.08, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 322, Score: 563.99, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 323, Score: 553.45, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 324, Score: 574.10, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 325, Score: 580.14, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 326, Score: 566.59, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 327, Score: 568.32, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 328, Score: 580.22, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 329, Score: 579.96, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 330, Score: 588.27, Max: 1006.11, Min: 37.56, T-max: 1000
# *** Episode 330 	 Average Score (over agents): 588.27 	 Average Score on 100 Episode: 481.16, Time: 00:58:53***
# Episode: 331, Score: 587.25, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 332, Score: 532.68, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 333, Score: 579.85, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 334, Score: 564.18, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 335, Score: 566.57, Max: 1006.11, Min: 37.56, T-max: 1000
# Episode: 336, Score: 1144.74, Max: 1144.74, Min: 37.56, T-max: 1999
# Episode: 337, Score: 583.90, Max: 1144.74, Min: 37.56, T-max: 1000
# Episode: 338, Score: 583.31, Max: 1144.74, Min: 37.56, T-max: 1000
# Episode: 339, Score: 581.33, Max: 1144.74, Min: 37.56, T-max: 1000
# Episode: 340, Score: 548.53, Max: 1144.74, Min: 37.56, T-max: 1000
# *** Episode 340 	 Average Score (over agents): 548.53 	 Average Score on 100 Episode: 506.95, Time: 01:00:25***
# Episode: 341, Score: 549.59, Max: 1144.74, Min: 37.56, T-max: 1000
# Episode: 342, Score: 1086.88, Max: 1144.74, Min: 37.56, T-max: 1999
# Episode: 343, Score: 603.90, Max: 1144.74, Min: 37.56, T-max: 1000
# Episode: 344, Score: 597.94, Max: 1144.74, Min: 37.56, T-max: 1000
# Episode: 345, Score: 598.18, Max: 1144.74, Min: 37.56, T-max: 1000
# Episode: 346, Score: 1161.46, Max: 1161.46, Min: 37.56, T-max: 1999
# Episode: 347, Score: 567.51, Max: 1161.46, Min: 37.56, T-max: 1000
# Episode: 348, Score: 551.08, Max: 1161.46, Min: 37.56, T-max: 1000
# Episode: 349, Score: 607.99, Max: 1161.46, Min: 37.56, T-max: 1000
# Episode: 350, Score: 594.30, Max: 1161.46, Min: 37.56, T-max: 1000
# *** Episode 350 	 Average Score (over agents): 594.30 	 Average Score on 100 Episode: 537.01, Time: 01:02:29***
# Episode: 351, Score: 572.62, Max: 1161.46, Min: 37.56, T-max: 1000
# Episode: 352, Score: 605.56, Max: 1161.46, Min: 37.56, T-max: 1000
# Episode: 353, Score: 605.07, Max: 1161.46, Min: 37.56, T-max: 1000
# Episode: 354, Score: 598.55, Max: 1161.46, Min: 37.56, T-max: 1000
# Episode: 355, Score: 529.58, Max: 1161.46, Min: 37.56, T-max: 1000
# Episode: 356, Score: 572.34, Max: 1161.46, Min: 37.56, T-max: 1000
# Episode: 357, Score: 566.11, Max: 1161.46, Min: 37.56, T-max: 1000
# Episode: 358, Score: 594.27, Max: 1161.46, Min: 37.56, T-max: 1000
# Episode: 359, Score: 576.45, Max: 1161.46, Min: 37.56, T-max: 1000
# Episode: 360, Score: 485.14, Max: 1161.46, Min: 37.56, T-max: 1000
# *** Episode 360 	 Average Score (over agents): 485.14 	 Average Score on 100 Episode: 552.71, Time: 01:04:53***
# Episode: 361, Score: 1235.72, Max: 1235.72, Min: 37.56, T-max: 1999
# Episode: 362, Score: 627.03, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 363, Score: 474.49, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 364, Score: 581.69, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 365, Score: 1233.07, Max: 1235.72, Min: 37.56, T-max: 1999
# Episode: 366, Score: 569.28, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 367, Score: 510.92, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 368, Score: 571.14, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 369, Score: 1009.78, Max: 1235.72, Min: 37.56, T-max: 1999
# Episode: 370, Score: 603.26, Max: 1235.72, Min: 37.56, T-max: 1000
# *** Episode 370 	 Average Score (over agents): 603.26 	 Average Score on 100 Episode: 583.18, Time: 01:06:32***
# Episode: 371, Score: 616.94, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 372, Score: 598.93, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 373, Score: 1179.35, Max: 1235.72, Min: 37.56, T-max: 1999
# Episode: 374, Score: 647.12, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 375, Score: 628.08, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 376, Score: 606.44, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 377, Score: 514.61, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 378, Score: 1162.18, Max: 1235.72, Min: 37.56, T-max: 1999
# Episode: 379, Score: 624.50, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 380, Score: 607.73, Max: 1235.72, Min: 37.56, T-max: 1000
# *** Episode 380 	 Average Score (over agents): 607.73 	 Average Score on 100 Episode: 610.05, Time: 01:08:27***
# Episode: 381, Score: 563.91, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 382, Score: 1220.00, Max: 1235.72, Min: 37.56, T-max: 1999
# Episode: 383, Score: 585.15, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 384, Score: 587.68, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 385, Score: 579.98, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 386, Score: 615.98, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 387, Score: 595.18, Max: 1235.72, Min: 37.56, T-max: 1000
# Episode: 388, Score: 1242.20, Max: 1242.20, Min: 37.56, T-max: 1999
# Episode: 389, Score: 630.48, Max: 1242.20, Min: 37.56, T-max: 1000
# Episode: 390, Score: 625.77, Max: 1242.20, Min: 37.56, T-max: 1000
# *** Episode 390 	 Average Score (over agents): 625.77 	 Average Score on 100 Episode: 631.23, Time: 01:10:32***
# Episode: 391, Score: 610.97, Max: 1242.20, Min: 37.56, T-max: 1000
# Episode: 392, Score: 1281.44, Max: 1281.44, Min: 37.56, T-max: 1999
# Episode: 393, Score: 579.02, Max: 1281.44, Min: 37.56, T-max: 1000
# Episode: 394, Score: 636.04, Max: 1281.44, Min: 37.56, T-max: 1000
# Episode: 395, Score: 632.05, Max: 1281.44, Min: 37.56, T-max: 1000
# Episode: 396, Score: 637.38, Max: 1281.44, Min: 37.56, T-max: 1000
# Episode: 397, Score: 499.39, Max: 1281.44, Min: 37.56, T-max: 1000
# Episode: 398, Score: 1085.45, Max: 1281.44, Min: 37.56, T-max: 1999
# Episode: 399, Score: 609.22, Max: 1281.44, Min: 37.56, T-max: 1000
# Episode: 400, Score: 628.27, Max: 1281.44, Min: 37.56, T-max: 1000
# *** Episode 400 	 Average Score (over agents): 628.27 	 Average Score on 100 Episode: 649.80, Time: 01:12:37***
# Episode: 401, Score: 632.32, Max: 1281.44, Min: 37.56, T-max: 1000
# Episode: 402, Score: 1237.63, Max: 1281.44, Min: 37.56, T-max: 1999
# Episode: 403, Score: 614.40, Max: 1281.44, Min: 37.56, T-max: 1000
# Episode: 404, Score: 1254.65, Max: 1281.44, Min: 37.56, T-max: 1999
# Episode: 405, Score: 581.07, Max: 1281.44, Min: 37.56, T-max: 1000
# Episode: 406, Score: 645.81, Max: 1281.44, Min: 37.56, T-max: 1000
# Episode: 407, Score: 1272.14, Max: 1281.44, Min: 37.56, T-max: 1999
# Episode: 408, Score: 611.34, Max: 1281.44, Min: 37.56, T-max: 1000
# Episode: 409, Score: 623.66, Max: 1281.44, Min: 37.56, T-max: 1000
# Episode: 410, Score: 619.69, Max: 1281.44, Min: 37.56, T-max: 1000
# *** Episode 410 	 Average Score (over agents): 619.69 	 Average Score on 100 Episode: 673.15, Time: 01:14:53***
# Episode: 411, Score: 620.15, Max: 1281.44, Min: 37.56, T-max: 1000
# Episode: 412, Score: 1285.82, Max: 1285.82, Min: 37.56, T-max: 1999
# Episode: 413, Score: 647.96, Max: 1285.82, Min: 37.56, T-max: 1000
# Episode: 414, Score: 641.54, Max: 1285.82, Min: 37.56, T-max: 1000
# Episode: 415, Score: 1290.02, Max: 1290.02, Min: 37.56, T-max: 1999
# Episode: 416, Score: 609.05, Max: 1290.02, Min: 37.56, T-max: 1000
# Episode: 417, Score: 1305.62, Max: 1305.62, Min: 37.56, T-max: 1999
# Episode: 418, Score: 657.12, Max: 1305.62, Min: 37.56, T-max: 1000
# Episode: 419, Score: 1326.34, Max: 1326.34, Min: 37.56, T-max: 1999
# Episode: 420, Score: 1325.25, Max: 1326.34, Min: 37.56, T-max: 1999
# *** Episode 420 	 Average Score (over agents): 1325.25 	 Average Score on 100 Episode: 714.26, Time: 01:17:26***
# Episode: 421, Score: 661.95, Max: 1326.34, Min: 37.56, T-max: 1000
# Episode: 422, Score: 666.77, Max: 1326.34, Min: 37.56, T-max: 1000
# Episode: 423, Score: 1350.10, Max: 1350.10, Min: 37.56, T-max: 1999
# Episode: 424, Score: 666.57, Max: 1350.10, Min: 37.56, T-max: 1000
# Episode: 425, Score: 1344.33, Max: 1350.10, Min: 37.56, T-max: 1999
# Episode: 426, Score: 656.13, Max: 1350.10, Min: 37.56, T-max: 1000
# Episode: 427, Score: 1347.16, Max: 1350.10, Min: 37.56, T-max: 1999
# Episode: 428, Score: 683.10, Max: 1350.10, Min: 37.56, T-max: 1000
# Episode: 429, Score: 1354.67, Max: 1354.67, Min: 37.56, T-max: 1999
# Episode: 430, Score: 700.29, Max: 1354.67, Min: 37.56, T-max: 1000
# *** Episode 430 	 Average Score (over agents): 700.29 	 Average Score on 100 Episode: 751.77, Time: 01:19:51***
# Episode: 431, Score: 683.79, Max: 1354.67, Min: 37.56, T-max: 1000
# Episode: 432, Score: 690.89, Max: 1354.67, Min: 37.56, T-max: 1000
# Episode: 433, Score: 694.78, Max: 1354.67, Min: 37.56, T-max: 1000
# Episode: 434, Score: 680.53, Max: 1354.67, Min: 37.56, T-max: 1000
# Episode: 435, Score: 1353.72, Max: 1354.67, Min: 37.56, T-max: 1999
# Episode: 436, Score: 689.05, Max: 1354.67, Min: 37.56, T-max: 1000
# Episode: 437, Score: 1393.52, Max: 1393.52, Min: 37.56, T-max: 1999
# Episode: 438, Score: 1390.74, Max: 1393.52, Min: 37.56, T-max: 1999
# Episode: 439, Score: 710.97, Max: 1393.52, Min: 37.56, T-max: 1000
# Episode: 440, Score: 707.02, Max: 1393.52, Min: 37.56, T-max: 1000
# *** Episode 440 	 Average Score (over agents): 707.02 	 Average Score on 100 Episode: 779.00, Time: 01:22:05***
# Episode: 441, Score: 716.59, Max: 1393.52, Min: 37.56, T-max: 1000
# Episode: 442, Score: 1417.14, Max: 1417.14, Min: 37.56, T-max: 1999
# Episode: 443, Score: 632.18, Max: 1417.14, Min: 37.56, T-max: 1000
# Episode: 444, Score: 1402.99, Max: 1417.14, Min: 37.56, T-max: 1999
# Episode: 445, Score: 714.92, Max: 1417.14, Min: 37.56, T-max: 1000
# Episode: 446, Score: 1432.89, Max: 1432.89, Min: 37.56, T-max: 1999
# Episode: 447, Score: 688.19, Max: 1432.89, Min: 37.56, T-max: 1000
# Episode: 448, Score: 681.49, Max: 1432.89, Min: 37.56, T-max: 1000
# Episode: 449, Score: 708.65, Max: 1432.89, Min: 37.56, T-max: 1000
# Episode: 450, Score: 1438.66, Max: 1438.66, Min: 37.56, T-max: 1999
# *** Episode 450 	 Average Score (over agents): 1438.66 	 Average Score on 100 Episode: 808.15, Time: 01:24:30***
#
#  End of PPO!

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %%
env.close()
