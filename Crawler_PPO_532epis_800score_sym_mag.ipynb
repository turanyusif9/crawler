# %% [markdown]
# # Continuous Control
#
# ---
#
# Congratulations for completing the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program!  In this notebook, you will learn how to control an agent in a more challenging environment, where the goal is to train a creature with four arms to walk forward.  **Note that this exercise is optional!**
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Crawler.app"`
# - **Windows** (x86): `"path/to/Crawler_Windows_x86/Crawler.exe"`
# - **Windows** (x86_64): `"path/to/Crawler_Windows_x86_64/Crawler.exe"`
# - **Linux** (x86): `"path/to/Crawler_Linux/Crawler.x86"`
# - **Linux** (x86_64): `"path/to/Crawler_Linux/Crawler.x86_64"`
# - **Linux** (x86, headless): `"path/to/Crawler_Linux_NoVis/Crawler.x86"`
# - **Linux** (x86_64, headless): `"path/to/Crawler_Linux_NoVis/Crawler.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Crawler.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Crawler.app")
# ```

# %%
env = UnityEnvironment(file_name='C:/Users/Turan/Desktop/drl project/deep-reinforcement-learning/p2_continuous-control/Crawler_Windows_x86_64/Crawler.exe')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: CrawlerBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 129
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 20
#         Vector Action descriptions: , , , , , , , , , , , , , , , , , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 12
# Size of each action: 20
# There are 12 agents. Each observes a state with length: 129
# The state for the first agent looks like: [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  2.25000000e+00
#   1.00000000e+00  0.00000000e+00  1.78813934e-07  0.00000000e+00
#   1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093168e-01 -1.42857209e-01 -6.06078804e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339906e+00 -1.42857209e-01
#  -1.33341408e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093347e-01 -1.42857209e-01 -6.06078625e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339953e+00 -1.42857209e-01
#  -1.33341372e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093168e-01 -1.42857209e-01  6.06078804e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339906e+00 -1.42857209e-01
#   1.33341408e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093347e-01 -1.42857209e-01  6.06078625e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339953e+00 -1.42857209e-01
#   1.33341372e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
#env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
#states = env_info.vector_observations                  # get the current state (for each agent)
#scores = np.zeros(num_agents)                          # initialize the score (for each agent)
#while True:
#    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
#    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
#    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#    next_states = env_info.vector_observations         # get next state (for each agent)
#    rewards = env_info.rewards                         # get reward (for each agent)
#    dones = env_info.local_done                        # see if episode finished
#    scores += env_info.rewards                         # update the score (for each agent)
#    states = next_states                               # roll over states to next time step
#    if np.any(dones):                                  # exit loop if episode finished
#        break
#print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
#env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
from  collections  import deque
from itertools import count
import torch
import time
#from ddpg_agent import Agent
from ppo_agent_combined import Agent
import matplotlib.pyplot as plt
# %matplotlib inline
env_info = env.reset(train_mode=True)[brain_name]
agent = Agent(state_size=state_size, action_size=action_size, random_seed=8, n_agent=num_agents, \
              fc1_units=128, fc2_units=128)

print("Smoothness used:", agent.USE_SMOOTHNESS)
print("Symmetry used:", agent.USE_SYMMETRY)
print("Magnitude used:", agent.USE_MAGNITUDE)
# Out:
# Smoothness used: False
# Symmetry used: True
# Magnitude used: True

# %%
def ppo(env, agent, n_episodes=500, print_every=10, n_agent = 12):
    """
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        print_every (int): number of episodes to print result
        n_agent (int): number of identical agents in environment
    """
    scores_deque = deque(maxlen=100)
    scores_global = []    
    scores = []
    max_t = 2000
        
    time_start = time.time()
    
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        states = env_info.vector_observations
        agent_scores = np.zeros(n_agent)
        t_max = 0
        for t in range(max_t):
            actions, log_probs, _, values = agent.act(states)
            # get needed information from environment
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations
            rewards = env_info.rewards
            dones = np.array([1 if t else 0 for t in env_info.local_done])
            agent.save_step([states, values.detach(), actions, log_probs.detach(), rewards, 1 - dones])
            states = next_states
            agent_scores += rewards
            t_max = t
            if all(dones) or t == max_t-1:
                agent.step(next_states)
                break
                
        score = np.mean(agent_scores)
        scores_deque.append(score)
        scores.append(score)

        print('Episode: {}, Score: {:.2f}, Max: {:.2f}, Min: {:.2f}, T-max: {}   '\
              .format(i_episode, score, np.max(scores), np.min(scores), t_max))
        
        if i_episode % print_every == 0:
            torch.save(agent.actor_critic.actor.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.actor_critic.critic.state_dict(), 'checkpoint_critic.pth')
            s = (int)(time.time() - time_start) 
            print('*** Episode {} \t Average Score (over agents): {:.2f} \t Average Score on 100 Episode: {:.2f}, Time: {:02}:{:02}:{:02}***'\
                  .format(i_episode, score, np.mean(scores_deque), s//3600, s%3600//60, s%60))
            
        if len(scores_deque) == 100 and np.mean(scores_deque) >= 800: # 650: # 500:   
            break


    print('\n End of PPO!')
    return scores

scores = ppo(env=env, agent=agent)
# Out:
# c:\Users\Turan\miniconda3\envs\drlnd\lib\site-packages\torch\nn\functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Episode: 1, Score: 47.94, Max: 47.94, Min: 47.94, T-max: 1000
# Episode: 2, Score: 49.67, Max: 49.67, Min: 47.94, T-max: 1000
# Episode: 3, Score: 43.91, Max: 49.67, Min: 43.91, T-max: 1000
# Episode: 4, Score: 48.24, Max: 49.67, Min: 43.91, T-max: 1000
# Episode: 5, Score: 37.69, Max: 49.67, Min: 37.69, T-max: 1000
# Episode: 6, Score: 45.28, Max: 49.67, Min: 37.69, T-max: 1000
# Episode: 7, Score: 50.30, Max: 50.30, Min: 37.69, T-max: 1000
# Episode: 8, Score: 48.77, Max: 50.30, Min: 37.69, T-max: 1000
# Episode: 9, Score: 49.94, Max: 50.30, Min: 37.69, T-max: 1000
# Episode: 10, Score: 47.63, Max: 50.30, Min: 37.69, T-max: 1000
# *** Episode 10 	 Average Score (over agents): 47.63 	 Average Score on 100 Episode: 46.94, Time: 00:01:10***
# Episode: 11, Score: 45.97, Max: 50.30, Min: 37.69, T-max: 1000
# Episode: 12, Score: 46.45, Max: 50.30, Min: 37.69, T-max: 1000
# Episode: 13, Score: 53.76, Max: 53.76, Min: 37.69, T-max: 1000
# Episode: 14, Score: 49.69, Max: 53.76, Min: 37.69, T-max: 1000
# Episode: 15, Score: 52.26, Max: 53.76, Min: 37.69, T-max: 1000
# Episode: 16, Score: 52.05, Max: 53.76, Min: 37.69, T-max: 1000
# Episode: 17, Score: 55.54, Max: 55.54, Min: 37.69, T-max: 1000
# Episode: 18, Score: 56.50, Max: 56.50, Min: 37.69, T-max: 1000
# Episode: 19, Score: 57.06, Max: 57.06, Min: 37.69, T-max: 1000
# Episode: 20, Score: 56.64, Max: 57.06, Min: 37.69, T-max: 1000
# *** Episode 20 	 Average Score (over agents): 56.64 	 Average Score on 100 Episode: 49.76, Time: 00:02:38***
# Episode: 21, Score: 56.88, Max: 57.06, Min: 37.69, T-max: 1000
# Episode: 22, Score: 52.99, Max: 57.06, Min: 37.69, T-max: 1000
# Episode: 23, Score: 57.21, Max: 57.21, Min: 37.69, T-max: 1000
# Episode: 24, Score: 51.99, Max: 57.21, Min: 37.69, T-max: 1000
# Episode: 25, Score: 54.70, Max: 57.21, Min: 37.69, T-max: 1000
# Episode: 26, Score: 58.67, Max: 58.67, Min: 37.69, T-max: 1000
# Episode: 27, Score: 59.70, Max: 59.70, Min: 37.69, T-max: 1000
# Episode: 28, Score: 61.95, Max: 61.95, Min: 37.69, T-max: 1000
# Episode: 29, Score: 62.72, Max: 62.72, Min: 37.69, T-max: 1000
# Episode: 30, Score: 62.76, Max: 62.76, Min: 37.69, T-max: 1000
# *** Episode 30 	 Average Score (over agents): 62.76 	 Average Score on 100 Episode: 52.50, Time: 00:04:21***
# Episode: 31, Score: 64.63, Max: 64.63, Min: 37.69, T-max: 1000
# Episode: 32, Score: 58.52, Max: 64.63, Min: 37.69, T-max: 1000
# Episode: 33, Score: 64.84, Max: 64.84, Min: 37.69, T-max: 1000
# Episode: 34, Score: 66.09, Max: 66.09, Min: 37.69, T-max: 1000
# Episode: 35, Score: 65.77, Max: 66.09, Min: 37.69, T-max: 1000
# Episode: 36, Score: 66.98, Max: 66.98, Min: 37.69, T-max: 1000
# Episode: 37, Score: 66.18, Max: 66.98, Min: 37.69, T-max: 1000
# Episode: 38, Score: 65.60, Max: 66.98, Min: 37.69, T-max: 1000
# Episode: 39, Score: 69.25, Max: 69.25, Min: 37.69, T-max: 1000
# Episode: 40, Score: 67.77, Max: 69.25, Min: 37.69, T-max: 1000
# *** Episode 40 	 Average Score (over agents): 67.77 	 Average Score on 100 Episode: 55.76, Time: 00:06:07***
# Episode: 41, Score: 67.05, Max: 69.25, Min: 37.69, T-max: 1000
# Episode: 42, Score: 65.28, Max: 69.25, Min: 37.69, T-max: 1000
# Episode: 43, Score: 69.39, Max: 69.39, Min: 37.69, T-max: 1000
# Episode: 44, Score: 67.56, Max: 69.39, Min: 37.69, T-max: 1000
# Episode: 45, Score: 69.55, Max: 69.55, Min: 37.69, T-max: 1000
# Episode: 46, Score: 72.69, Max: 72.69, Min: 37.69, T-max: 1000
# Episode: 47, Score: 72.18, Max: 72.69, Min: 37.69, T-max: 1000
# Episode: 48, Score: 68.07, Max: 72.69, Min: 37.69, T-max: 1000
# Episode: 49, Score: 74.64, Max: 74.64, Min: 37.69, T-max: 1000
# Episode: 50, Score: 72.21, Max: 74.64, Min: 37.69, T-max: 1000
# *** Episode 50 	 Average Score (over agents): 72.21 	 Average Score on 100 Episode: 58.58, Time: 00:07:52***
# Episode: 51, Score: 73.44, Max: 74.64, Min: 37.69, T-max: 1000
# Episode: 52, Score: 75.02, Max: 75.02, Min: 37.69, T-max: 1000
# Episode: 53, Score: 77.48, Max: 77.48, Min: 37.69, T-max: 1000
# Episode: 54, Score: 68.24, Max: 77.48, Min: 37.69, T-max: 1000
# Episode: 55, Score: 75.65, Max: 77.48, Min: 37.69, T-max: 1000
# Episode: 56, Score: 78.80, Max: 78.80, Min: 37.69, T-max: 1000
# Episode: 57, Score: 76.36, Max: 78.80, Min: 37.69, T-max: 1000
# Episode: 58, Score: 81.86, Max: 81.86, Min: 37.69, T-max: 1000
# Episode: 59, Score: 80.60, Max: 81.86, Min: 37.69, T-max: 1000
# Episode: 60, Score: 80.85, Max: 81.86, Min: 37.69, T-max: 1000
# *** Episode 60 	 Average Score (over agents): 80.85 	 Average Score on 100 Episode: 61.62, Time: 00:09:39***
# Episode: 61, Score: 87.69, Max: 87.69, Min: 37.69, T-max: 1000
# Episode: 62, Score: 85.99, Max: 87.69, Min: 37.69, T-max: 1000
# Episode: 63, Score: 85.35, Max: 87.69, Min: 37.69, T-max: 1000
# Episode: 64, Score: 83.17, Max: 87.69, Min: 37.69, T-max: 1000
# Episode: 65, Score: 84.20, Max: 87.69, Min: 37.69, T-max: 1000
# Episode: 66, Score: 89.54, Max: 89.54, Min: 37.69, T-max: 1000
# Episode: 67, Score: 91.78, Max: 91.78, Min: 37.69, T-max: 1000
# Episode: 68, Score: 85.42, Max: 91.78, Min: 37.69, T-max: 1000
# Episode: 69, Score: 84.74, Max: 91.78, Min: 37.69, T-max: 1000
# Episode: 70, Score: 89.38, Max: 91.78, Min: 37.69, T-max: 1000
# *** Episode 70 	 Average Score (over agents): 89.38 	 Average Score on 100 Episode: 65.21, Time: 00:11:25***
# Episode: 71, Score: 89.36, Max: 91.78, Min: 37.69, T-max: 1000
# Episode: 72, Score: 95.56, Max: 95.56, Min: 37.69, T-max: 1000
# Episode: 73, Score: 87.22, Max: 95.56, Min: 37.69, T-max: 1000
# Episode: 74, Score: 92.21, Max: 95.56, Min: 37.69, T-max: 1000
# Episode: 75, Score: 97.96, Max: 97.96, Min: 37.69, T-max: 1000
# Episode: 76, Score: 94.46, Max: 97.96, Min: 37.69, T-max: 1000
# Episode: 77, Score: 106.18, Max: 106.18, Min: 37.69, T-max: 1000
# Episode: 78, Score: 100.31, Max: 106.18, Min: 37.69, T-max: 1000
# Episode: 79, Score: 113.85, Max: 113.85, Min: 37.69, T-max: 1000
# Episode: 80, Score: 106.08, Max: 113.85, Min: 37.69, T-max: 1000
# *** Episode 80 	 Average Score (over agents): 106.08 	 Average Score on 100 Episode: 69.35, Time: 00:13:10***
# Episode: 81, Score: 101.82, Max: 113.85, Min: 37.69, T-max: 1000
# Episode: 82, Score: 108.32, Max: 113.85, Min: 37.69, T-max: 1000
# Episode: 83, Score: 102.94, Max: 113.85, Min: 37.69, T-max: 1000
# Episode: 84, Score: 103.28, Max: 113.85, Min: 37.69, T-max: 1000
# Episode: 85, Score: 99.54, Max: 113.85, Min: 37.69, T-max: 1000
# Episode: 86, Score: 103.03, Max: 113.85, Min: 37.69, T-max: 1000
# Episode: 87, Score: 107.78, Max: 113.85, Min: 37.69, T-max: 1000
# Episode: 88, Score: 111.92, Max: 113.85, Min: 37.69, T-max: 1000
# Episode: 89, Score: 111.11, Max: 113.85, Min: 37.69, T-max: 1000
# Episode: 90, Score: 115.74, Max: 115.74, Min: 37.69, T-max: 1000
# *** Episode 90 	 Average Score (over agents): 115.74 	 Average Score on 100 Episode: 73.48, Time: 00:14:57***
# Episode: 91, Score: 118.16, Max: 118.16, Min: 37.69, T-max: 1000
# Episode: 92, Score: 114.27, Max: 118.16, Min: 37.69, T-max: 1000
# Episode: 93, Score: 116.30, Max: 118.16, Min: 37.69, T-max: 1000
# Episode: 94, Score: 124.88, Max: 124.88, Min: 37.69, T-max: 1000
# Episode: 95, Score: 119.22, Max: 124.88, Min: 37.69, T-max: 1000
# Episode: 96, Score: 122.37, Max: 124.88, Min: 37.69, T-max: 1000
# Episode: 97, Score: 114.15, Max: 124.88, Min: 37.69, T-max: 1000
# Episode: 98, Score: 124.51, Max: 124.88, Min: 37.69, T-max: 1000
# Episode: 99, Score: 118.31, Max: 124.88, Min: 37.69, T-max: 1000
# Episode: 100, Score: 137.88, Max: 137.88, Min: 37.69, T-max: 1000
# *** Episode 100 	 Average Score (over agents): 137.88 	 Average Score on 100 Episode: 78.23, Time: 00:16:44***
# Episode: 101, Score: 128.84, Max: 137.88, Min: 37.69, T-max: 1000
# Episode: 102, Score: 127.33, Max: 137.88, Min: 37.69, T-max: 1000
# Episode: 103, Score: 130.67, Max: 137.88, Min: 37.69, T-max: 1000
# Episode: 104, Score: 135.57, Max: 137.88, Min: 37.69, T-max: 1000
# Episode: 105, Score: 127.67, Max: 137.88, Min: 37.69, T-max: 1000
# Episode: 106, Score: 142.75, Max: 142.75, Min: 37.69, T-max: 1000
# Episode: 107, Score: 127.63, Max: 142.75, Min: 37.69, T-max: 1000
# Episode: 108, Score: 136.26, Max: 142.75, Min: 37.69, T-max: 1000
# Episode: 109, Score: 129.35, Max: 142.75, Min: 37.69, T-max: 1000
# Episode: 110, Score: 129.00, Max: 142.75, Min: 37.69, T-max: 1000
# *** Episode 110 	 Average Score (over agents): 129.00 	 Average Score on 100 Episode: 86.69, Time: 00:18:29***
# Episode: 111, Score: 142.74, Max: 142.75, Min: 37.69, T-max: 1000
# Episode: 112, Score: 140.58, Max: 142.75, Min: 37.69, T-max: 1000
# Episode: 113, Score: 144.29, Max: 144.29, Min: 37.69, T-max: 1000
# Episode: 114, Score: 128.59, Max: 144.29, Min: 37.69, T-max: 1000
# Episode: 115, Score: 159.57, Max: 159.57, Min: 37.69, T-max: 1000
# Episode: 116, Score: 140.99, Max: 159.57, Min: 37.69, T-max: 1000
# Episode: 117, Score: 149.40, Max: 159.57, Min: 37.69, T-max: 1000
# Episode: 118, Score: 145.18, Max: 159.57, Min: 37.69, T-max: 1000
# Episode: 119, Score: 154.02, Max: 159.57, Min: 37.69, T-max: 1000
# Episode: 120, Score: 153.57, Max: 159.57, Min: 37.69, T-max: 1000
# *** Episode 120 	 Average Score (over agents): 153.57 	 Average Score on 100 Episode: 96.02, Time: 00:20:17***
# Episode: 121, Score: 166.90, Max: 166.90, Min: 37.69, T-max: 1000
# Episode: 122, Score: 154.48, Max: 166.90, Min: 37.69, T-max: 1000
# Episode: 123, Score: 168.70, Max: 168.70, Min: 37.69, T-max: 1000
# Episode: 124, Score: 149.33, Max: 168.70, Min: 37.69, T-max: 1000
# Episode: 125, Score: 165.72, Max: 168.70, Min: 37.69, T-max: 1000
# Episode: 126, Score: 157.96, Max: 168.70, Min: 37.69, T-max: 1000
# Episode: 127, Score: 170.91, Max: 170.91, Min: 37.69, T-max: 1000
# Episode: 128, Score: 154.34, Max: 170.91, Min: 37.69, T-max: 1000
# Episode: 129, Score: 169.54, Max: 170.91, Min: 37.69, T-max: 1000
# Episode: 130, Score: 165.77, Max: 170.91, Min: 37.69, T-max: 1000
# *** Episode 130 	 Average Score (over agents): 165.77 	 Average Score on 100 Episode: 106.46, Time: 00:22:02***
# Episode: 131, Score: 171.19, Max: 171.19, Min: 37.69, T-max: 1000
# Episode: 132, Score: 176.20, Max: 176.20, Min: 37.69, T-max: 1000
# Episode: 133, Score: 169.21, Max: 176.20, Min: 37.69, T-max: 1000
# Episode: 134, Score: 174.82, Max: 176.20, Min: 37.69, T-max: 1000
# Episode: 135, Score: 186.05, Max: 186.05, Min: 37.69, T-max: 1000
# Episode: 136, Score: 175.09, Max: 186.05, Min: 37.69, T-max: 1000
# Episode: 137, Score: 185.77, Max: 186.05, Min: 37.69, T-max: 1000
# Episode: 138, Score: 173.45, Max: 186.05, Min: 37.69, T-max: 1000
# Episode: 139, Score: 198.68, Max: 198.68, Min: 37.69, T-max: 1000
# Episode: 140, Score: 192.66, Max: 198.68, Min: 37.69, T-max: 1000
# *** Episode 140 	 Average Score (over agents): 192.66 	 Average Score on 100 Episode: 117.94, Time: 00:23:49***
# Episode: 141, Score: 180.49, Max: 198.68, Min: 37.69, T-max: 1000
# Episode: 142, Score: 202.62, Max: 202.62, Min: 37.69, T-max: 1000
# Episode: 143, Score: 177.72, Max: 202.62, Min: 37.69, T-max: 1000
# Episode: 144, Score: 184.46, Max: 202.62, Min: 37.69, T-max: 1000
# Episode: 145, Score: 197.07, Max: 202.62, Min: 37.69, T-max: 1000
# Episode: 146, Score: 196.18, Max: 202.62, Min: 37.69, T-max: 1000
# Episode: 147, Score: 201.33, Max: 202.62, Min: 37.69, T-max: 1000
# Episode: 148, Score: 181.63, Max: 202.62, Min: 37.69, T-max: 1000
# Episode: 149, Score: 193.35, Max: 202.62, Min: 37.69, T-max: 1000
# Episode: 150, Score: 198.98, Max: 202.62, Min: 37.69, T-max: 1000
# *** Episode 150 	 Average Score (over agents): 198.98 	 Average Score on 100 Episode: 130.09, Time: 00:25:36***
# Episode: 151, Score: 189.64, Max: 202.62, Min: 37.69, T-max: 1000
# Episode: 152, Score: 200.95, Max: 202.62, Min: 37.69, T-max: 1000
# Episode: 153, Score: 211.54, Max: 211.54, Min: 37.69, T-max: 1000
# Episode: 154, Score: 209.75, Max: 211.54, Min: 37.69, T-max: 1000
# Episode: 155, Score: 210.47, Max: 211.54, Min: 37.69, T-max: 1000
# Episode: 156, Score: 204.99, Max: 211.54, Min: 37.69, T-max: 1000
# Episode: 157, Score: 221.09, Max: 221.09, Min: 37.69, T-max: 1000
# Episode: 158, Score: 222.59, Max: 222.59, Min: 37.69, T-max: 1000
# Episode: 159, Score: 214.66, Max: 222.59, Min: 37.69, T-max: 1000
# Episode: 160, Score: 211.06, Max: 222.59, Min: 37.69, T-max: 1000
# *** Episode 160 	 Average Score (over agents): 211.06 	 Average Score on 100 Episode: 143.37, Time: 00:27:21***
# Episode: 161, Score: 208.82, Max: 222.59, Min: 37.69, T-max: 1000
# Episode: 162, Score: 203.49, Max: 222.59, Min: 37.69, T-max: 1000
# Episode: 163, Score: 226.81, Max: 226.81, Min: 37.69, T-max: 1000
# Episode: 164, Score: 221.91, Max: 226.81, Min: 37.69, T-max: 1000
# Episode: 165, Score: 226.79, Max: 226.81, Min: 37.69, T-max: 1000
# Episode: 166, Score: 228.49, Max: 228.49, Min: 37.69, T-max: 1000
# Episode: 167, Score: 220.90, Max: 228.49, Min: 37.69, T-max: 1000
# Episode: 168, Score: 218.26, Max: 228.49, Min: 37.69, T-max: 1000
# Episode: 169, Score: 244.92, Max: 244.92, Min: 37.69, T-max: 1000
# Episode: 170, Score: 241.93, Max: 244.92, Min: 37.69, T-max: 1000
# *** Episode 170 	 Average Score (over agents): 241.93 	 Average Score on 100 Episode: 157.12, Time: 00:29:07***
# Episode: 171, Score: 238.27, Max: 244.92, Min: 37.69, T-max: 1000
# Episode: 172, Score: 238.74, Max: 244.92, Min: 37.69, T-max: 1000
# Episode: 173, Score: 250.41, Max: 250.41, Min: 37.69, T-max: 1000
# Episode: 174, Score: 255.24, Max: 255.24, Min: 37.69, T-max: 1000
# Episode: 175, Score: 237.80, Max: 255.24, Min: 37.69, T-max: 1000
# Episode: 176, Score: 246.89, Max: 255.24, Min: 37.69, T-max: 1000
# Episode: 177, Score: 240.82, Max: 255.24, Min: 37.69, T-max: 1000
# Episode: 178, Score: 265.63, Max: 265.63, Min: 37.69, T-max: 1000
# Episode: 179, Score: 236.28, Max: 265.63, Min: 37.69, T-max: 1000
# Episode: 180, Score: 244.68, Max: 265.63, Min: 37.69, T-max: 1000
# *** Episode 180 	 Average Score (over agents): 244.68 	 Average Score on 100 Episode: 171.84, Time: 00:30:41***
# Episode: 181, Score: 273.77, Max: 273.77, Min: 37.69, T-max: 1000
# Episode: 182, Score: 258.38, Max: 273.77, Min: 37.69, T-max: 1000
# Episode: 183, Score: 274.05, Max: 274.05, Min: 37.69, T-max: 1000
# Episode: 184, Score: 267.74, Max: 274.05, Min: 37.69, T-max: 1000
# Episode: 185, Score: 261.11, Max: 274.05, Min: 37.69, T-max: 1000
# Episode: 186, Score: 258.75, Max: 274.05, Min: 37.69, T-max: 1000
# Episode: 187, Score: 284.09, Max: 284.09, Min: 37.69, T-max: 1000
# Episode: 188, Score: 284.25, Max: 284.25, Min: 37.69, T-max: 1000
# Episode: 189, Score: 308.08, Max: 308.08, Min: 37.69, T-max: 1000
# Episode: 190, Score: 292.19, Max: 308.08, Min: 37.69, T-max: 1000
# *** Episode 190 	 Average Score (over agents): 292.19 	 Average Score on 100 Episode: 188.81, Time: 00:32:02***
# Episode: 191, Score: 270.42, Max: 308.08, Min: 37.69, T-max: 1000
# Episode: 192, Score: 295.52, Max: 308.08, Min: 37.69, T-max: 1000
# Episode: 193, Score: 306.88, Max: 308.08, Min: 37.69, T-max: 1000
# Episode: 194, Score: 286.32, Max: 308.08, Min: 37.69, T-max: 1000
# Episode: 195, Score: 278.36, Max: 308.08, Min: 37.69, T-max: 1000
# Episode: 196, Score: 298.01, Max: 308.08, Min: 37.69, T-max: 1000
# Episode: 197, Score: 298.41, Max: 308.08, Min: 37.69, T-max: 1000
# Episode: 198, Score: 320.01, Max: 320.01, Min: 37.69, T-max: 1000
# Episode: 199, Score: 309.76, Max: 320.01, Min: 37.69, T-max: 1000
# Episode: 200, Score: 312.83, Max: 320.01, Min: 37.69, T-max: 1000
# *** Episode 200 	 Average Score (over agents): 312.83 	 Average Score on 100 Episode: 206.47, Time: 00:33:37***
# Episode: 201, Score: 314.75, Max: 320.01, Min: 37.69, T-max: 1000
# Episode: 202, Score: 321.49, Max: 321.49, Min: 37.69, T-max: 1000
# Episode: 203, Score: 305.93, Max: 321.49, Min: 37.69, T-max: 1000
# Episode: 204, Score: 323.06, Max: 323.06, Min: 37.69, T-max: 1000
# Episode: 205, Score: 327.97, Max: 327.97, Min: 37.69, T-max: 1000
# Episode: 206, Score: 326.61, Max: 327.97, Min: 37.69, T-max: 1000
# Episode: 207, Score: 315.28, Max: 327.97, Min: 37.69, T-max: 1000
# Episode: 208, Score: 350.52, Max: 350.52, Min: 37.69, T-max: 1000
# Episode: 209, Score: 334.20, Max: 350.52, Min: 37.69, T-max: 1000
# Episode: 210, Score: 339.72, Max: 350.52, Min: 37.69, T-max: 1000
# *** Episode 210 	 Average Score (over agents): 339.72 	 Average Score on 100 Episode: 225.92, Time: 00:35:20***
# Episode: 211, Score: 337.24, Max: 350.52, Min: 37.69, T-max: 1000
# Episode: 212, Score: 333.09, Max: 350.52, Min: 37.69, T-max: 1000
# Episode: 213, Score: 324.21, Max: 350.52, Min: 37.69, T-max: 1000
# Episode: 214, Score: 370.77, Max: 370.77, Min: 37.69, T-max: 1000
# Episode: 215, Score: 362.59, Max: 370.77, Min: 37.69, T-max: 1000
# Episode: 216, Score: 369.92, Max: 370.77, Min: 37.69, T-max: 1000
# Episode: 217, Score: 376.27, Max: 376.27, Min: 37.69, T-max: 1000
# Episode: 218, Score: 332.44, Max: 376.27, Min: 37.69, T-max: 1000
# Episode: 219, Score: 369.70, Max: 376.27, Min: 37.69, T-max: 1000
# Episode: 220, Score: 383.67, Max: 383.67, Min: 37.69, T-max: 1000
# *** Episode 220 	 Average Score (over agents): 383.67 	 Average Score on 100 Episode: 246.93, Time: 00:37:01***
# Episode: 221, Score: 384.25, Max: 384.25, Min: 37.69, T-max: 1000
# Episode: 222, Score: 373.33, Max: 384.25, Min: 37.69, T-max: 1000
# Episode: 223, Score: 379.78, Max: 384.25, Min: 37.69, T-max: 1000
# Episode: 224, Score: 387.36, Max: 387.36, Min: 37.69, T-max: 1000
# Episode: 225, Score: 377.56, Max: 387.36, Min: 37.69, T-max: 1000
# Episode: 226, Score: 391.48, Max: 391.48, Min: 37.69, T-max: 1000
# Episode: 227, Score: 361.99, Max: 391.48, Min: 37.69, T-max: 1000
# Episode: 228, Score: 395.29, Max: 395.29, Min: 37.69, T-max: 1000
# Episode: 229, Score: 403.41, Max: 403.41, Min: 37.69, T-max: 1000
# Episode: 230, Score: 395.54, Max: 403.41, Min: 37.69, T-max: 1000
# *** Episode 230 	 Average Score (over agents): 395.54 	 Average Score on 100 Episode: 269.19, Time: 00:38:31***
# Episode: 231, Score: 387.73, Max: 403.41, Min: 37.69, T-max: 1000
# Episode: 232, Score: 414.63, Max: 414.63, Min: 37.69, T-max: 1000
# Episode: 233, Score: 408.48, Max: 414.63, Min: 37.69, T-max: 1000
# Episode: 234, Score: 412.57, Max: 414.63, Min: 37.69, T-max: 1000
# Episode: 235, Score: 406.51, Max: 414.63, Min: 37.69, T-max: 1000
# Episode: 236, Score: 416.94, Max: 416.94, Min: 37.69, T-max: 1000
# Episode: 237, Score: 412.58, Max: 416.94, Min: 37.69, T-max: 1000
# Episode: 238, Score: 411.85, Max: 416.94, Min: 37.69, T-max: 1000
# Episode: 239, Score: 418.82, Max: 418.82, Min: 37.69, T-max: 1000
# Episode: 240, Score: 418.44, Max: 418.82, Min: 37.69, T-max: 1000
# *** Episode 240 	 Average Score (over agents): 418.44 	 Average Score on 100 Episode: 292.25, Time: 00:39:51***
# Episode: 241, Score: 432.81, Max: 432.81, Min: 37.69, T-max: 1000
# Episode: 242, Score: 422.71, Max: 432.81, Min: 37.69, T-max: 1000
# Episode: 243, Score: 393.57, Max: 432.81, Min: 37.69, T-max: 1000
# Episode: 244, Score: 435.24, Max: 435.24, Min: 37.69, T-max: 1000
# Episode: 245, Score: 434.89, Max: 435.24, Min: 37.69, T-max: 1000
# Episode: 246, Score: 432.45, Max: 435.24, Min: 37.69, T-max: 1000
# Episode: 247, Score: 449.52, Max: 449.52, Min: 37.69, T-max: 1000
# Episode: 248, Score: 449.01, Max: 449.52, Min: 37.69, T-max: 1000
# Episode: 249, Score: 440.34, Max: 449.52, Min: 37.69, T-max: 1000
# Episode: 250, Score: 449.25, Max: 449.52, Min: 37.69, T-max: 1000
# *** Episode 250 	 Average Score (over agents): 449.25 	 Average Score on 100 Episode: 316.51, Time: 00:41:36***
# Episode: 251, Score: 456.29, Max: 456.29, Min: 37.69, T-max: 1000
# Episode: 252, Score: 418.82, Max: 456.29, Min: 37.69, T-max: 1000
# Episode: 253, Score: 462.59, Max: 462.59, Min: 37.69, T-max: 1000
# Episode: 254, Score: 460.07, Max: 462.59, Min: 37.69, T-max: 1000
# Episode: 255, Score: 469.55, Max: 469.55, Min: 37.69, T-max: 1000
# Episode: 256, Score: 462.82, Max: 469.55, Min: 37.69, T-max: 1000
# Episode: 257, Score: 446.94, Max: 469.55, Min: 37.69, T-max: 1000
# Episode: 258, Score: 465.68, Max: 469.55, Min: 37.69, T-max: 1000
# Episode: 259, Score: 479.69, Max: 479.69, Min: 37.69, T-max: 1000
# Episode: 260, Score: 480.78, Max: 480.78, Min: 37.69, T-max: 1000
# *** Episode 260 	 Average Score (over agents): 480.78 	 Average Score on 100 Episode: 341.57, Time: 00:43:22***
# Episode: 261, Score: 464.07, Max: 480.78, Min: 37.69, T-max: 1000
# Episode: 262, Score: 483.68, Max: 483.68, Min: 37.69, T-max: 1000
# Episode: 263, Score: 898.46, Max: 898.46, Min: 37.69, T-max: 1999
# Episode: 264, Score: 481.83, Max: 898.46, Min: 37.69, T-max: 1000
# Episode: 265, Score: 487.57, Max: 898.46, Min: 37.69, T-max: 1000
# Episode: 266, Score: 485.54, Max: 898.46, Min: 37.69, T-max: 1000
# Episode: 267, Score: 499.31, Max: 898.46, Min: 37.69, T-max: 1000
# Episode: 268, Score: 497.95, Max: 898.46, Min: 37.69, T-max: 1000
# Episode: 269, Score: 495.91, Max: 898.46, Min: 37.69, T-max: 1000
# Episode: 270, Score: 499.17, Max: 898.46, Min: 37.69, T-max: 1000
# *** Episode 270 	 Average Score (over agents): 499.17 	 Average Score on 100 Episode: 372.08, Time: 00:45:17***
# Episode: 271, Score: 493.90, Max: 898.46, Min: 37.69, T-max: 1000
# Episode: 272, Score: 494.18, Max: 898.46, Min: 37.69, T-max: 1000
# Episode: 273, Score: 472.14, Max: 898.46, Min: 37.69, T-max: 1000
# Episode: 274, Score: 493.06, Max: 898.46, Min: 37.69, T-max: 1000
# Episode: 275, Score: 499.89, Max: 898.46, Min: 37.69, T-max: 1000
# Episode: 276, Score: 491.02, Max: 898.46, Min: 37.69, T-max: 1000
# Episode: 277, Score: 507.89, Max: 898.46, Min: 37.69, T-max: 1000
# Episode: 278, Score: 1008.59, Max: 1008.59, Min: 37.69, T-max: 1999
# Episode: 279, Score: 515.85, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 280, Score: 510.20, Max: 1008.59, Min: 37.69, T-max: 1000
# *** Episode 280 	 Average Score (over agents): 510.20 	 Average Score on 100 Episode: 402.40, Time: 00:47:12***
# Episode: 281, Score: 516.09, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 282, Score: 494.51, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 283, Score: 519.50, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 284, Score: 525.13, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 285, Score: 521.78, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 286, Score: 519.90, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 287, Score: 518.30, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 288, Score: 514.45, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 289, Score: 505.36, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 290, Score: 527.39, Max: 1008.59, Min: 37.69, T-max: 1000
# *** Episode 290 	 Average Score (over agents): 527.39 	 Average Score on 100 Episode: 426.40, Time: 00:48:57***
# Episode: 291, Score: 531.36, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 292, Score: 530.38, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 293, Score: 530.64, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 294, Score: 541.64, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 295, Score: 534.45, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 296, Score: 540.37, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 297, Score: 545.87, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 298, Score: 551.09, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 299, Score: 550.01, Max: 1008.59, Min: 37.69, T-max: 1000
# Episode: 300, Score: 551.43, Max: 1008.59, Min: 37.69, T-max: 1000
# *** Episode 300 	 Average Score (over agents): 551.43 	 Average Score on 100 Episode: 450.71, Time: 00:50:42***
# Episode: 301, Score: 1097.63, Max: 1097.63, Min: 37.69, T-max: 1999
# Episode: 302, Score: 1104.90, Max: 1104.90, Min: 37.69, T-max: 1999
# Episode: 303, Score: 559.62, Max: 1104.90, Min: 37.69, T-max: 1000
# Episode: 304, Score: 561.36, Max: 1104.90, Min: 37.69, T-max: 1000
# Episode: 305, Score: 566.31, Max: 1104.90, Min: 37.69, T-max: 1000
# Episode: 306, Score: 1136.68, Max: 1136.68, Min: 37.69, T-max: 1999
# Episode: 307, Score: 569.96, Max: 1136.68, Min: 37.69, T-max: 1000
# Episode: 308, Score: 566.88, Max: 1136.68, Min: 37.69, T-max: 1000
# Episode: 309, Score: 574.13, Max: 1136.68, Min: 37.69, T-max: 1000
# Episode: 310, Score: 559.61, Max: 1136.68, Min: 37.69, T-max: 1000
# *** Episode 310 	 Average Score (over agents): 559.61 	 Average Score on 100 Episode: 491.08, Time: 00:52:57***
# Episode: 311, Score: 567.92, Max: 1136.68, Min: 37.69, T-max: 1000
# Episode: 312, Score: 561.67, Max: 1136.68, Min: 37.69, T-max: 1000
# Episode: 313, Score: 1137.86, Max: 1137.86, Min: 37.69, T-max: 1999
# Episode: 314, Score: 1148.78, Max: 1148.78, Min: 37.69, T-max: 1999
# Episode: 315, Score: 575.72, Max: 1148.78, Min: 37.69, T-max: 1000
# Episode: 316, Score: 580.40, Max: 1148.78, Min: 37.69, T-max: 1000
# Episode: 317, Score: 1160.59, Max: 1160.59, Min: 37.69, T-max: 1999
# Episode: 318, Score: 589.63, Max: 1160.59, Min: 37.69, T-max: 1000
# Episode: 319, Score: 586.95, Max: 1160.59, Min: 37.69, T-max: 1000
# Episode: 320, Score: 1160.32, Max: 1160.59, Min: 37.69, T-max: 1999
# *** Episode 320 	 Average Score (over agents): 1160.32 	 Average Score on 100 Episode: 536.18, Time: 00:55:21***
# Episode: 321, Score: 1175.80, Max: 1175.80, Min: 37.69, T-max: 1999
# Episode: 322, Score: 1162.97, Max: 1175.80, Min: 37.69, T-max: 1999
# Episode: 323, Score: 1175.55, Max: 1175.80, Min: 37.69, T-max: 1999
# Episode: 324, Score: 1193.86, Max: 1193.86, Min: 37.69, T-max: 1999
# Episode: 325, Score: 609.90, Max: 1193.86, Min: 37.69, T-max: 1000
# Episode: 326, Score: 604.49, Max: 1193.86, Min: 37.69, T-max: 1000
# Episode: 327, Score: 1197.51, Max: 1197.51, Min: 37.69, T-max: 1999
# Episode: 328, Score: 609.59, Max: 1197.51, Min: 37.69, T-max: 1000
# Episode: 329, Score: 1175.27, Max: 1197.51, Min: 37.69, T-max: 1999
# Episode: 330, Score: 1210.26, Max: 1210.26, Min: 37.69, T-max: 1999
# *** Episode 330 	 Average Score (over agents): 1210.26 	 Average Score on 100 Episode: 598.84, Time: 00:58:15***
# Episode: 331, Score: 599.90, Max: 1210.26, Min: 37.69, T-max: 1000
# Episode: 332, Score: 613.01, Max: 1210.26, Min: 37.69, T-max: 1000
# Episode: 333, Score: 615.17, Max: 1210.26, Min: 37.69, T-max: 1000
# Episode: 334, Score: 1231.03, Max: 1231.03, Min: 37.69, T-max: 1999
# Episode: 335, Score: 1251.97, Max: 1251.97, Min: 37.69, T-max: 1999
# Episode: 336, Score: 619.78, Max: 1251.97, Min: 37.69, T-max: 1000
# Episode: 337, Score: 628.80, Max: 1251.97, Min: 37.69, T-max: 1000
# Episode: 338, Score: 624.51, Max: 1251.97, Min: 37.69, T-max: 1000
# Episode: 339, Score: 1201.44, Max: 1251.97, Min: 37.69, T-max: 1999
# Episode: 340, Score: 634.95, Max: 1251.97, Min: 37.69, T-max: 1000
# *** Episode 340 	 Average Score (over agents): 634.95 	 Average Score on 100 Episode: 637.96, Time: 01:00:31***
# Episode: 341, Score: 642.22, Max: 1251.97, Min: 37.69, T-max: 1000
# Episode: 342, Score: 1266.81, Max: 1266.81, Min: 37.69, T-max: 1999
# Episode: 343, Score: 632.21, Max: 1266.81, Min: 37.69, T-max: 1000
# Episode: 344, Score: 1261.40, Max: 1266.81, Min: 37.69, T-max: 1999
# Episode: 345, Score: 1216.87, Max: 1266.81, Min: 37.69, T-max: 1999
# Episode: 346, Score: 640.60, Max: 1266.81, Min: 37.69, T-max: 1000
# Episode: 347, Score: 1270.40, Max: 1270.40, Min: 37.69, T-max: 1999
# Episode: 348, Score: 1274.27, Max: 1274.27, Min: 37.69, T-max: 1999
# Episode: 349, Score: 1271.91, Max: 1274.27, Min: 37.69, T-max: 1999
# Episode: 350, Score: 1272.97, Max: 1274.27, Min: 37.69, T-max: 1999
# *** Episode 350 	 Average Score (over agents): 1272.97 	 Average Score on 100 Episode: 702.05, Time: 01:03:35***
# Episode: 351, Score: 1246.61, Max: 1274.27, Min: 37.69, T-max: 1999
# Episode: 352, Score: 1299.48, Max: 1299.48, Min: 37.69, T-max: 1999
# Episode: 353, Score: 1300.93, Max: 1300.93, Min: 37.69, T-max: 1999
# Episode: 354, Score: 1289.89, Max: 1300.93, Min: 37.69, T-max: 1999
# Episode: 355, Score: 1294.29, Max: 1300.93, Min: 37.69, T-max: 1999
# Episode: 356, Score: 1300.08, Max: 1300.93, Min: 37.69, T-max: 1999
# Episode: 357, Score: 1296.20, Max: 1300.93, Min: 37.69, T-max: 1999
# Episode: 358, Score: 1284.14, Max: 1300.93, Min: 37.69, T-max: 1999
# Episode: 359, Score: 1287.07, Max: 1300.93, Min: 37.69, T-max: 1999
# Episode: 360, Score: 1290.18, Max: 1300.93, Min: 37.69, T-max: 1999
# *** Episode 360 	 Average Score (over agents): 1290.18 	 Average Score on 100 Episode: 784.91, Time: 01:07:40***
# Episode: 361, Score: 1310.05, Max: 1310.05, Min: 37.69, T-max: 1999
# Episode: 362, Score: 652.18, Max: 1310.05, Min: 37.69, T-max: 1000
# Episode: 363, Score: 657.88, Max: 1310.05, Min: 37.69, T-max: 1000
# Episode: 364, Score: 1304.74, Max: 1310.05, Min: 37.69, T-max: 1999
#
#  End of PPO!

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %%
env.close()
