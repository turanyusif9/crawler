# %% [markdown]
# # Continuous Control
#
# ---
#
# Congratulations for completing the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program!  In this notebook, you will learn how to control an agent in a more challenging environment, where the goal is to train a creature with four arms to walk forward.  **Note that this exercise is optional!**
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Crawler.app"`
# - **Windows** (x86): `"path/to/Crawler_Windows_x86/Crawler.exe"`
# - **Windows** (x86_64): `"path/to/Crawler_Windows_x86_64/Crawler.exe"`
# - **Linux** (x86): `"path/to/Crawler_Linux/Crawler.x86"`
# - **Linux** (x86_64): `"path/to/Crawler_Linux/Crawler.x86_64"`
# - **Linux** (x86, headless): `"path/to/Crawler_Linux_NoVis/Crawler.x86"`
# - **Linux** (x86_64, headless): `"path/to/Crawler_Linux_NoVis/Crawler.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Crawler.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Crawler.app")
# ```

# %%
env = UnityEnvironment(file_name='C:/Users/Turan/Desktop/drl project/deep-reinforcement-learning/p2_continuous-control/Crawler_Windows_x86_64/Crawler.exe')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: CrawlerBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 129
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 20
#         Vector Action descriptions: , , , , , , , , , , , , , , , , , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 12
# Size of each action: 20
# There are 12 agents. Each observes a state with length: 129
# The state for the first agent looks like: [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  2.25000000e+00
#   1.00000000e+00  0.00000000e+00  1.78813934e-07  0.00000000e+00
#   1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093168e-01 -1.42857209e-01 -6.06078804e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339906e+00 -1.42857209e-01
#  -1.33341408e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093347e-01 -1.42857209e-01 -6.06078625e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339953e+00 -1.42857209e-01
#  -1.33341372e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093168e-01 -1.42857209e-01  6.06078804e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339906e+00 -1.42857209e-01
#   1.33341408e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093347e-01 -1.42857209e-01  6.06078625e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339953e+00 -1.42857209e-01
#   1.33341372e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
#env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
#states = env_info.vector_observations                  # get the current state (for each agent)
#scores = np.zeros(num_agents)                          # initialize the score (for each agent)
#while True:
#    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
#    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
#    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#    next_states = env_info.vector_observations         # get next state (for each agent)
#    rewards = env_info.rewards                         # get reward (for each agent)
#    dones = env_info.local_done                        # see if episode finished
#    scores += env_info.rewards                         # update the score (for each agent)
#    states = next_states                               # roll over states to next time step
#    if np.any(dones):                                  # exit loop if episode finished
#        break
#print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
#env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
from  collections  import deque
from itertools import count
import torch
import time
#from ddpg_agent import Agent
from ppo_agent_combined import Agent
import matplotlib.pyplot as plt
# %matplotlib inline
env_info = env.reset(train_mode=True)[brain_name]
agent = Agent(state_size=state_size, action_size=action_size, random_seed=8, n_agent=num_agents, \
              fc1_units=128, fc2_units=128)

print("Smoothness used:", agent.USE_SMOOTHNESS)
print("Symmetry used:", agent.USE_SYMMETRY)
print("Magnitude used:", agent.USE_MAGNITUDE)
# Out:
# Smoothness used: True
# Symmetry used: False
# Magnitude used: False

# %%
def ppo(env, agent, n_episodes=500, print_every=10, n_agent = 12):
    """
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        print_every (int): number of episodes to print result
        n_agent (int): number of identical agents in environment
    """
    scores_deque = deque(maxlen=100)
    scores_global = []    
    scores = []
    max_t = 2000
        
    time_start = time.time()
    
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        states = env_info.vector_observations
        agent_scores = np.zeros(n_agent)
        t_max = 0
        for t in range(max_t):
            actions, log_probs, _, values = agent.act(states)
            # get needed information from environment
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations
            rewards = env_info.rewards
            dones = np.array([1 if t else 0 for t in env_info.local_done])
            agent.save_step([states, values.detach(), actions, log_probs.detach(), rewards, 1 - dones])
            states = next_states
            agent_scores += rewards
            t_max = t
            if all(dones) or t == max_t-1:
                agent.step(next_states)
                break
                
        score = np.mean(agent_scores)
        scores_deque.append(score)
        scores.append(score)

        print('Episode: {}, Score: {:.2f}, Max: {:.2f}, Min: {:.2f}, T-max: {}   '\
              .format(i_episode, score, np.max(scores), np.min(scores), t_max))
        
        if i_episode % print_every == 0:
            torch.save(agent.actor_critic.actor.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.actor_critic.critic.state_dict(), 'checkpoint_critic.pth')
            s = (int)(time.time() - time_start) 
            print('*** Episode {} \t Average Score (over agents): {:.2f} \t Average Score on 100 Episode: {:.2f}, Time: {:02}:{:02}:{:02}***'\
                  .format(i_episode, score, np.mean(scores_deque), s//3600, s%3600//60, s%60))
            
        if len(scores_deque) == 100 and np.mean(scores_deque) >= 800: # 650: # 500:   
            break


    print('\n End of PPO!')
    return scores

scores = ppo(env=env, agent=agent)
# Out:
# c:\Users\Turan\miniconda3\envs\drlnd\lib\site-packages\torch\nn\functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Episode: 1, Score: 47.94, Max: 47.94, Min: 47.94, T-max: 1000
# Episode: 2, Score: 49.67, Max: 49.67, Min: 47.94, T-max: 1000
# Episode: 3, Score: 43.91, Max: 49.67, Min: 43.91, T-max: 1000
# Episode: 4, Score: 48.56, Max: 49.67, Min: 43.91, T-max: 1000
# Episode: 5, Score: 37.55, Max: 49.67, Min: 37.55, T-max: 1000
# Episode: 6, Score: 45.87, Max: 49.67, Min: 37.55, T-max: 1000
# Episode: 7, Score: 51.17, Max: 51.17, Min: 37.55, T-max: 1000
# Episode: 8, Score: 49.41, Max: 51.17, Min: 37.55, T-max: 1000
# Episode: 9, Score: 49.55, Max: 51.17, Min: 37.55, T-max: 1000
# Episode: 10, Score: 50.04, Max: 51.17, Min: 37.55, T-max: 1000
# *** Episode 10 	 Average Score (over agents): 50.04 	 Average Score on 100 Episode: 47.37, Time: 00:01:05***
# Episode: 11, Score: 45.38, Max: 51.17, Min: 37.55, T-max: 1000
# Episode: 12, Score: 45.09, Max: 51.17, Min: 37.55, T-max: 1000
# Episode: 13, Score: 53.69, Max: 53.69, Min: 37.55, T-max: 1000
# Episode: 14, Score: 47.86, Max: 53.69, Min: 37.55, T-max: 1000
# Episode: 15, Score: 50.39, Max: 53.69, Min: 37.55, T-max: 1000
# Episode: 16, Score: 52.34, Max: 53.69, Min: 37.55, T-max: 1000
# Episode: 17, Score: 55.26, Max: 55.26, Min: 37.55, T-max: 1000
# Episode: 18, Score: 55.17, Max: 55.26, Min: 37.55, T-max: 1000
# Episode: 19, Score: 55.85, Max: 55.85, Min: 37.55, T-max: 1000
# Episode: 20, Score: 55.79, Max: 55.85, Min: 37.55, T-max: 1000
# *** Episode 20 	 Average Score (over agents): 55.79 	 Average Score on 100 Episode: 49.53, Time: 00:02:14***
# Episode: 21, Score: 56.41, Max: 56.41, Min: 37.55, T-max: 1000
# Episode: 22, Score: 55.56, Max: 56.41, Min: 37.55, T-max: 1000
# Episode: 23, Score: 55.31, Max: 56.41, Min: 37.55, T-max: 1000
# Episode: 24, Score: 53.45, Max: 56.41, Min: 37.55, T-max: 1000
# Episode: 25, Score: 52.98, Max: 56.41, Min: 37.55, T-max: 1000
# Episode: 26, Score: 57.79, Max: 57.79, Min: 37.55, T-max: 1000
# Episode: 27, Score: 58.42, Max: 58.42, Min: 37.55, T-max: 1000
# Episode: 28, Score: 61.56, Max: 61.56, Min: 37.55, T-max: 1000
# Episode: 29, Score: 59.24, Max: 61.56, Min: 37.55, T-max: 1000
# Episode: 30, Score: 60.73, Max: 61.56, Min: 37.55, T-max: 1000
# *** Episode 30 	 Average Score (over agents): 60.73 	 Average Score on 100 Episode: 52.07, Time: 00:03:21***
# Episode: 31, Score: 63.07, Max: 63.07, Min: 37.55, T-max: 1000
# Episode: 32, Score: 57.96, Max: 63.07, Min: 37.55, T-max: 1000
# Episode: 33, Score: 62.01, Max: 63.07, Min: 37.55, T-max: 1000
# Episode: 34, Score: 61.69, Max: 63.07, Min: 37.55, T-max: 1000
# Episode: 35, Score: 63.30, Max: 63.30, Min: 37.55, T-max: 1000
# Episode: 36, Score: 65.51, Max: 65.51, Min: 37.55, T-max: 1000
# Episode: 37, Score: 66.96, Max: 66.96, Min: 37.55, T-max: 1000
# Episode: 38, Score: 64.24, Max: 66.96, Min: 37.55, T-max: 1000
# Episode: 39, Score: 67.58, Max: 67.58, Min: 37.55, T-max: 1000
# Episode: 40, Score: 63.06, Max: 67.58, Min: 37.55, T-max: 1000
# *** Episode 40 	 Average Score (over agents): 63.06 	 Average Score on 100 Episode: 54.93, Time: 00:04:28***
# Episode: 41, Score: 63.57, Max: 67.58, Min: 37.55, T-max: 1000
# Episode: 42, Score: 65.30, Max: 67.58, Min: 37.55, T-max: 1000
# Episode: 43, Score: 67.35, Max: 67.58, Min: 37.55, T-max: 1000
# Episode: 44, Score: 64.51, Max: 67.58, Min: 37.55, T-max: 1000
# Episode: 45, Score: 67.08, Max: 67.58, Min: 37.55, T-max: 1000
# Episode: 46, Score: 68.02, Max: 68.02, Min: 37.55, T-max: 1000
# Episode: 47, Score: 70.54, Max: 70.54, Min: 37.55, T-max: 1000
# Episode: 48, Score: 63.64, Max: 70.54, Min: 37.55, T-max: 1000
# Episode: 49, Score: 68.53, Max: 70.54, Min: 37.55, T-max: 1000
# Episode: 50, Score: 67.79, Max: 70.54, Min: 37.55, T-max: 1000
# *** Episode 50 	 Average Score (over agents): 67.79 	 Average Score on 100 Episode: 57.27, Time: 00:05:36***
# Episode: 51, Score: 72.93, Max: 72.93, Min: 37.55, T-max: 1000
# Episode: 52, Score: 71.86, Max: 72.93, Min: 37.55, T-max: 1000
# Episode: 53, Score: 63.69, Max: 72.93, Min: 37.55, T-max: 1000
# Episode: 54, Score: 59.67, Max: 72.93, Min: 37.55, T-max: 1000
# Episode: 55, Score: 69.68, Max: 72.93, Min: 37.55, T-max: 1000
# Episode: 56, Score: 74.13, Max: 74.13, Min: 37.55, T-max: 1000
# Episode: 57, Score: 72.40, Max: 74.13, Min: 37.55, T-max: 1000
# Episode: 58, Score: 75.68, Max: 75.68, Min: 37.55, T-max: 1000
# Episode: 59, Score: 71.21, Max: 75.68, Min: 37.55, T-max: 1000
# Episode: 60, Score: 72.72, Max: 75.68, Min: 37.55, T-max: 1000
# *** Episode 60 	 Average Score (over agents): 72.72 	 Average Score on 100 Episode: 59.46, Time: 00:14:18***
# Episode: 61, Score: 81.92, Max: 81.92, Min: 37.55, T-max: 1000
# Episode: 62, Score: 74.20, Max: 81.92, Min: 37.55, T-max: 1000
# Episode: 63, Score: 80.56, Max: 81.92, Min: 37.55, T-max: 1000
# Episode: 64, Score: 75.49, Max: 81.92, Min: 37.55, T-max: 1000
# Episode: 65, Score: 74.37, Max: 81.92, Min: 37.55, T-max: 1000
# Episode: 66, Score: 79.42, Max: 81.92, Min: 37.55, T-max: 1000
# Episode: 67, Score: 81.77, Max: 81.92, Min: 37.55, T-max: 1000
# Episode: 68, Score: 75.65, Max: 81.92, Min: 37.55, T-max: 1000
# Episode: 69, Score: 73.87, Max: 81.92, Min: 37.55, T-max: 1000
# Episode: 70, Score: 81.92, Max: 81.92, Min: 37.55, T-max: 1000
# *** Episode 70 	 Average Score (over agents): 81.92 	 Average Score on 100 Episode: 62.10, Time: 00:15:41***
# Episode: 71, Score: 86.52, Max: 86.52, Min: 37.55, T-max: 1000
# Episode: 72, Score: 82.12, Max: 86.52, Min: 37.55, T-max: 1000
# Episode: 73, Score: 77.52, Max: 86.52, Min: 37.55, T-max: 1000
# Episode: 74, Score: 90.23, Max: 90.23, Min: 37.55, T-max: 1000
# Episode: 75, Score: 79.64, Max: 90.23, Min: 37.55, T-max: 1000
# Episode: 76, Score: 84.99, Max: 90.23, Min: 37.55, T-max: 1000
# Episode: 77, Score: 85.27, Max: 90.23, Min: 37.55, T-max: 1000
# Episode: 78, Score: 86.65, Max: 90.23, Min: 37.55, T-max: 1000
# Episode: 79, Score: 96.72, Max: 96.72, Min: 37.55, T-max: 1000
# Episode: 80, Score: 98.74, Max: 98.74, Min: 37.55, T-max: 1000
# *** Episode 80 	 Average Score (over agents): 98.74 	 Average Score on 100 Episode: 65.19, Time: 00:17:05***
# Episode: 81, Score: 87.35, Max: 98.74, Min: 37.55, T-max: 1000
# Episode: 82, Score: 103.32, Max: 103.32, Min: 37.55, T-max: 1000
# Episode: 83, Score: 87.37, Max: 103.32, Min: 37.55, T-max: 1000
# Episode: 84, Score: 90.27, Max: 103.32, Min: 37.55, T-max: 1000
# Episode: 85, Score: 97.62, Max: 103.32, Min: 37.55, T-max: 1000
# Episode: 86, Score: 91.02, Max: 103.32, Min: 37.55, T-max: 1000
# Episode: 87, Score: 94.17, Max: 103.32, Min: 37.55, T-max: 1000
# Episode: 88, Score: 86.21, Max: 103.32, Min: 37.55, T-max: 1000
# Episode: 89, Score: 99.05, Max: 103.32, Min: 37.55, T-max: 1000
# Episode: 90, Score: 102.68, Max: 103.32, Min: 37.55, T-max: 1000
# *** Episode 90 	 Average Score (over agents): 102.68 	 Average Score on 100 Episode: 68.38, Time: 00:18:11***
# Episode: 91, Score: 91.70, Max: 103.32, Min: 37.55, T-max: 1000
# Episode: 92, Score: 105.60, Max: 105.60, Min: 37.55, T-max: 1000
# Episode: 93, Score: 101.06, Max: 105.60, Min: 37.55, T-max: 1000
# Episode: 94, Score: 104.24, Max: 105.60, Min: 37.55, T-max: 1000
# Episode: 95, Score: 100.10, Max: 105.60, Min: 37.55, T-max: 1000
# Episode: 96, Score: 112.95, Max: 112.95, Min: 37.55, T-max: 1000
# Episode: 97, Score: 106.04, Max: 112.95, Min: 37.55, T-max: 1000
# Episode: 98, Score: 110.13, Max: 112.95, Min: 37.55, T-max: 1000
# Episode: 99, Score: 102.45, Max: 112.95, Min: 37.55, T-max: 1000
# Episode: 100, Score: 107.59, Max: 112.95, Min: 37.55, T-max: 1000
# *** Episode 100 	 Average Score (over agents): 107.59 	 Average Score on 100 Episode: 71.96, Time: 00:19:16***
# Episode: 101, Score: 96.28, Max: 112.95, Min: 37.55, T-max: 1000
# Episode: 102, Score: 108.09, Max: 112.95, Min: 37.55, T-max: 1000
# Episode: 103, Score: 107.90, Max: 112.95, Min: 37.55, T-max: 1000
# Episode: 104, Score: 112.82, Max: 112.95, Min: 37.55, T-max: 1000
# Episode: 105, Score: 112.19, Max: 112.95, Min: 37.55, T-max: 1000
# Episode: 106, Score: 116.42, Max: 116.42, Min: 37.55, T-max: 1000
# Episode: 107, Score: 113.96, Max: 116.42, Min: 37.55, T-max: 1000
# Episode: 108, Score: 120.30, Max: 120.30, Min: 37.55, T-max: 1000
# Episode: 109, Score: 112.44, Max: 120.30, Min: 37.55, T-max: 1000
# Episode: 110, Score: 110.39, Max: 120.30, Min: 37.55, T-max: 1000
# *** Episode 110 	 Average Score (over agents): 110.39 	 Average Score on 100 Episode: 78.33, Time: 00:20:27***
# Episode: 111, Score: 122.21, Max: 122.21, Min: 37.55, T-max: 1000
# Episode: 112, Score: 128.97, Max: 128.97, Min: 37.55, T-max: 1000
# Episode: 113, Score: 103.85, Max: 128.97, Min: 37.55, T-max: 1000
# Episode: 114, Score: 131.34, Max: 131.34, Min: 37.55, T-max: 1000
# Episode: 115, Score: 142.51, Max: 142.51, Min: 37.55, T-max: 1000
# Episode: 116, Score: 128.72, Max: 142.51, Min: 37.55, T-max: 1000
# Episode: 117, Score: 132.75, Max: 142.51, Min: 37.55, T-max: 1000
# Episode: 118, Score: 122.84, Max: 142.51, Min: 37.55, T-max: 1000
# Episode: 119, Score: 142.77, Max: 142.77, Min: 37.55, T-max: 1000
# Episode: 120, Score: 132.96, Max: 142.77, Min: 37.55, T-max: 1000
# *** Episode 120 	 Average Score (over agents): 132.96 	 Average Score on 100 Episode: 86.05, Time: 00:21:46***
# Episode: 121, Score: 141.06, Max: 142.77, Min: 37.55, T-max: 1000
# Episode: 122, Score: 139.55, Max: 142.77, Min: 37.55, T-max: 1000
# Episode: 123, Score: 136.09, Max: 142.77, Min: 37.55, T-max: 1000
# Episode: 124, Score: 149.82, Max: 149.82, Min: 37.55, T-max: 1000
# Episode: 125, Score: 142.56, Max: 149.82, Min: 37.55, T-max: 1000
# Episode: 126, Score: 147.74, Max: 149.82, Min: 37.55, T-max: 1000
# Episode: 127, Score: 149.51, Max: 149.82, Min: 37.55, T-max: 1000
# Episode: 128, Score: 148.94, Max: 149.82, Min: 37.55, T-max: 1000
# Episode: 129, Score: 174.44, Max: 174.44, Min: 37.55, T-max: 1000
# Episode: 130, Score: 157.92, Max: 174.44, Min: 37.55, T-max: 1000
# *** Episode 130 	 Average Score (over agents): 157.92 	 Average Score on 100 Episode: 95.21, Time: 00:23:19***
# Episode: 131, Score: 152.06, Max: 174.44, Min: 37.55, T-max: 1000
# Episode: 132, Score: 167.53, Max: 174.44, Min: 37.55, T-max: 1000
# Episode: 133, Score: 156.16, Max: 174.44, Min: 37.55, T-max: 1000
# Episode: 134, Score: 178.59, Max: 178.59, Min: 37.55, T-max: 1000
# Episode: 135, Score: 152.78, Max: 178.59, Min: 37.55, T-max: 1000
# Episode: 136, Score: 146.36, Max: 178.59, Min: 37.55, T-max: 1000
# Episode: 137, Score: 159.93, Max: 178.59, Min: 37.55, T-max: 1000
# Episode: 138, Score: 157.47, Max: 178.59, Min: 37.55, T-max: 1000
# Episode: 139, Score: 178.56, Max: 178.59, Min: 37.55, T-max: 1000
# Episode: 140, Score: 163.12, Max: 178.59, Min: 37.55, T-max: 1000
# *** Episode 140 	 Average Score (over agents): 163.12 	 Average Score on 100 Episode: 104.99, Time: 00:24:37***
# Episode: 141, Score: 173.69, Max: 178.59, Min: 37.55, T-max: 1000
# Episode: 142, Score: 166.58, Max: 178.59, Min: 37.55, T-max: 1000
# Episode: 143, Score: 172.71, Max: 178.59, Min: 37.55, T-max: 1000
# Episode: 144, Score: 187.26, Max: 187.26, Min: 37.55, T-max: 1000
# Episode: 145, Score: 168.80, Max: 187.26, Min: 37.55, T-max: 1000
# Episode: 146, Score: 165.41, Max: 187.26, Min: 37.55, T-max: 1000
# Episode: 147, Score: 179.22, Max: 187.26, Min: 37.55, T-max: 1000
# Episode: 148, Score: 194.67, Max: 194.67, Min: 37.55, T-max: 1000
# Episode: 149, Score: 180.68, Max: 194.67, Min: 37.55, T-max: 1000
# Episode: 150, Score: 176.16, Max: 194.67, Min: 37.55, T-max: 1000
# *** Episode 150 	 Average Score (over agents): 176.16 	 Average Score on 100 Episode: 115.97, Time: 00:26:04***
# Episode: 151, Score: 202.46, Max: 202.46, Min: 37.55, T-max: 1000
# Episode: 152, Score: 175.15, Max: 202.46, Min: 37.55, T-max: 1000
# Episode: 153, Score: 212.28, Max: 212.28, Min: 37.55, T-max: 1000
# Episode: 154, Score: 195.13, Max: 212.28, Min: 37.55, T-max: 1000
# Episode: 155, Score: 215.06, Max: 215.06, Min: 37.55, T-max: 1000
# Episode: 156, Score: 183.29, Max: 215.06, Min: 37.55, T-max: 1000
# Episode: 157, Score: 203.05, Max: 215.06, Min: 37.55, T-max: 1000
# Episode: 158, Score: 211.45, Max: 215.06, Min: 37.55, T-max: 1000
# Episode: 159, Score: 207.04, Max: 215.06, Min: 37.55, T-max: 1000
# Episode: 160, Score: 187.54, Max: 215.06, Min: 37.55, T-max: 1000
# *** Episode 160 	 Average Score (over agents): 187.54 	 Average Score on 100 Episode: 128.86, Time: 00:27:21***
# Episode: 161, Score: 212.42, Max: 215.06, Min: 37.55, T-max: 1000
# Episode: 162, Score: 191.96, Max: 215.06, Min: 37.55, T-max: 1000
# Episode: 163, Score: 221.25, Max: 221.25, Min: 37.55, T-max: 1000
# Episode: 164, Score: 209.91, Max: 221.25, Min: 37.55, T-max: 1000
# Episode: 165, Score: 204.27, Max: 221.25, Min: 37.55, T-max: 1000
# Episode: 166, Score: 216.67, Max: 221.25, Min: 37.55, T-max: 1000
# Episode: 167, Score: 223.84, Max: 223.84, Min: 37.55, T-max: 1000
# Episode: 168, Score: 217.82, Max: 223.84, Min: 37.55, T-max: 1000
# Episode: 169, Score: 232.19, Max: 232.19, Min: 37.55, T-max: 1000
# Episode: 170, Score: 223.99, Max: 232.19, Min: 37.55, T-max: 1000
# *** Episode 170 	 Average Score (over agents): 223.99 	 Average Score on 100 Episode: 142.61, Time: 00:29:08***
# Episode: 171, Score: 233.19, Max: 233.19, Min: 37.55, T-max: 1000
# Episode: 172, Score: 221.68, Max: 233.19, Min: 37.55, T-max: 1000
# Episode: 173, Score: 219.24, Max: 233.19, Min: 37.55, T-max: 1000
# Episode: 174, Score: 230.47, Max: 233.19, Min: 37.55, T-max: 1000
# Episode: 175, Score: 225.71, Max: 233.19, Min: 37.55, T-max: 1000
# Episode: 176, Score: 232.00, Max: 233.19, Min: 37.55, T-max: 1000
# Episode: 177, Score: 235.02, Max: 235.02, Min: 37.55, T-max: 1000
# Episode: 178, Score: 244.49, Max: 244.49, Min: 37.55, T-max: 1000
# Episode: 179, Score: 253.68, Max: 253.68, Min: 37.55, T-max: 1000
# Episode: 180, Score: 231.34, Max: 253.68, Min: 37.55, T-max: 1000
# *** Episode 180 	 Average Score (over agents): 231.34 	 Average Score on 100 Episode: 157.20, Time: 00:30:50***
# Episode: 181, Score: 251.70, Max: 253.68, Min: 37.55, T-max: 1000
# Episode: 182, Score: 245.33, Max: 253.68, Min: 37.55, T-max: 1000
# Episode: 183, Score: 239.52, Max: 253.68, Min: 37.55, T-max: 1000
# Episode: 184, Score: 263.48, Max: 263.48, Min: 37.55, T-max: 1000
# Episode: 185, Score: 242.81, Max: 263.48, Min: 37.55, T-max: 1000
# Episode: 186, Score: 237.80, Max: 263.48, Min: 37.55, T-max: 1000
# Episode: 187, Score: 265.18, Max: 265.18, Min: 37.55, T-max: 1000
# Episode: 188, Score: 278.10, Max: 278.10, Min: 37.55, T-max: 1000
# Episode: 189, Score: 264.19, Max: 278.10, Min: 37.55, T-max: 1000
# Episode: 190, Score: 269.88, Max: 278.10, Min: 37.55, T-max: 1000
# *** Episode 190 	 Average Score (over agents): 269.88 	 Average Score on 100 Episode: 173.38, Time: 00:32:38***
# Episode: 191, Score: 249.18, Max: 278.10, Min: 37.55, T-max: 1000
# Episode: 192, Score: 262.13, Max: 278.10, Min: 37.55, T-max: 1000
# Episode: 193, Score: 276.25, Max: 278.10, Min: 37.55, T-max: 1000
# Episode: 194, Score: 265.31, Max: 278.10, Min: 37.55, T-max: 1000
# Episode: 195, Score: 281.25, Max: 281.25, Min: 37.55, T-max: 1000
# Episode: 196, Score: 288.97, Max: 288.97, Min: 37.55, T-max: 1000
# Episode: 197, Score: 287.02, Max: 288.97, Min: 37.55, T-max: 1000
# Episode: 198, Score: 259.22, Max: 288.97, Min: 37.55, T-max: 1000
# Episode: 199, Score: 276.67, Max: 288.97, Min: 37.55, T-max: 1000
# Episode: 200, Score: 290.56, Max: 290.56, Min: 37.55, T-max: 1000
# *** Episode 200 	 Average Score (over agents): 290.56 	 Average Score on 100 Episode: 190.33, Time: 00:34:19***
# Episode: 201, Score: 276.08, Max: 290.56, Min: 37.55, T-max: 1000
# Episode: 202, Score: 273.67, Max: 290.56, Min: 37.55, T-max: 1000
# Episode: 203, Score: 281.15, Max: 290.56, Min: 37.55, T-max: 1000
# Episode: 204, Score: 293.58, Max: 293.58, Min: 37.55, T-max: 1000
# Episode: 205, Score: 310.25, Max: 310.25, Min: 37.55, T-max: 1000
# Episode: 206, Score: 297.72, Max: 310.25, Min: 37.55, T-max: 1000
# Episode: 207, Score: 288.41, Max: 310.25, Min: 37.55, T-max: 1000
# Episode: 208, Score: 296.60, Max: 310.25, Min: 37.55, T-max: 1000
# Episode: 209, Score: 303.50, Max: 310.25, Min: 37.55, T-max: 1000
# Episode: 210, Score: 302.82, Max: 310.25, Min: 37.55, T-max: 1000
# *** Episode 210 	 Average Score (over agents): 302.82 	 Average Score on 100 Episode: 208.46, Time: 00:36:07***
# Episode: 211, Score: 330.58, Max: 330.58, Min: 37.55, T-max: 1000
# Episode: 212, Score: 326.20, Max: 330.58, Min: 37.55, T-max: 1000
# Episode: 213, Score: 320.28, Max: 330.58, Min: 37.55, T-max: 1000
# Episode: 214, Score: 330.56, Max: 330.58, Min: 37.55, T-max: 1000
# Episode: 215, Score: 317.11, Max: 330.58, Min: 37.55, T-max: 1000
# Episode: 216, Score: 325.78, Max: 330.58, Min: 37.55, T-max: 1000
# Episode: 217, Score: 339.67, Max: 339.67, Min: 37.55, T-max: 1000
# Episode: 218, Score: 316.90, Max: 339.67, Min: 37.55, T-max: 1000
# Episode: 219, Score: 325.13, Max: 339.67, Min: 37.55, T-max: 1000
# Episode: 220, Score: 342.35, Max: 342.35, Min: 37.55, T-max: 1000
# *** Episode 220 	 Average Score (over agents): 342.35 	 Average Score on 100 Episode: 228.32, Time: 00:38:00***
# Episode: 221, Score: 344.18, Max: 344.18, Min: 37.55, T-max: 1000
# Episode: 222, Score: 343.95, Max: 344.18, Min: 37.55, T-max: 1000
# Episode: 223, Score: 355.58, Max: 355.58, Min: 37.55, T-max: 1000
# Episode: 224, Score: 325.75, Max: 355.58, Min: 37.55, T-max: 1000
# Episode: 225, Score: 348.61, Max: 355.58, Min: 37.55, T-max: 1000
# Episode: 226, Score: 345.41, Max: 355.58, Min: 37.55, T-max: 1000
# Episode: 227, Score: 333.45, Max: 355.58, Min: 37.55, T-max: 1000
# Episode: 228, Score: 334.98, Max: 355.58, Min: 37.55, T-max: 1000
# Episode: 229, Score: 373.38, Max: 373.38, Min: 37.55, T-max: 1000
# Episode: 230, Score: 366.24, Max: 373.38, Min: 37.55, T-max: 1000
# *** Episode 230 	 Average Score (over agents): 366.24 	 Average Score on 100 Episode: 248.16, Time: 00:39:51***
# Episode: 231, Score: 366.95, Max: 373.38, Min: 37.55, T-max: 1000
# Episode: 232, Score: 358.41, Max: 373.38, Min: 37.55, T-max: 1000
# Episode: 233, Score: 359.23, Max: 373.38, Min: 37.55, T-max: 1000
# Episode: 234, Score: 356.03, Max: 373.38, Min: 37.55, T-max: 1000
# Episode: 235, Score: 383.87, Max: 383.87, Min: 37.55, T-max: 1000
# Episode: 236, Score: 384.58, Max: 384.58, Min: 37.55, T-max: 1000
# Episode: 237, Score: 386.85, Max: 386.85, Min: 37.55, T-max: 1000
# Episode: 238, Score: 370.70, Max: 386.85, Min: 37.55, T-max: 1000
# Episode: 239, Score: 347.35, Max: 386.85, Min: 37.55, T-max: 1000
# Episode: 240, Score: 363.87, Max: 386.85, Min: 37.55, T-max: 1000
# *** Episode 240 	 Average Score (over agents): 363.87 	 Average Score on 100 Episode: 268.81, Time: 00:41:43***
# Episode: 241, Score: 394.23, Max: 394.23, Min: 37.55, T-max: 1000
# Episode: 242, Score: 391.85, Max: 394.23, Min: 37.55, T-max: 1000
# Episode: 243, Score: 396.27, Max: 396.27, Min: 37.55, T-max: 1000
# Episode: 244, Score: 380.77, Max: 396.27, Min: 37.55, T-max: 1000
# Episode: 245, Score: 379.17, Max: 396.27, Min: 37.55, T-max: 1000
# Episode: 246, Score: 382.35, Max: 396.27, Min: 37.55, T-max: 1000
# Episode: 247, Score: 399.84, Max: 399.84, Min: 37.55, T-max: 1000
# Episode: 248, Score: 401.75, Max: 401.75, Min: 37.55, T-max: 1000
# Episode: 249, Score: 401.85, Max: 401.85, Min: 37.55, T-max: 1000
# Episode: 250, Score: 407.24, Max: 407.24, Min: 37.55, T-max: 1000
# *** Episode 250 	 Average Score (over agents): 407.24 	 Average Score on 100 Episode: 290.51, Time: 00:43:23***
# Episode: 251, Score: 400.43, Max: 407.24, Min: 37.55, T-max: 1000
# Episode: 252, Score: 394.18, Max: 407.24, Min: 37.55, T-max: 1000
# Episode: 253, Score: 412.45, Max: 412.45, Min: 37.55, T-max: 1000
# Episode: 254, Score: 383.68, Max: 412.45, Min: 37.55, T-max: 1000
# Episode: 255, Score: 412.99, Max: 412.99, Min: 37.55, T-max: 1000
# Episode: 256, Score: 435.48, Max: 435.48, Min: 37.55, T-max: 1000
# Episode: 257, Score: 433.01, Max: 435.48, Min: 37.55, T-max: 1000
# Episode: 258, Score: 436.69, Max: 436.69, Min: 37.55, T-max: 1000
# Episode: 259, Score: 439.80, Max: 439.80, Min: 37.55, T-max: 1000
# Episode: 260, Score: 438.61, Max: 439.80, Min: 37.55, T-max: 1000
# *** Episode 260 	 Average Score (over agents): 438.61 	 Average Score on 100 Episode: 312.46, Time: 00:45:10***
# Episode: 261, Score: 431.72, Max: 439.80, Min: 37.55, T-max: 1000
# Episode: 262, Score: 418.16, Max: 439.80, Min: 37.55, T-max: 1000
# Episode: 263, Score: 436.77, Max: 439.80, Min: 37.55, T-max: 1000
# Episode: 264, Score: 443.24, Max: 443.24, Min: 37.55, T-max: 1000
# Episode: 265, Score: 446.44, Max: 446.44, Min: 37.55, T-max: 1000
# Episode: 266, Score: 451.45, Max: 451.45, Min: 37.55, T-max: 1000
# Episode: 267, Score: 447.57, Max: 451.45, Min: 37.55, T-max: 1000
# Episode: 268, Score: 442.21, Max: 451.45, Min: 37.55, T-max: 1000
# Episode: 269, Score: 432.52, Max: 451.45, Min: 37.55, T-max: 1000
# Episode: 270, Score: 443.85, Max: 451.45, Min: 37.55, T-max: 1000
# *** Episode 270 	 Average Score (over agents): 443.85 	 Average Score on 100 Episode: 334.86, Time: 00:46:57***
# Episode: 271, Score: 444.13, Max: 451.45, Min: 37.55, T-max: 1000
# Episode: 272, Score: 450.57, Max: 451.45, Min: 37.55, T-max: 1000
# Episode: 273, Score: 452.84, Max: 452.84, Min: 37.55, T-max: 1000
# Episode: 274, Score: 453.99, Max: 453.99, Min: 37.55, T-max: 1000
# Episode: 275, Score: 460.30, Max: 460.30, Min: 37.55, T-max: 1000
# Episode: 276, Score: 455.40, Max: 460.30, Min: 37.55, T-max: 1000
# Episode: 277, Score: 459.85, Max: 460.30, Min: 37.55, T-max: 1000
# Episode: 278, Score: 446.63, Max: 460.30, Min: 37.55, T-max: 1000
# Episode: 279, Score: 462.00, Max: 462.00, Min: 37.55, T-max: 1000
# Episode: 280, Score: 472.52, Max: 472.52, Min: 37.55, T-max: 1000
# *** Episode 280 	 Average Score (over agents): 472.52 	 Average Score on 100 Episode: 357.17, Time: 00:48:42***
# Episode: 281, Score: 471.00, Max: 472.52, Min: 37.55, T-max: 1000
# Episode: 282, Score: 466.43, Max: 472.52, Min: 37.55, T-max: 1000
# Episode: 283, Score: 480.71, Max: 480.71, Min: 37.55, T-max: 1000
# Episode: 284, Score: 482.82, Max: 482.82, Min: 37.55, T-max: 1000
# Episode: 285, Score: 477.11, Max: 482.82, Min: 37.55, T-max: 1000
# Episode: 286, Score: 451.18, Max: 482.82, Min: 37.55, T-max: 1000
# Episode: 287, Score: 446.28, Max: 482.82, Min: 37.55, T-max: 1000
# Episode: 288, Score: 468.87, Max: 482.82, Min: 37.55, T-max: 1000
# Episode: 289, Score: 496.21, Max: 496.21, Min: 37.55, T-max: 1000
# Episode: 290, Score: 488.57, Max: 496.21, Min: 37.55, T-max: 1000
# *** Episode 290 	 Average Score (over agents): 488.57 	 Average Score on 100 Episode: 378.88, Time: 00:50:17***
# Episode: 291, Score: 490.70, Max: 496.21, Min: 37.55, T-max: 1000
# Episode: 292, Score: 497.62, Max: 497.62, Min: 37.55, T-max: 1000
# Episode: 293, Score: 499.84, Max: 499.84, Min: 37.55, T-max: 1000
# Episode: 294, Score: 500.23, Max: 500.23, Min: 37.55, T-max: 1000
# Episode: 295, Score: 504.81, Max: 504.81, Min: 37.55, T-max: 1000
# Episode: 296, Score: 498.74, Max: 504.81, Min: 37.55, T-max: 1000
# Episode: 297, Score: 511.26, Max: 511.26, Min: 37.55, T-max: 1000
# Episode: 298, Score: 516.76, Max: 516.76, Min: 37.55, T-max: 1000
# Episode: 299, Score: 513.51, Max: 516.76, Min: 37.55, T-max: 1000
# Episode: 300, Score: 517.20, Max: 517.20, Min: 37.55, T-max: 1000
# *** Episode 300 	 Average Score (over agents): 517.20 	 Average Score on 100 Episode: 402.02, Time: 00:52:05***
# Episode: 301, Score: 523.59, Max: 523.59, Min: 37.55, T-max: 1000
# Episode: 302, Score: 516.62, Max: 523.59, Min: 37.55, T-max: 1000
# Episode: 303, Score: 515.80, Max: 523.59, Min: 37.55, T-max: 1000
# Episode: 304, Score: 521.95, Max: 523.59, Min: 37.55, T-max: 1000
# Episode: 305, Score: 523.62, Max: 523.62, Min: 37.55, T-max: 1000
# Episode: 306, Score: 502.30, Max: 523.62, Min: 37.55, T-max: 1000
# Episode: 307, Score: 536.52, Max: 536.52, Min: 37.55, T-max: 1000
# Episode: 308, Score: 524.03, Max: 536.52, Min: 37.55, T-max: 1000
# Episode: 309, Score: 524.59, Max: 536.52, Min: 37.55, T-max: 1000
# Episode: 310, Score: 529.81, Max: 536.52, Min: 37.55, T-max: 1000
# *** Episode 310 	 Average Score (over agents): 529.81 	 Average Score on 100 Episode: 424.97, Time: 00:53:42***
# Episode: 311, Score: 527.88, Max: 536.52, Min: 37.55, T-max: 1000
# Episode: 312, Score: 536.86, Max: 536.86, Min: 37.55, T-max: 1000
# Episode: 313, Score: 547.01, Max: 547.01, Min: 37.55, T-max: 1000
# Episode: 314, Score: 534.48, Max: 547.01, Min: 37.55, T-max: 1000
# Episode: 315, Score: 542.06, Max: 547.01, Min: 37.55, T-max: 1000
# Episode: 316, Score: 1100.88, Max: 1100.88, Min: 37.55, T-max: 1999
# Episode: 317, Score: 547.55, Max: 1100.88, Min: 37.55, T-max: 1000
# Episode: 318, Score: 556.17, Max: 1100.88, Min: 37.55, T-max: 1000
# Episode: 319, Score: 1105.85, Max: 1105.85, Min: 37.55, T-max: 1999
# Episode: 320, Score: 561.69, Max: 1105.85, Min: 37.55, T-max: 1000
# *** Episode 320 	 Average Score (over agents): 561.69 	 Average Score on 100 Episode: 457.83, Time: 00:55:50***
# Episode: 321, Score: 558.11, Max: 1105.85, Min: 37.55, T-max: 1000
# Episode: 322, Score: 560.91, Max: 1105.85, Min: 37.55, T-max: 1000
# Episode: 323, Score: 566.17, Max: 1105.85, Min: 37.55, T-max: 1000
# Episode: 324, Score: 563.64, Max: 1105.85, Min: 37.55, T-max: 1000
# Episode: 325, Score: 558.74, Max: 1105.85, Min: 37.55, T-max: 1000
# Episode: 326, Score: 572.07, Max: 1105.85, Min: 37.55, T-max: 1000
# Episode: 327, Score: 570.93, Max: 1105.85, Min: 37.55, T-max: 1000
# Episode: 328, Score: 570.32, Max: 1105.85, Min: 37.55, T-max: 1000
# Episode: 329, Score: 572.00, Max: 1105.85, Min: 37.55, T-max: 1000
# Episode: 330, Score: 1151.51, Max: 1151.51, Min: 37.55, T-max: 1999
# *** Episode 330 	 Average Score (over agents): 1151.51 	 Average Score on 100 Episode: 485.56, Time: 00:57:39***
# Episode: 331, Score: 1170.91, Max: 1170.91, Min: 37.55, T-max: 1999
# Episode: 332, Score: 1172.45, Max: 1172.45, Min: 37.55, T-max: 1999
# Episode: 333, Score: 601.70, Max: 1172.45, Min: 37.55, T-max: 1000
# Episode: 334, Score: 595.75, Max: 1172.45, Min: 37.55, T-max: 1000
# Episode: 335, Score: 584.21, Max: 1172.45, Min: 37.55, T-max: 1000
# Episode: 336, Score: 604.13, Max: 1172.45, Min: 37.55, T-max: 1000
# Episode: 337, Score: 599.37, Max: 1172.45, Min: 37.55, T-max: 1000
# Episode: 338, Score: 606.58, Max: 1172.45, Min: 37.55, T-max: 1000
# Episode: 339, Score: 1212.19, Max: 1212.19, Min: 37.55, T-max: 1999
# Episode: 340, Score: 604.89, Max: 1212.19, Min: 37.55, T-max: 1000
# *** Episode 340 	 Average Score (over agents): 604.89 	 Average Score on 100 Episode: 526.30, Time: 00:59:57***
# Episode: 341, Score: 1217.66, Max: 1217.66, Min: 37.55, T-max: 1999
# Episode: 342, Score: 608.99, Max: 1217.66, Min: 37.55, T-max: 1000
# Episode: 343, Score: 1210.03, Max: 1217.66, Min: 37.55, T-max: 1999
# Episode: 344, Score: 1204.80, Max: 1217.66, Min: 37.55, T-max: 1999
# Episode: 345, Score: 1225.41, Max: 1225.41, Min: 37.55, T-max: 1999
# Episode: 346, Score: 1233.20, Max: 1233.20, Min: 37.55, T-max: 1999
# Episode: 347, Score: 1229.79, Max: 1233.20, Min: 37.55, T-max: 1999
# Episode: 348, Score: 1232.03, Max: 1233.20, Min: 37.55, T-max: 1999
# Episode: 349, Score: 618.85, Max: 1233.20, Min: 37.55, T-max: 1000
# Episode: 350, Score: 622.84, Max: 1233.20, Min: 37.55, T-max: 1000
# *** Episode 350 	 Average Score (over agents): 622.84 	 Average Score on 100 Episode: 590.99, Time: 01:02:54***
# Episode: 351, Score: 1238.70, Max: 1238.70, Min: 37.55, T-max: 1999
# Episode: 352, Score: 1248.75, Max: 1248.75, Min: 37.55, T-max: 1999
# Episode: 353, Score: 1254.47, Max: 1254.47, Min: 37.55, T-max: 1999
# Episode: 354, Score: 632.71, Max: 1254.47, Min: 37.55, T-max: 1000
# Episode: 355, Score: 641.28, Max: 1254.47, Min: 37.55, T-max: 1000
# Episode: 356, Score: 631.97, Max: 1254.47, Min: 37.55, T-max: 1000
# Episode: 357, Score: 1271.55, Max: 1271.55, Min: 37.55, T-max: 1999
# Episode: 358, Score: 637.71, Max: 1271.55, Min: 37.55, T-max: 1000
# Episode: 359, Score: 641.35, Max: 1271.55, Min: 37.55, T-max: 1000
# Episode: 360, Score: 1282.68, Max: 1282.68, Min: 37.55, T-max: 1999
# *** Episode 360 	 Average Score (over agents): 1282.68 	 Average Score on 100 Episode: 643.93, Time: 01:05:29***
# Episode: 361, Score: 643.68, Max: 1282.68, Min: 37.55, T-max: 1000
# Episode: 362, Score: 639.99, Max: 1282.68, Min: 37.55, T-max: 1000
# Episode: 363, Score: 646.03, Max: 1282.68, Min: 37.55, T-max: 1000
# Episode: 364, Score: 1282.18, Max: 1282.68, Min: 37.55, T-max: 1999
# Episode: 365, Score: 1289.11, Max: 1289.11, Min: 37.55, T-max: 1999
# Episode: 366, Score: 656.78, Max: 1289.11, Min: 37.55, T-max: 1000
# Episode: 367, Score: 645.64, Max: 1289.11, Min: 37.55, T-max: 1000
# Episode: 368, Score: 651.12, Max: 1289.11, Min: 37.55, T-max: 1000
# Episode: 369, Score: 1295.60, Max: 1295.60, Min: 37.55, T-max: 1999
# Episode: 370, Score: 1292.55, Max: 1295.60, Min: 37.55, T-max: 1999
# *** Episode 370 	 Average Score (over agents): 1292.55 	 Average Score on 100 Episode: 690.41, Time: 01:08:02***
# Episode: 371, Score: 662.17, Max: 1295.60, Min: 37.55, T-max: 1000
# Episode: 372, Score: 1307.18, Max: 1307.18, Min: 37.55, T-max: 1999
# Episode: 373, Score: 1315.72, Max: 1315.72, Min: 37.55, T-max: 1999
# Episode: 374, Score: 649.49, Max: 1315.72, Min: 37.55, T-max: 1000
# Episode: 375, Score: 1333.15, Max: 1333.15, Min: 37.55, T-max: 1999
# Episode: 376, Score: 666.78, Max: 1333.15, Min: 37.55, T-max: 1000
# Episode: 377, Score: 1333.73, Max: 1333.73, Min: 37.55, T-max: 1999
# Episode: 378, Score: 1335.51, Max: 1335.51, Min: 37.55, T-max: 1999
# Episode: 379, Score: 667.02, Max: 1335.51, Min: 37.55, T-max: 1000
# Episode: 380, Score: 1326.73, Max: 1335.51, Min: 37.55, T-max: 1999
# *** Episode 380 	 Average Score (over agents): 1326.73 	 Average Score on 100 Episode: 750.81, Time: 01:11:10***
# Episode: 381, Score: 1342.36, Max: 1342.36, Min: 37.55, T-max: 1999
# Episode: 382, Score: 635.30, Max: 1342.36, Min: 37.55, T-max: 1000
# Episode: 383, Score: 676.77, Max: 1342.36, Min: 37.55, T-max: 1000
# Episode: 384, Score: 673.17, Max: 1342.36, Min: 37.55, T-max: 1000
# Episode: 385, Score: 679.78, Max: 1342.36, Min: 37.55, T-max: 1000
# Episode: 386, Score: 674.67, Max: 1342.36, Min: 37.55, T-max: 1000
# Episode: 387, Score: 686.59, Max: 1342.36, Min: 37.55, T-max: 1000
# Episode: 388, Score: 682.33, Max: 1342.36, Min: 37.55, T-max: 1000
# Episode: 389, Score: 679.60, Max: 1342.36, Min: 37.55, T-max: 1000
# Episode: 390, Score: 1368.89, Max: 1368.89, Min: 37.55, T-max: 1999
# *** Episode 390 	 Average Score (over agents): 1368.89 	 Average Score on 100 Episode: 784.51, Time: 01:13:43***
# Episode: 391, Score: 1362.01, Max: 1368.89, Min: 37.55, T-max: 1999
# Episode: 392, Score: 1377.95, Max: 1377.95, Min: 37.55, T-max: 1999
#
#  End of PPO!

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %%
env.close()
