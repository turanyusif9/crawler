# %% [markdown]
# # Continuous Control
#
# ---
#
# Congratulations for completing the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program!  In this notebook, you will learn how to control an agent in a more challenging environment, where the goal is to train a creature with four arms to walk forward.  **Note that this exercise is optional!**
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Crawler.app"`
# - **Windows** (x86): `"path/to/Crawler_Windows_x86/Crawler.exe"`
# - **Windows** (x86_64): `"path/to/Crawler_Windows_x86_64/Crawler.exe"`
# - **Linux** (x86): `"path/to/Crawler_Linux/Crawler.x86"`
# - **Linux** (x86_64): `"path/to/Crawler_Linux/Crawler.x86_64"`
# - **Linux** (x86, headless): `"path/to/Crawler_Linux_NoVis/Crawler.x86"`
# - **Linux** (x86_64, headless): `"path/to/Crawler_Linux_NoVis/Crawler.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Crawler.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Crawler.app")
# ```

# %%
env = UnityEnvironment(file_name='C:/Users/Turan/Desktop/drl project/deep-reinforcement-learning/p2_continuous-control/Crawler_Windows_x86_64/Crawler.exe')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: CrawlerBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 129
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 20
#         Vector Action descriptions: , , , , , , , , , , , , , , , , , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 12
# Size of each action: 20
# There are 12 agents. Each observes a state with length: 129
# The state for the first agent looks like: [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  2.25000000e+00
#   1.00000000e+00  0.00000000e+00  1.78813934e-07  0.00000000e+00
#   1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093168e-01 -1.42857209e-01 -6.06078804e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339906e+00 -1.42857209e-01
#  -1.33341408e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093347e-01 -1.42857209e-01 -6.06078625e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339953e+00 -1.42857209e-01
#  -1.33341372e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093168e-01 -1.42857209e-01  6.06078804e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339906e+00 -1.42857209e-01
#   1.33341408e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093347e-01 -1.42857209e-01  6.06078625e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339953e+00 -1.42857209e-01
#   1.33341372e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
#env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
#states = env_info.vector_observations                  # get the current state (for each agent)
#scores = np.zeros(num_agents)                          # initialize the score (for each agent)
#while True:
#    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
#    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
#    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#    next_states = env_info.vector_observations         # get next state (for each agent)
#    rewards = env_info.rewards                         # get reward (for each agent)
#    dones = env_info.local_done                        # see if episode finished
#    scores += env_info.rewards                         # update the score (for each agent)
#    states = next_states                               # roll over states to next time step
#    if np.any(dones):                                  # exit loop if episode finished
#        break
#print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
#env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
from  collections  import deque
from itertools import count
import torch
import time
#from ddpg_agent import Agent
from ppo_agent_combined import Agent
import matplotlib.pyplot as plt
# %matplotlib inline
env_info = env.reset(train_mode=True)[brain_name]
agent = Agent(state_size=state_size, action_size=action_size, random_seed=8, n_agent=num_agents, \
              fc1_units=128, fc2_units=128)

print("Smoothness used:", agent.USE_SMOOTHNESS)
print("Symmetry used:", agent.USE_SYMMETRY)
print("Magnitude used:", agent.USE_MAGNITUDE)
# Out:
# Smoothness used: False
# Symmetry used: False
# Magnitude used: True

# %%
def ppo(env, agent, n_episodes=500, print_every=10, n_agent = 12):
    """
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        print_every (int): number of episodes to print result
        n_agent (int): number of identical agents in environment
    """
    scores_deque = deque(maxlen=100)
    scores_global = []    
    scores = []
    max_t = 2000
        
    time_start = time.time()
    
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        states = env_info.vector_observations
        agent_scores = np.zeros(n_agent)
        t_max = 0
        for t in range(max_t):
            actions, log_probs, _, values = agent.act(states)
            # get needed information from environment
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations
            rewards = env_info.rewards
            dones = np.array([1 if t else 0 for t in env_info.local_done])
            agent.save_step([states, values.detach(), actions, log_probs.detach(), rewards, 1 - dones])
            states = next_states
            agent_scores += rewards
            t_max = t
            if all(dones) or t == max_t-1:
                agent.step(next_states)
                break
                
        score = np.mean(agent_scores)
        scores_deque.append(score)
        scores.append(score)

        print('Episode: {}, Score: {:.2f}, Max: {:.2f}, Min: {:.2f}, T-max: {}   '\
              .format(i_episode, score, np.max(scores), np.min(scores), t_max))
        
        if i_episode % print_every == 0:
            torch.save(agent.actor_critic.actor.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.actor_critic.critic.state_dict(), 'checkpoint_critic.pth')
            s = (int)(time.time() - time_start) 
            print('*** Episode {} \t Average Score (over agents): {:.2f} \t Average Score on 100 Episode: {:.2f}, Time: {:02}:{:02}:{:02}***'\
                  .format(i_episode, score, np.mean(scores_deque), s//3600, s%3600//60, s%60))
            
        if len(scores_deque) == 100 and np.mean(scores_deque) >= 800: # 650: # 500:   
            break


    print('\n End of PPO!')
    return scores

scores = ppo(env=env, agent=agent)
# Out:
# c:\Users\Turan\miniconda3\envs\drlnd\lib\site-packages\torch\nn\functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Episode: 1, Score: 47.94, Max: 47.94, Min: 47.94, T-max: 1000
# Episode: 2, Score: 49.67, Max: 49.67, Min: 47.94, T-max: 1000
# Episode: 3, Score: 43.91, Max: 49.67, Min: 43.91, T-max: 1000
# Episode: 4, Score: 47.40, Max: 49.67, Min: 43.91, T-max: 1000
# Episode: 5, Score: 37.29, Max: 49.67, Min: 37.29, T-max: 1000
# Episode: 6, Score: 45.14, Max: 49.67, Min: 37.29, T-max: 1000
# Episode: 7, Score: 48.15, Max: 49.67, Min: 37.29, T-max: 1000
# Episode: 8, Score: 48.36, Max: 49.67, Min: 37.29, T-max: 1000
# Episode: 9, Score: 49.10, Max: 49.67, Min: 37.29, T-max: 1000
# Episode: 10, Score: 47.01, Max: 49.67, Min: 37.29, T-max: 1000
# *** Episode 10 	 Average Score (over agents): 47.01 	 Average Score on 100 Episode: 46.40, Time: 00:01:39***
# Episode: 11, Score: 47.37, Max: 49.67, Min: 37.29, T-max: 1000
# Episode: 12, Score: 45.77, Max: 49.67, Min: 37.29, T-max: 1000
# Episode: 13, Score: 53.06, Max: 53.06, Min: 37.29, T-max: 1000
# Episode: 14, Score: 49.67, Max: 53.06, Min: 37.29, T-max: 1000
# Episode: 15, Score: 48.23, Max: 53.06, Min: 37.29, T-max: 1000
# Episode: 16, Score: 51.79, Max: 53.06, Min: 37.29, T-max: 1000
# Episode: 17, Score: 54.41, Max: 54.41, Min: 37.29, T-max: 1000
# Episode: 18, Score: 55.15, Max: 55.15, Min: 37.29, T-max: 1000
# Episode: 19, Score: 56.01, Max: 56.01, Min: 37.29, T-max: 1000
# Episode: 20, Score: 55.17, Max: 56.01, Min: 37.29, T-max: 1000
# *** Episode 20 	 Average Score (over agents): 55.17 	 Average Score on 100 Episode: 49.03, Time: 00:03:15***
# Episode: 21, Score: 54.99, Max: 56.01, Min: 37.29, T-max: 1000
# Episode: 22, Score: 52.98, Max: 56.01, Min: 37.29, T-max: 1000
# Episode: 23, Score: 54.99, Max: 56.01, Min: 37.29, T-max: 1000
# Episode: 24, Score: 49.75, Max: 56.01, Min: 37.29, T-max: 1000
# Episode: 25, Score: 54.24, Max: 56.01, Min: 37.29, T-max: 1000
# Episode: 26, Score: 57.90, Max: 57.90, Min: 37.29, T-max: 1000
# Episode: 27, Score: 56.53, Max: 57.90, Min: 37.29, T-max: 1000
# Episode: 28, Score: 60.70, Max: 60.70, Min: 37.29, T-max: 1000
# Episode: 29, Score: 60.38, Max: 60.70, Min: 37.29, T-max: 1000
# Episode: 30, Score: 61.32, Max: 61.32, Min: 37.29, T-max: 1000
# *** Episode 30 	 Average Score (over agents): 61.32 	 Average Score on 100 Episode: 51.48, Time: 00:04:58***
# Episode: 31, Score: 61.64, Max: 61.64, Min: 37.29, T-max: 1000
# Episode: 32, Score: 55.05, Max: 61.64, Min: 37.29, T-max: 1000
# Episode: 33, Score: 57.30, Max: 61.64, Min: 37.29, T-max: 1000
# Episode: 34, Score: 60.46, Max: 61.64, Min: 37.29, T-max: 1000
# Episode: 35, Score: 63.67, Max: 63.67, Min: 37.29, T-max: 1000
# Episode: 36, Score: 65.30, Max: 65.30, Min: 37.29, T-max: 1000
# Episode: 37, Score: 63.03, Max: 65.30, Min: 37.29, T-max: 1000
# Episode: 38, Score: 59.85, Max: 65.30, Min: 37.29, T-max: 1000
# Episode: 39, Score: 66.80, Max: 66.80, Min: 37.29, T-max: 1000
# Episode: 40, Score: 65.96, Max: 66.80, Min: 37.29, T-max: 1000
# *** Episode 40 	 Average Score (over agents): 65.96 	 Average Score on 100 Episode: 54.09, Time: 00:06:41***
# Episode: 41, Score: 66.20, Max: 66.80, Min: 37.29, T-max: 1000
# Episode: 42, Score: 60.34, Max: 66.80, Min: 37.29, T-max: 1000
# Episode: 43, Score: 64.74, Max: 66.80, Min: 37.29, T-max: 1000
# Episode: 44, Score: 64.27, Max: 66.80, Min: 37.29, T-max: 1000
# Episode: 45, Score: 65.51, Max: 66.80, Min: 37.29, T-max: 1000
# Episode: 46, Score: 66.04, Max: 66.80, Min: 37.29, T-max: 1000
# Episode: 47, Score: 65.16, Max: 66.80, Min: 37.29, T-max: 1000
# Episode: 48, Score: 62.76, Max: 66.80, Min: 37.29, T-max: 1000
# Episode: 49, Score: 69.58, Max: 69.58, Min: 37.29, T-max: 1000
# Episode: 50, Score: 65.23, Max: 69.58, Min: 37.29, T-max: 1000
# *** Episode 50 	 Average Score (over agents): 65.23 	 Average Score on 100 Episode: 56.26, Time: 00:08:22***
# Episode: 51, Score: 69.31, Max: 69.58, Min: 37.29, T-max: 1000
# Episode: 52, Score: 70.90, Max: 70.90, Min: 37.29, T-max: 1000
# Episode: 53, Score: 68.19, Max: 70.90, Min: 37.29, T-max: 1000
# Episode: 54, Score: 61.68, Max: 70.90, Min: 37.29, T-max: 1000
# Episode: 55, Score: 66.89, Max: 70.90, Min: 37.29, T-max: 1000
# Episode: 56, Score: 71.63, Max: 71.63, Min: 37.29, T-max: 1000
# Episode: 57, Score: 72.23, Max: 72.23, Min: 37.29, T-max: 1000
# Episode: 58, Score: 73.17, Max: 73.17, Min: 37.29, T-max: 1000
# Episode: 59, Score: 65.78, Max: 73.17, Min: 37.29, T-max: 1000
# Episode: 60, Score: 68.56, Max: 73.17, Min: 37.29, T-max: 1000
# *** Episode 60 	 Average Score (over agents): 68.56 	 Average Score on 100 Episode: 58.36, Time: 00:10:04***
# Episode: 61, Score: 80.83, Max: 80.83, Min: 37.29, T-max: 1000
# Episode: 62, Score: 76.24, Max: 80.83, Min: 37.29, T-max: 1000
# Episode: 63, Score: 79.06, Max: 80.83, Min: 37.29, T-max: 1000
# Episode: 64, Score: 76.47, Max: 80.83, Min: 37.29, T-max: 1000
# Episode: 65, Score: 72.32, Max: 80.83, Min: 37.29, T-max: 1000
# Episode: 66, Score: 78.47, Max: 80.83, Min: 37.29, T-max: 1000
# Episode: 67, Score: 80.88, Max: 80.88, Min: 37.29, T-max: 1000
# Episode: 68, Score: 74.28, Max: 80.88, Min: 37.29, T-max: 1000
# Episode: 69, Score: 76.44, Max: 80.88, Min: 37.29, T-max: 1000
# Episode: 70, Score: 74.87, Max: 80.88, Min: 37.29, T-max: 1000
# *** Episode 70 	 Average Score (over agents): 74.87 	 Average Score on 100 Episode: 61.02, Time: 00:11:44***
# Episode: 71, Score: 85.33, Max: 85.33, Min: 37.29, T-max: 1000
# Episode: 72, Score: 79.96, Max: 85.33, Min: 37.29, T-max: 1000
# Episode: 73, Score: 76.65, Max: 85.33, Min: 37.29, T-max: 1000
# Episode: 74, Score: 84.39, Max: 85.33, Min: 37.29, T-max: 1000
# Episode: 75, Score: 80.44, Max: 85.33, Min: 37.29, T-max: 1000
# Episode: 76, Score: 82.50, Max: 85.33, Min: 37.29, T-max: 1000
# Episode: 77, Score: 85.57, Max: 85.57, Min: 37.29, T-max: 1000
# Episode: 78, Score: 84.93, Max: 85.57, Min: 37.29, T-max: 1000
# Episode: 79, Score: 90.81, Max: 90.81, Min: 37.29, T-max: 1000
# Episode: 80, Score: 87.76, Max: 90.81, Min: 37.29, T-max: 1000
# *** Episode 80 	 Average Score (over agents): 87.76 	 Average Score on 100 Episode: 63.87, Time: 00:13:19***
# Episode: 81, Score: 82.62, Max: 90.81, Min: 37.29, T-max: 1000
# Episode: 82, Score: 90.51, Max: 90.81, Min: 37.29, T-max: 1000
# Episode: 83, Score: 80.93, Max: 90.81, Min: 37.29, T-max: 1000
# Episode: 84, Score: 85.55, Max: 90.81, Min: 37.29, T-max: 1000
# Episode: 85, Score: 89.78, Max: 90.81, Min: 37.29, T-max: 1000
# Episode: 86, Score: 81.85, Max: 90.81, Min: 37.29, T-max: 1000
# Episode: 87, Score: 74.13, Max: 90.81, Min: 37.29, T-max: 1000
# Episode: 88, Score: 85.97, Max: 90.81, Min: 37.29, T-max: 1000
# Episode: 89, Score: 91.41, Max: 91.41, Min: 37.29, T-max: 1000
# Episode: 90, Score: 92.97, Max: 92.97, Min: 37.29, T-max: 1000
# *** Episode 90 	 Average Score (over agents): 92.97 	 Average Score on 100 Episode: 66.28, Time: 00:14:55***
# Episode: 91, Score: 78.64, Max: 92.97, Min: 37.29, T-max: 1000
# Episode: 92, Score: 98.67, Max: 98.67, Min: 37.29, T-max: 1000
# Episode: 93, Score: 93.69, Max: 98.67, Min: 37.29, T-max: 1000
# Episode: 94, Score: 85.74, Max: 98.67, Min: 37.29, T-max: 1000
# Episode: 95, Score: 76.84, Max: 98.67, Min: 37.29, T-max: 1000
# Episode: 96, Score: 90.04, Max: 98.67, Min: 37.29, T-max: 1000
# Episode: 97, Score: 87.41, Max: 98.67, Min: 37.29, T-max: 1000
# Episode: 98, Score: 90.19, Max: 98.67, Min: 37.29, T-max: 1000
# Episode: 99, Score: 85.60, Max: 98.67, Min: 37.29, T-max: 1000
# Episode: 100, Score: 96.78, Max: 98.67, Min: 37.29, T-max: 1000
# *** Episode 100 	 Average Score (over agents): 96.78 	 Average Score on 100 Episode: 68.49, Time: 00:16:33***
# Episode: 101, Score: 97.66, Max: 98.67, Min: 37.29, T-max: 1000
# Episode: 102, Score: 89.56, Max: 98.67, Min: 37.29, T-max: 1000
# Episode: 103, Score: 87.02, Max: 98.67, Min: 37.29, T-max: 1000
# Episode: 104, Score: 91.96, Max: 98.67, Min: 37.29, T-max: 1000
# Episode: 105, Score: 92.13, Max: 98.67, Min: 37.29, T-max: 1000
# Episode: 106, Score: 104.14, Max: 104.14, Min: 37.29, T-max: 1000
# Episode: 107, Score: 85.51, Max: 104.14, Min: 37.29, T-max: 1000
# Episode: 108, Score: 101.51, Max: 104.14, Min: 37.29, T-max: 1000
# Episode: 109, Score: 97.68, Max: 104.14, Min: 37.29, T-max: 1000
# Episode: 110, Score: 94.39, Max: 104.14, Min: 37.29, T-max: 1000
# *** Episode 110 	 Average Score (over agents): 94.39 	 Average Score on 100 Episode: 73.27, Time: 00:18:09***
# Episode: 111, Score: 101.70, Max: 104.14, Min: 37.29, T-max: 1000
# Episode: 112, Score: 105.48, Max: 105.48, Min: 37.29, T-max: 1000
# Episode: 113, Score: 102.58, Max: 105.48, Min: 37.29, T-max: 1000
# Episode: 114, Score: 98.27, Max: 105.48, Min: 37.29, T-max: 1000
# Episode: 115, Score: 114.11, Max: 114.11, Min: 37.29, T-max: 1000
# Episode: 116, Score: 99.08, Max: 114.11, Min: 37.29, T-max: 1000
# Episode: 117, Score: 121.05, Max: 121.05, Min: 37.29, T-max: 1000
# Episode: 118, Score: 96.68, Max: 121.05, Min: 37.29, T-max: 1000
# Episode: 119, Score: 115.15, Max: 121.05, Min: 37.29, T-max: 1000
# Episode: 120, Score: 97.49, Max: 121.05, Min: 37.29, T-max: 1000
# *** Episode 120 	 Average Score (over agents): 97.49 	 Average Score on 100 Episode: 78.62, Time: 00:19:43***
# Episode: 121, Score: 113.96, Max: 121.05, Min: 37.29, T-max: 1000
# Episode: 122, Score: 111.42, Max: 121.05, Min: 37.29, T-max: 1000
# Episode: 123, Score: 118.97, Max: 121.05, Min: 37.29, T-max: 1000
# Episode: 124, Score: 116.27, Max: 121.05, Min: 37.29, T-max: 1000
# Episode: 125, Score: 118.83, Max: 121.05, Min: 37.29, T-max: 1000
# Episode: 126, Score: 119.51, Max: 121.05, Min: 37.29, T-max: 1000
# Episode: 127, Score: 112.62, Max: 121.05, Min: 37.29, T-max: 1000
# Episode: 128, Score: 112.25, Max: 121.05, Min: 37.29, T-max: 1000
# Episode: 129, Score: 128.41, Max: 128.41, Min: 37.29, T-max: 1000
# Episode: 130, Score: 107.58, Max: 128.41, Min: 37.29, T-max: 1000
# *** Episode 130 	 Average Score (over agents): 107.58 	 Average Score on 100 Episode: 84.58, Time: 00:21:25***
# Episode: 131, Score: 116.41, Max: 128.41, Min: 37.29, T-max: 1000
# Episode: 132, Score: 135.55, Max: 135.55, Min: 37.29, T-max: 1000
# Episode: 133, Score: 130.48, Max: 135.55, Min: 37.29, T-max: 1000
# Episode: 134, Score: 140.60, Max: 140.60, Min: 37.29, T-max: 1000
# Episode: 135, Score: 116.50, Max: 140.60, Min: 37.29, T-max: 1000
# Episode: 136, Score: 122.25, Max: 140.60, Min: 37.29, T-max: 1000
# Episode: 137, Score: 125.80, Max: 140.60, Min: 37.29, T-max: 1000
# Episode: 138, Score: 125.64, Max: 140.60, Min: 37.29, T-max: 1000
# Episode: 139, Score: 145.38, Max: 145.38, Min: 37.29, T-max: 1000
# Episode: 140, Score: 146.85, Max: 146.85, Min: 37.29, T-max: 1000
# *** Episode 140 	 Average Score (over agents): 146.85 	 Average Score on 100 Episode: 91.44, Time: 00:23:06***
# Episode: 141, Score: 145.17, Max: 146.85, Min: 37.29, T-max: 1000
# Episode: 142, Score: 132.57, Max: 146.85, Min: 37.29, T-max: 1000
# Episode: 143, Score: 138.55, Max: 146.85, Min: 37.29, T-max: 1000
# Episode: 144, Score: 155.53, Max: 155.53, Min: 37.29, T-max: 1000
# Episode: 145, Score: 152.98, Max: 155.53, Min: 37.29, T-max: 1000
# Episode: 146, Score: 149.06, Max: 155.53, Min: 37.29, T-max: 1000
# Episode: 147, Score: 157.75, Max: 157.75, Min: 37.29, T-max: 1000
# Episode: 148, Score: 147.60, Max: 157.75, Min: 37.29, T-max: 1000
# Episode: 149, Score: 159.95, Max: 159.95, Min: 37.29, T-max: 1000
# Episode: 150, Score: 139.29, Max: 159.95, Min: 37.29, T-max: 1000
# *** Episode 150 	 Average Score (over agents): 139.29 	 Average Score on 100 Episode: 99.73, Time: 00:24:47***
# Episode: 151, Score: 142.84, Max: 159.95, Min: 37.29, T-max: 1000
# Episode: 152, Score: 145.90, Max: 159.95, Min: 37.29, T-max: 1000
# Episode: 153, Score: 164.28, Max: 164.28, Min: 37.29, T-max: 1000
# Episode: 154, Score: 152.82, Max: 164.28, Min: 37.29, T-max: 1000
# Episode: 155, Score: 164.74, Max: 164.74, Min: 37.29, T-max: 1000
# Episode: 156, Score: 166.30, Max: 166.30, Min: 37.29, T-max: 1000
# Episode: 157, Score: 172.20, Max: 172.20, Min: 37.29, T-max: 1000
# Episode: 158, Score: 169.07, Max: 172.20, Min: 37.29, T-max: 1000
# Episode: 159, Score: 166.77, Max: 172.20, Min: 37.29, T-max: 1000
# Episode: 160, Score: 151.84, Max: 172.20, Min: 37.29, T-max: 1000
# *** Episode 160 	 Average Score (over agents): 151.84 	 Average Score on 100 Episode: 108.81, Time: 00:26:27***
# Episode: 161, Score: 156.13, Max: 172.20, Min: 37.29, T-max: 1000
# Episode: 162, Score: 156.50, Max: 172.20, Min: 37.29, T-max: 1000
# Episode: 163, Score: 173.45, Max: 173.45, Min: 37.29, T-max: 1000
# Episode: 164, Score: 164.29, Max: 173.45, Min: 37.29, T-max: 1000
# Episode: 165, Score: 192.43, Max: 192.43, Min: 37.29, T-max: 1000
# Episode: 166, Score: 187.02, Max: 192.43, Min: 37.29, T-max: 1000
# Episode: 167, Score: 182.42, Max: 192.43, Min: 37.29, T-max: 1000
# Episode: 168, Score: 167.29, Max: 192.43, Min: 37.29, T-max: 1000
# Episode: 169, Score: 182.08, Max: 192.43, Min: 37.29, T-max: 1000
# Episode: 170, Score: 178.93, Max: 192.43, Min: 37.29, T-max: 1000
# *** Episode 170 	 Average Score (over agents): 178.93 	 Average Score on 100 Episode: 118.52, Time: 00:28:09***
# Episode: 171, Score: 156.92, Max: 192.43, Min: 37.29, T-max: 1000
# Episode: 172, Score: 195.29, Max: 195.29, Min: 37.29, T-max: 1000
# Episode: 173, Score: 186.26, Max: 195.29, Min: 37.29, T-max: 1000
# Episode: 174, Score: 173.77, Max: 195.29, Min: 37.29, T-max: 1000
# Episode: 175, Score: 184.08, Max: 195.29, Min: 37.29, T-max: 1000
# Episode: 176, Score: 177.40, Max: 195.29, Min: 37.29, T-max: 1000
# Episode: 177, Score: 193.79, Max: 195.29, Min: 37.29, T-max: 1000
# Episode: 178, Score: 178.52, Max: 195.29, Min: 37.29, T-max: 1000
# Episode: 179, Score: 185.12, Max: 195.29, Min: 37.29, T-max: 1000
# Episode: 180, Score: 187.59, Max: 195.29, Min: 37.29, T-max: 1000
# *** Episode 180 	 Average Score (over agents): 187.59 	 Average Score on 100 Episode: 128.32, Time: 00:29:57***
# Episode: 181, Score: 183.45, Max: 195.29, Min: 37.29, T-max: 1000
# Episode: 182, Score: 186.72, Max: 195.29, Min: 37.29, T-max: 1000
# Episode: 183, Score: 191.70, Max: 195.29, Min: 37.29, T-max: 1000
# Episode: 184, Score: 221.65, Max: 221.65, Min: 37.29, T-max: 1000
# Episode: 185, Score: 210.84, Max: 221.65, Min: 37.29, T-max: 1000
# Episode: 186, Score: 191.68, Max: 221.65, Min: 37.29, T-max: 1000
# Episode: 187, Score: 204.64, Max: 221.65, Min: 37.29, T-max: 1000
# Episode: 188, Score: 204.36, Max: 221.65, Min: 37.29, T-max: 1000
# Episode: 189, Score: 212.65, Max: 221.65, Min: 37.29, T-max: 1000
# Episode: 190, Score: 210.12, Max: 221.65, Min: 37.29, T-max: 1000
# *** Episode 190 	 Average Score (over agents): 210.12 	 Average Score on 100 Episode: 139.94, Time: 00:31:51***
# Episode: 191, Score: 195.30, Max: 221.65, Min: 37.29, T-max: 1000
# Episode: 192, Score: 229.09, Max: 229.09, Min: 37.29, T-max: 1000
# Episode: 193, Score: 219.55, Max: 229.09, Min: 37.29, T-max: 1000
# Episode: 194, Score: 230.91, Max: 230.91, Min: 37.29, T-max: 1000
# Episode: 195, Score: 204.42, Max: 230.91, Min: 37.29, T-max: 1000
# Episode: 196, Score: 190.18, Max: 230.91, Min: 37.29, T-max: 1000
# Episode: 197, Score: 202.02, Max: 230.91, Min: 37.29, T-max: 1000
# Episode: 198, Score: 216.23, Max: 230.91, Min: 37.29, T-max: 1000
# Episode: 199, Score: 237.19, Max: 237.19, Min: 37.29, T-max: 1000
# Episode: 200, Score: 206.73, Max: 237.19, Min: 37.29, T-max: 1000
# *** Episode 200 	 Average Score (over agents): 206.73 	 Average Score on 100 Episode: 152.42, Time: 00:33:46***
# Episode: 201, Score: 230.98, Max: 237.19, Min: 37.29, T-max: 1000
# Episode: 202, Score: 240.36, Max: 240.36, Min: 37.29, T-max: 1000
# Episode: 203, Score: 231.56, Max: 240.36, Min: 37.29, T-max: 1000
# Episode: 204, Score: 233.02, Max: 240.36, Min: 37.29, T-max: 1000
# Episode: 205, Score: 231.88, Max: 240.36, Min: 37.29, T-max: 1000
# Episode: 206, Score: 237.69, Max: 240.36, Min: 37.29, T-max: 1000
# Episode: 207, Score: 233.14, Max: 240.36, Min: 37.29, T-max: 1000
# Episode: 208, Score: 246.00, Max: 246.00, Min: 37.29, T-max: 1000
# Episode: 209, Score: 246.59, Max: 246.59, Min: 37.29, T-max: 1000
# Episode: 210, Score: 264.24, Max: 264.24, Min: 37.29, T-max: 1000
# *** Episode 210 	 Average Score (over agents): 264.24 	 Average Score on 100 Episode: 166.96, Time: 00:35:22***
# Episode: 211, Score: 257.70, Max: 264.24, Min: 37.29, T-max: 1000
# Episode: 212, Score: 260.12, Max: 264.24, Min: 37.29, T-max: 1000
# Episode: 213, Score: 227.17, Max: 264.24, Min: 37.29, T-max: 1000
# Episode: 214, Score: 255.46, Max: 264.24, Min: 37.29, T-max: 1000
# Episode: 215, Score: 254.61, Max: 264.24, Min: 37.29, T-max: 1000
# Episode: 216, Score: 244.09, Max: 264.24, Min: 37.29, T-max: 1000
# Episode: 217, Score: 264.03, Max: 264.24, Min: 37.29, T-max: 1000
# Episode: 218, Score: 263.22, Max: 264.24, Min: 37.29, T-max: 1000
# Episode: 219, Score: 257.76, Max: 264.24, Min: 37.29, T-max: 1000
# Episode: 220, Score: 241.81, Max: 264.24, Min: 37.29, T-max: 1000
# *** Episode 220 	 Average Score (over agents): 241.81 	 Average Score on 100 Episode: 181.71, Time: 00:37:04***
# Episode: 221, Score: 263.28, Max: 264.24, Min: 37.29, T-max: 1000
# Episode: 222, Score: 260.01, Max: 264.24, Min: 37.29, T-max: 1000
# Episode: 258, Score: 320.51, Max: 492.95, Min: 37.29, T-max: 1000
# Episode: 259, Score: 301.11, Max: 492.95, Min: 37.29, T-max: 1000
# Episode: 260, Score: 323.74, Max: 492.95, Min: 37.29, T-max: 1000
# *** Episode 260 	 Average Score (over agents): 323.74 	 Average Score on 100 Episode: 244.55, Time: 00:43:51***
# Episode: 261, Score: 337.65, Max: 492.95, Min: 37.29, T-max: 1000
# Episode: 262, Score: 339.46, Max: 492.95, Min: 37.29, T-max: 1000
# Episode: 263, Score: 339.45, Max: 492.95, Min: 37.29, T-max: 1000
# Episode: 264, Score: 667.11, Max: 667.11, Min: 37.29, T-max: 1999
# Episode: 265, Score: 325.50, Max: 667.11, Min: 37.29, T-max: 1000
# Episode: 266, Score: 327.28, Max: 667.11, Min: 37.29, T-max: 1000
# Episode: 267, Score: 356.51, Max: 667.11, Min: 37.29, T-max: 1000
# Episode: 268, Score: 346.44, Max: 667.11, Min: 37.29, T-max: 1000
# Episode: 269, Score: 345.93, Max: 667.11, Min: 37.29, T-max: 1000
# Episode: 270, Score: 345.36, Max: 667.11, Min: 37.29, T-max: 1000
# *** Episode 270 	 Average Score (over agents): 345.36 	 Average Score on 100 Episode: 264.45, Time: 00:45:41***
# Episode: 271, Score: 335.94, Max: 667.11, Min: 37.29, T-max: 1000
# Episode: 272, Score: 700.56, Max: 700.56, Min: 37.29, T-max: 1999
# Episode: 273, Score: 345.69, Max: 700.56, Min: 37.29, T-max: 1000
# Episode: 274, Score: 363.67, Max: 700.56, Min: 37.29, T-max: 1000
# Episode: 275, Score: 640.44, Max: 700.56, Min: 37.29, T-max: 1999
# Episode: 276, Score: 354.16, Max: 700.56, Min: 37.29, T-max: 1000
# Episode: 277, Score: 349.40, Max: 700.56, Min: 37.29, T-max: 1000
# Episode: 278, Score: 348.44, Max: 700.56, Min: 37.29, T-max: 1000
# Episode: 279, Score: 708.00, Max: 708.00, Min: 37.29, T-max: 1999
# Episode: 280, Score: 346.33, Max: 708.00, Min: 37.29, T-max: 1000
# *** Episode 280 	 Average Score (over agents): 346.33 	 Average Score on 100 Episode: 291.19, Time: 00:47:54***
# Episode: 281, Score: 329.57, Max: 708.00, Min: 37.29, T-max: 1000
# Episode: 282, Score: 357.78, Max: 708.00, Min: 37.29, T-max: 1000
# Episode: 283, Score: 712.13, Max: 712.13, Min: 37.29, T-max: 1999
# Episode: 284, Score: 368.03, Max: 712.13, Min: 37.29, T-max: 1000
# Episode: 285, Score: 375.04, Max: 712.13, Min: 37.29, T-max: 1000
# Episode: 286, Score: 719.27, Max: 719.27, Min: 37.29, T-max: 1999
# Episode: 287, Score: 753.56, Max: 753.56, Min: 37.29, T-max: 1999
# Episode: 288, Score: 348.59, Max: 753.56, Min: 37.29, T-max: 1000
# Episode: 289, Score: 407.26, Max: 753.56, Min: 37.29, T-max: 1000
# Episode: 290, Score: 390.22, Max: 753.56, Min: 37.29, T-max: 1000
# *** Episode 290 	 Average Score (over agents): 390.22 	 Average Score on 100 Episode: 318.62, Time: 00:50:04***
# Episode: 291, Score: 385.76, Max: 753.56, Min: 37.29, T-max: 1000
# Episode: 292, Score: 395.60, Max: 753.56, Min: 37.29, T-max: 1000
# Episode: 293, Score: 366.30, Max: 753.56, Min: 37.29, T-max: 1000
# Episode: 294, Score: 388.30, Max: 753.56, Min: 37.29, T-max: 1000
# Episode: 295, Score: 382.25, Max: 753.56, Min: 37.29, T-max: 1000
# Episode: 296, Score: 394.55, Max: 753.56, Min: 37.29, T-max: 1000
# Episode: 297, Score: 392.46, Max: 753.56, Min: 37.29, T-max: 1000
# Episode: 298, Score: 391.65, Max: 753.56, Min: 37.29, T-max: 1000
# Episode: 299, Score: 398.49, Max: 753.56, Min: 37.29, T-max: 1000
# Episode: 300, Score: 366.72, Max: 753.56, Min: 37.29, T-max: 1000
# *** Episode 300 	 Average Score (over agents): 366.72 	 Average Score on 100 Episode: 335.93, Time: 00:51:50***
# Episode: 301, Score: 803.06, Max: 803.06, Min: 37.29, T-max: 1999
# Episode: 302, Score: 408.68, Max: 803.06, Min: 37.29, T-max: 1000
# Episode: 303, Score: 348.51, Max: 803.06, Min: 37.29, T-max: 1000
# Episode: 304, Score: 391.64, Max: 803.06, Min: 37.29, T-max: 1000
# Episode: 305, Score: 363.04, Max: 803.06, Min: 37.29, T-max: 1000
# Episode: 306, Score: 420.98, Max: 803.06, Min: 37.29, T-max: 1000
# Episode: 307, Score: 811.09, Max: 811.09, Min: 37.29, T-max: 1999
# Episode: 308, Score: 850.79, Max: 850.79, Min: 37.29, T-max: 1999
# Episode: 309, Score: 422.14, Max: 850.79, Min: 37.29, T-max: 1000
# Episode: 310, Score: 821.61, Max: 850.79, Min: 37.29, T-max: 1999
# *** Episode 310 	 Average Score (over agents): 821.61 	 Average Score on 100 Episode: 368.39, Time: 00:54:11***
# Episode: 311, Score: 375.01, Max: 850.79, Min: 37.29, T-max: 1000
# Episode: 312, Score: 440.66, Max: 850.79, Min: 37.29, T-max: 1000
# Episode: 313, Score: 436.64, Max: 850.79, Min: 37.29, T-max: 1000
# Episode: 314, Score: 867.59, Max: 867.59, Min: 37.29, T-max: 1999
# Episode: 315, Score: 770.84, Max: 867.59, Min: 37.29, T-max: 1999
# Episode: 316, Score: 399.66, Max: 867.59, Min: 37.29, T-max: 1000
# Episode: 317, Score: 458.44, Max: 867.59, Min: 37.29, T-max: 1000
# Episode: 318, Score: 429.53, Max: 867.59, Min: 37.29, T-max: 1000
# Episode: 319, Score: 450.34, Max: 867.59, Min: 37.29, T-max: 1000
# Episode: 320, Score: 380.93, Max: 867.59, Min: 37.29, T-max: 1000
# *** Episode 320 	 Average Score (over agents): 380.93 	 Average Score on 100 Episode: 393.23, Time: 00:56:15***
# Episode: 321, Score: 327.01, Max: 867.59, Min: 37.29, T-max: 1000
# Episode: 322, Score: 327.34, Max: 867.59, Min: 37.29, T-max: 1000
# Episode: 323, Score: 462.69, Max: 867.59, Min: 37.29, T-max: 1000
# Episode: 324, Score: 847.73, Max: 867.59, Min: 37.29, T-max: 1999
# Episode: 325, Score: 331.46, Max: 867.59, Min: 37.29, T-max: 1000
# Episode: 436, Score: 999.91, Max: 1052.10, Min: 37.29, T-max: 1999
# Episode: 437, Score: 539.69, Max: 1052.10, Min: 37.29, T-max: 1000
# Episode: 438, Score: 537.07, Max: 1052.10, Min: 37.29, T-max: 1000
# Episode: 439, Score: 527.75, Max: 1052.10, Min: 37.29, T-max: 1000
# Episode: 440, Score: 541.66, Max: 1052.10, Min: 37.29, T-max: 1000
# *** Episode 440 	 Average Score (over agents): 541.66 	 Average Score on 100 Episode: 484.50, Time: 01:27:57***
# Episode: 441, Score: 539.87, Max: 1052.10, Min: 37.29, T-max: 1000
# Episode: 442, Score: 545.08, Max: 1052.10, Min: 37.29, T-max: 1000
# Episode: 443, Score: 502.62, Max: 1052.10, Min: 37.29, T-max: 1000
# Episode: 444, Score: 541.19, Max: 1052.10, Min: 37.29, T-max: 1000
# Episode: 445, Score: 1019.61, Max: 1052.10, Min: 37.29, T-max: 1999
# Episode: 446, Score: 544.77, Max: 1052.10, Min: 37.29, T-max: 1000
# Episode: 447, Score: 543.92, Max: 1052.10, Min: 37.29, T-max: 1000
# Episode: 448, Score: 547.59, Max: 1052.10, Min: 37.29, T-max: 1000
# Episode: 449, Score: 540.89, Max: 1052.10, Min: 37.29, T-max: 1000
# Episode: 450, Score: 548.19, Max: 1052.10, Min: 37.29, T-max: 1000
# *** Episode 450 	 Average Score (over agents): 548.19 	 Average Score on 100 Episode: 493.44, Time: 01:30:16***
# Episode: 451, Score: 1079.43, Max: 1079.43, Min: 37.29, T-max: 1999
# Episode: 452, Score: 1092.45, Max: 1092.45, Min: 37.29, T-max: 1999
# Episode: 453, Score: 1077.79, Max: 1092.45, Min: 37.29, T-max: 1999
# Episode: 454, Score: 1107.23, Max: 1107.23, Min: 37.29, T-max: 1999
# Episode: 455, Score: 520.57, Max: 1107.23, Min: 37.29, T-max: 1000
# Episode: 456, Score: 1098.17, Max: 1107.23, Min: 37.29, T-max: 1999
# Episode: 457, Score: 564.37, Max: 1107.23, Min: 37.29, T-max: 1000
# Episode: 458, Score: 1144.86, Max: 1144.86, Min: 37.29, T-max: 1999
# Episode: 459, Score: 1074.87, Max: 1144.86, Min: 37.29, T-max: 1999
# Episode: 460, Score: 1145.57, Max: 1145.57, Min: 37.29, T-max: 1999
# *** Episode 460 	 Average Score (over agents): 1145.57 	 Average Score on 100 Episode: 555.22, Time: 01:33:59***
# Episode: 461, Score: 1152.22, Max: 1152.22, Min: 37.29, T-max: 1999
# Episode: 462, Score: 575.63, Max: 1152.22, Min: 37.29, T-max: 1000
# Episode: 463, Score: 571.63, Max: 1152.22, Min: 37.29, T-max: 1000
# Episode: 464, Score: 580.60, Max: 1152.22, Min: 37.29, T-max: 1000
# Episode: 465, Score: 1151.87, Max: 1152.22, Min: 37.29, T-max: 1999
# Episode: 466, Score: 1095.99, Max: 1152.22, Min: 37.29, T-max: 1999
# Episode: 467, Score: 1154.78, Max: 1154.78, Min: 37.29, T-max: 1999
# Episode: 468, Score: 1152.37, Max: 1154.78, Min: 37.29, T-max: 1999
# Episode: 469, Score: 1091.33, Max: 1154.78, Min: 37.29, T-max: 1999
# Episode: 470, Score: 587.22, Max: 1154.78, Min: 37.29, T-max: 1000
# *** Episode 470 	 Average Score (over agents): 587.22 	 Average Score on 100 Episode: 609.94, Time: 01:37:28***
# Episode: 471, Score: 584.33, Max: 1154.78, Min: 37.29, T-max: 1000
# Episode: 472, Score: 1163.49, Max: 1163.49, Min: 37.29, T-max: 1999
# Episode: 473, Score: 1168.90, Max: 1168.90, Min: 37.29, T-max: 1999
# Episode: 474, Score: 1174.22, Max: 1174.22, Min: 37.29, T-max: 1999
# Episode: 475, Score: 1172.56, Max: 1174.22, Min: 37.29, T-max: 1999
# Episode: 476, Score: 588.05, Max: 1174.22, Min: 37.29, T-max: 1000
# Episode: 477, Score: 538.77, Max: 1174.22, Min: 37.29, T-max: 1000
# Episode: 478, Score: 1137.59, Max: 1174.22, Min: 37.29, T-max: 1999
# Episode: 479, Score: 589.36, Max: 1174.22, Min: 37.29, T-max: 1000
# Episode: 480, Score: 1167.51, Max: 1174.22, Min: 37.29, T-max: 1999
# *** Episode 480 	 Average Score (over agents): 1167.51 	 Average Score on 100 Episode: 662.50, Time: 01:41:06***
# Episode: 481, Score: 1120.41, Max: 1174.22, Min: 37.29, T-max: 1999
# Episode: 482, Score: 540.94, Max: 1174.22, Min: 37.29, T-max: 1000
# Episode: 483, Score: 1202.48, Max: 1202.48, Min: 37.29, T-max: 1999
# Episode: 484, Score: 1202.46, Max: 1202.48, Min: 37.29, T-max: 1999
# Episode: 485, Score: 618.74, Max: 1202.48, Min: 37.29, T-max: 1000
# Episode: 486, Score: 1154.99, Max: 1202.48, Min: 37.29, T-max: 1999
# Episode: 487, Score: 610.40, Max: 1202.48, Min: 37.29, T-max: 1000
# Episode: 488, Score: 1226.86, Max: 1226.86, Min: 37.29, T-max: 1999
# Episode: 489, Score: 610.43, Max: 1226.86, Min: 37.29, T-max: 1000
# Episode: 490, Score: 617.02, Max: 1226.86, Min: 37.29, T-max: 1000
# *** Episode 490 	 Average Score (over agents): 617.02 	 Average Score on 100 Episode: 708.66, Time: 01:44:22***
# Episode: 491, Score: 1211.78, Max: 1226.86, Min: 37.29, T-max: 1999
# Episode: 492, Score: 626.33, Max: 1226.86, Min: 37.29, T-max: 1000
# Episode: 493, Score: 626.29, Max: 1226.86, Min: 37.29, T-max: 1000
# Episode: 494, Score: 617.91, Max: 1226.86, Min: 37.29, T-max: 1000
# Episode: 495, Score: 624.46, Max: 1226.86, Min: 37.29, T-max: 1000
# Episode: 496, Score: 626.33, Max: 1226.86, Min: 37.29, T-max: 1000
# Episode: 497, Score: 626.12, Max: 1226.86, Min: 37.29, T-max: 1000
# Episode: 498, Score: 622.12, Max: 1226.86, Min: 37.29, T-max: 1000
# Episode: 499, Score: 612.57, Max: 1226.86, Min: 37.29, T-max: 1000
# Episode: 500, Score: 625.83, Max: 1226.86, Min: 37.29, T-max: 1000
# *** Episode 500 	 Average Score (over agents): 625.83 	 Average Score on 100 Episode: 733.41, Time: 01:47:29***
#
#  End of PPO!

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %%
env.close()
