# %% [markdown]
# # Continuous Control
#
# ---
#
# Congratulations for completing the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program!  In this notebook, you will learn how to control an agent in a more challenging environment, where the goal is to train a creature with four arms to walk forward.  **Note that this exercise is optional!**
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Crawler.app"`
# - **Windows** (x86): `"path/to/Crawler_Windows_x86/Crawler.exe"`
# - **Windows** (x86_64): `"path/to/Crawler_Windows_x86_64/Crawler.exe"`
# - **Linux** (x86): `"path/to/Crawler_Linux/Crawler.x86"`
# - **Linux** (x86_64): `"path/to/Crawler_Linux/Crawler.x86_64"`
# - **Linux** (x86, headless): `"path/to/Crawler_Linux_NoVis/Crawler.x86"`
# - **Linux** (x86_64, headless): `"path/to/Crawler_Linux_NoVis/Crawler.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Crawler.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Crawler.app")
# ```

# %%
env = UnityEnvironment(file_name='C:/Users/Turan/Desktop/drl project/deep-reinforcement-learning/p2_continuous-control/Crawler_Windows_x86_64/Crawler.exe')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: CrawlerBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 129
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 20
#         Vector Action descriptions: , , , , , , , , , , , , , , , , , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 12
# Size of each action: 20
# There are 12 agents. Each observes a state with length: 129
# The state for the first agent looks like: [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  2.25000000e+00
#   1.00000000e+00  0.00000000e+00  1.78813934e-07  0.00000000e+00
#   1.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093168e-01 -1.42857209e-01 -6.06078804e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339906e+00 -1.42857209e-01
#  -1.33341408e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093347e-01 -1.42857209e-01 -6.06078625e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339953e+00 -1.42857209e-01
#  -1.33341372e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -6.06093168e-01 -1.42857209e-01  6.06078804e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.33339906e+00 -1.42857209e-01
#   1.33341408e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   6.06093347e-01 -1.42857209e-01  6.06078625e-01  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  1.33339953e+00 -1.42857209e-01
#   1.33341372e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
#env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
#states = env_info.vector_observations                  # get the current state (for each agent)
#scores = np.zeros(num_agents)                          # initialize the score (for each agent)
#while True:
#    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
#    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
#    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#    next_states = env_info.vector_observations         # get next state (for each agent)
#    rewards = env_info.rewards                         # get reward (for each agent)
#    dones = env_info.local_done                        # see if episode finished
#    scores += env_info.rewards                         # update the score (for each agent)
#    states = next_states                               # roll over states to next time step
#    if np.any(dones):                                  # exit loop if episode finished
#        break
#print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
#env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
from  collections  import deque
from itertools import count
import torch
import time
#from ddpg_agent import Agent
from ppo_agent_combined import Agent
import matplotlib.pyplot as plt
# %matplotlib inline
env_info = env.reset(train_mode=True)[brain_name]
agent = Agent(state_size=state_size, action_size=action_size, random_seed=8, n_agent=num_agents, \
              fc1_units=128, fc2_units=128)

print("Smoothness used:", agent.USE_SMOOTHNESS)
print("Symmetry used:", agent.USE_SYMMETRY)
print("Magnitude used:", agent.USE_MAGNITUDE)
# Out:
# Smoothness used: True
# Symmetry used: False
# Magnitude used: True

# %%
def ppo(env, agent, n_episodes=500, print_every=10, n_agent = 12):
    """
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        print_every (int): number of episodes to print result
        n_agent (int): number of identical agents in environment
    """
    scores_deque = deque(maxlen=100)
    scores_global = []    
    scores = []
    max_t = 2000
        
    time_start = time.time()
    
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=True)[brain_name]
        states = env_info.vector_observations
        agent_scores = np.zeros(n_agent)
        t_max = 0
        for t in range(max_t):
            actions, log_probs, _, values = agent.act(states)
            # get needed information from environment
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations
            rewards = env_info.rewards
            dones = np.array([1 if t else 0 for t in env_info.local_done])
            agent.save_step([states, values.detach(), actions, log_probs.detach(), rewards, 1 - dones])
            states = next_states
            agent_scores += rewards
            t_max = t
            if all(dones) or t == max_t-1:
                agent.step(next_states)
                break
                
        score = np.mean(agent_scores)
        scores_deque.append(score)
        scores.append(score)

        print('Episode: {}, Score: {:.2f}, Max: {:.2f}, Min: {:.2f}, T-max: {}   '\
              .format(i_episode, score, np.max(scores), np.min(scores), t_max))
        
        if i_episode % print_every == 0:
            torch.save(agent.actor_critic.actor.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.actor_critic.critic.state_dict(), 'checkpoint_critic.pth')
            s = (int)(time.time() - time_start) 
            print('*** Episode {} \t Average Score (over agents): {:.2f} \t Average Score on 100 Episode: {:.2f}, Time: {:02}:{:02}:{:02}***'\
                  .format(i_episode, score, np.mean(scores_deque), s//3600, s%3600//60, s%60))
            
        if len(scores_deque) == 100 and np.mean(scores_deque) >= 800: # 650: # 500:   
            break


    print('\n End of PPO!')
    return scores

scores = ppo(env=env, agent=agent)
# Out:
# c:\Users\Turan\miniconda3\envs\drlnd\lib\site-packages\torch\nn\functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Episode: 1, Score: 47.94, Max: 47.94, Min: 47.94, T-max: 1000
# Episode: 2, Score: 49.67, Max: 49.67, Min: 47.94, T-max: 1000
# Episode: 3, Score: 43.91, Max: 49.67, Min: 43.91, T-max: 1000
# Episode: 4, Score: 48.66, Max: 49.67, Min: 43.91, T-max: 1000
# Episode: 5, Score: 37.57, Max: 49.67, Min: 37.57, T-max: 1000
# Episode: 6, Score: 46.39, Max: 49.67, Min: 37.57, T-max: 1000
# Episode: 7, Score: 51.90, Max: 51.90, Min: 37.57, T-max: 1000
# Episode: 8, Score: 49.39, Max: 51.90, Min: 37.57, T-max: 1000
# Episode: 9, Score: 49.85, Max: 51.90, Min: 37.57, T-max: 1000
# Episode: 10, Score: 49.50, Max: 51.90, Min: 37.57, T-max: 1000
# *** Episode 10 	 Average Score (over agents): 49.50 	 Average Score on 100 Episode: 47.48, Time: 00:01:41***
# Episode: 11, Score: 46.50, Max: 51.90, Min: 37.57, T-max: 1000
# Episode: 12, Score: 46.00, Max: 51.90, Min: 37.57, T-max: 1000
# Episode: 13, Score: 53.18, Max: 53.18, Min: 37.57, T-max: 1000
# Episode: 14, Score: 51.47, Max: 53.18, Min: 37.57, T-max: 1000
# Episode: 15, Score: 52.35, Max: 53.18, Min: 37.57, T-max: 1000
# Episode: 16, Score: 52.44, Max: 53.18, Min: 37.57, T-max: 1000
# Episode: 17, Score: 55.56, Max: 55.56, Min: 37.57, T-max: 1000
# Episode: 18, Score: 55.23, Max: 55.56, Min: 37.57, T-max: 1000
# Episode: 19, Score: 56.05, Max: 56.05, Min: 37.57, T-max: 1000
# Episode: 20, Score: 55.41, Max: 56.05, Min: 37.57, T-max: 1000
# *** Episode 20 	 Average Score (over agents): 55.41 	 Average Score on 100 Episode: 49.95, Time: 00:03:21***
# Episode: 21, Score: 57.30, Max: 57.30, Min: 37.57, T-max: 1000
# Episode: 22, Score: 54.89, Max: 57.30, Min: 37.57, T-max: 1000
# Episode: 23, Score: 55.10, Max: 57.30, Min: 37.57, T-max: 1000
# Episode: 24, Score: 52.51, Max: 57.30, Min: 37.57, T-max: 1000
# Episode: 25, Score: 54.89, Max: 57.30, Min: 37.57, T-max: 1000
# Episode: 26, Score: 59.47, Max: 59.47, Min: 37.57, T-max: 1000
# Episode: 27, Score: 61.32, Max: 61.32, Min: 37.57, T-max: 1000
# Episode: 28, Score: 61.01, Max: 61.32, Min: 37.57, T-max: 1000
# Episode: 29, Score: 60.72, Max: 61.32, Min: 37.57, T-max: 1000
# Episode: 30, Score: 60.77, Max: 61.32, Min: 37.57, T-max: 1000
# *** Episode 30 	 Average Score (over agents): 60.77 	 Average Score on 100 Episode: 52.56, Time: 00:05:09***
# Episode: 31, Score: 62.83, Max: 62.83, Min: 37.57, T-max: 1000
# Episode: 32, Score: 58.66, Max: 62.83, Min: 37.57, T-max: 1000
# Episode: 33, Score: 63.55, Max: 63.55, Min: 37.57, T-max: 1000
# Episode: 34, Score: 59.85, Max: 63.55, Min: 37.57, T-max: 1000
# Episode: 35, Score: 62.93, Max: 63.55, Min: 37.57, T-max: 1000
# Episode: 36, Score: 65.34, Max: 65.34, Min: 37.57, T-max: 1000
# Episode: 37, Score: 66.66, Max: 66.66, Min: 37.57, T-max: 1000
# Episode: 38, Score: 64.73, Max: 66.66, Min: 37.57, T-max: 1000
# Episode: 39, Score: 66.42, Max: 66.66, Min: 37.57, T-max: 1000
# Episode: 40, Score: 64.03, Max: 66.66, Min: 37.57, T-max: 1000
# *** Episode 40 	 Average Score (over agents): 64.03 	 Average Score on 100 Episode: 55.30, Time: 00:06:50***
# Episode: 41, Score: 63.84, Max: 66.66, Min: 37.57, T-max: 1000
# Episode: 42, Score: 63.46, Max: 66.66, Min: 37.57, T-max: 1000
# Episode: 43, Score: 67.13, Max: 67.13, Min: 37.57, T-max: 1000
# Episode: 44, Score: 64.01, Max: 67.13, Min: 37.57, T-max: 1000
# Episode: 45, Score: 66.32, Max: 67.13, Min: 37.57, T-max: 1000
# Episode: 46, Score: 69.52, Max: 69.52, Min: 37.57, T-max: 1000
# Episode: 47, Score: 70.19, Max: 70.19, Min: 37.57, T-max: 1000
# Episode: 48, Score: 64.05, Max: 70.19, Min: 37.57, T-max: 1000
# Episode: 49, Score: 68.02, Max: 70.19, Min: 37.57, T-max: 1000
# Episode: 50, Score: 68.18, Max: 70.19, Min: 37.57, T-max: 1000
# *** Episode 50 	 Average Score (over agents): 68.18 	 Average Score on 100 Episode: 57.53, Time: 00:08:28***
# Episode: 51, Score: 71.14, Max: 71.14, Min: 37.57, T-max: 1000
# Episode: 52, Score: 70.50, Max: 71.14, Min: 37.57, T-max: 1000
# Episode: 53, Score: 66.99, Max: 71.14, Min: 37.57, T-max: 1000
# Episode: 54, Score: 60.93, Max: 71.14, Min: 37.57, T-max: 1000
# Episode: 55, Score: 72.77, Max: 72.77, Min: 37.57, T-max: 1000
# Episode: 56, Score: 72.85, Max: 72.85, Min: 37.57, T-max: 1000
# Episode: 57, Score: 70.91, Max: 72.85, Min: 37.57, T-max: 1000
# Episode: 58, Score: 76.17, Max: 76.17, Min: 37.57, T-max: 1000
# Episode: 59, Score: 71.62, Max: 76.17, Min: 37.57, T-max: 1000
# Episode: 60, Score: 73.14, Max: 76.17, Min: 37.57, T-max: 1000
# *** Episode 60 	 Average Score (over agents): 73.14 	 Average Score on 100 Episode: 59.73, Time: 00:10:11***
# Episode: 61, Score: 80.99, Max: 80.99, Min: 37.57, T-max: 1000
# Episode: 62, Score: 78.19, Max: 80.99, Min: 37.57, T-max: 1000
# Episode: 63, Score: 79.85, Max: 80.99, Min: 37.57, T-max: 1000
# Episode: 64, Score: 73.19, Max: 80.99, Min: 37.57, T-max: 1000
# Episode: 65, Score: 78.15, Max: 80.99, Min: 37.57, T-max: 1000
# Episode: 66, Score: 81.00, Max: 81.00, Min: 37.57, T-max: 1000
# Episode: 67, Score: 84.53, Max: 84.53, Min: 37.57, T-max: 1000
# Episode: 68, Score: 77.50, Max: 84.53, Min: 37.57, T-max: 1000
# Episode: 69, Score: 74.32, Max: 84.53, Min: 37.57, T-max: 1000
# Episode: 70, Score: 83.71, Max: 84.53, Min: 37.57, T-max: 1000
# *** Episode 70 	 Average Score (over agents): 83.71 	 Average Score on 100 Episode: 62.50, Time: 00:11:55***
# Episode: 71, Score: 86.63, Max: 86.63, Min: 37.57, T-max: 1000
# Episode: 72, Score: 83.58, Max: 86.63, Min: 37.57, T-max: 1000
# Episode: 73, Score: 78.72, Max: 86.63, Min: 37.57, T-max: 1000
# Episode: 74, Score: 82.29, Max: 86.63, Min: 37.57, T-max: 1000
# Episode: 75, Score: 83.11, Max: 86.63, Min: 37.57, T-max: 1000
# Episode: 76, Score: 86.71, Max: 86.71, Min: 37.57, T-max: 1000
# Episode: 77, Score: 96.11, Max: 96.11, Min: 37.57, T-max: 1000
# Episode: 78, Score: 84.60, Max: 96.11, Min: 37.57, T-max: 1000
# Episode: 79, Score: 93.42, Max: 96.11, Min: 37.57, T-max: 1000
# Episode: 80, Score: 91.14, Max: 96.11, Min: 37.57, T-max: 1000
# *** Episode 80 	 Average Score (over agents): 91.14 	 Average Score on 100 Episode: 65.52, Time: 00:13:41***
# Episode: 81, Score: 87.38, Max: 96.11, Min: 37.57, T-max: 1000
# Episode: 82, Score: 98.52, Max: 98.52, Min: 37.57, T-max: 1000
# Episode: 83, Score: 94.52, Max: 98.52, Min: 37.57, T-max: 1000
# Episode: 84, Score: 97.70, Max: 98.52, Min: 37.57, T-max: 1000
# Episode: 85, Score: 96.74, Max: 98.52, Min: 37.57, T-max: 1000
# Episode: 86, Score: 90.71, Max: 98.52, Min: 37.57, T-max: 1000
# Episode: 87, Score: 94.55, Max: 98.52, Min: 37.57, T-max: 1000
# Episode: 88, Score: 91.99, Max: 98.52, Min: 37.57, T-max: 1000
# Episode: 89, Score: 96.66, Max: 98.52, Min: 37.57, T-max: 1000
# Episode: 90, Score: 106.00, Max: 106.00, Min: 37.57, T-max: 1000
# *** Episode 90 	 Average Score (over agents): 106.00 	 Average Score on 100 Episode: 68.85, Time: 00:15:26***
# Episode: 91, Score: 101.72, Max: 106.00, Min: 37.57, T-max: 1000
# Episode: 92, Score: 110.33, Max: 110.33, Min: 37.57, T-max: 1000
# Episode: 93, Score: 104.17, Max: 110.33, Min: 37.57, T-max: 1000
# Episode: 94, Score: 110.24, Max: 110.33, Min: 37.57, T-max: 1000
# Episode: 95, Score: 99.08, Max: 110.33, Min: 37.57, T-max: 1000
# Episode: 96, Score: 115.77, Max: 115.77, Min: 37.57, T-max: 1000
# Episode: 97, Score: 111.69, Max: 115.77, Min: 37.57, T-max: 1000
# Episode: 98, Score: 111.79, Max: 115.77, Min: 37.57, T-max: 1000
# Episode: 99, Score: 111.44, Max: 115.77, Min: 37.57, T-max: 1000
# Episode: 100, Score: 118.52, Max: 118.52, Min: 37.57, T-max: 1000
# *** Episode 100 	 Average Score (over agents): 118.52 	 Average Score on 100 Episode: 72.91, Time: 00:17:16***
# Episode: 101, Score: 115.65, Max: 118.52, Min: 37.57, T-max: 1000
# Episode: 102, Score: 115.70, Max: 118.52, Min: 37.57, T-max: 1000
# Episode: 103, Score: 113.54, Max: 118.52, Min: 37.57, T-max: 1000
# Episode: 104, Score: 129.66, Max: 129.66, Min: 37.57, T-max: 1000
# Episode: 105, Score: 125.54, Max: 129.66, Min: 37.57, T-max: 1000
# Episode: 106, Score: 126.37, Max: 129.66, Min: 37.57, T-max: 1000
# Episode: 107, Score: 117.33, Max: 129.66, Min: 37.57, T-max: 1000
# Episode: 108, Score: 131.63, Max: 131.63, Min: 37.57, T-max: 1000
# Episode: 109, Score: 133.38, Max: 133.38, Min: 37.57, T-max: 1000
# Episode: 110, Score: 118.39, Max: 133.38, Min: 37.57, T-max: 1000
# *** Episode 110 	 Average Score (over agents): 118.39 	 Average Score on 100 Episode: 80.43, Time: 00:19:01***
# Episode: 111, Score: 132.65, Max: 133.38, Min: 37.57, T-max: 1000
# Episode: 112, Score: 130.19, Max: 133.38, Min: 37.57, T-max: 1000
# Episode: 113, Score: 127.17, Max: 133.38, Min: 37.57, T-max: 1000
# Episode: 114, Score: 116.51, Max: 133.38, Min: 37.57, T-max: 1000
# Episode: 115, Score: 148.79, Max: 148.79, Min: 37.57, T-max: 1000
# Episode: 116, Score: 139.21, Max: 148.79, Min: 37.57, T-max: 1000
# Episode: 117, Score: 138.14, Max: 148.79, Min: 37.57, T-max: 1000
# Episode: 118, Score: 140.49, Max: 148.79, Min: 37.57, T-max: 1000
# Episode: 119, Score: 137.66, Max: 148.79, Min: 37.57, T-max: 1000
# Episode: 120, Score: 146.13, Max: 148.79, Min: 37.57, T-max: 1000
# *** Episode 120 	 Average Score (over agents): 146.13 	 Average Score on 100 Episode: 88.76, Time: 00:20:52***
# Episode: 121, Score: 148.07, Max: 148.79, Min: 37.57, T-max: 1000
# Episode: 122, Score: 153.08, Max: 153.08, Min: 37.57, T-max: 1000
# Episode: 123, Score: 142.34, Max: 153.08, Min: 37.57, T-max: 1000
# Episode: 124, Score: 155.40, Max: 155.40, Min: 37.57, T-max: 1000
# Episode: 125, Score: 148.84, Max: 155.40, Min: 37.57, T-max: 1000
# Episode: 126, Score: 164.57, Max: 164.57, Min: 37.57, T-max: 1000
# Episode: 127, Score: 165.60, Max: 165.60, Min: 37.57, T-max: 1000
# Episode: 128, Score: 152.44, Max: 165.60, Min: 37.57, T-max: 1000
# Episode: 129, Score: 167.44, Max: 167.44, Min: 37.57, T-max: 1000
# Episode: 130, Score: 160.58, Max: 167.44, Min: 37.57, T-max: 1000
# *** Episode 130 	 Average Score (over agents): 160.58 	 Average Score on 100 Episode: 98.57, Time: 00:22:37***
# Episode: 131, Score: 168.05, Max: 168.05, Min: 37.57, T-max: 1000
# Episode: 132, Score: 179.11, Max: 179.11, Min: 37.57, T-max: 1000
# Episode: 133, Score: 170.86, Max: 179.11, Min: 37.57, T-max: 1000
# Episode: 134, Score: 177.72, Max: 179.11, Min: 37.57, T-max: 1000
# Episode: 135, Score: 153.27, Max: 179.11, Min: 37.57, T-max: 1000
# Episode: 136, Score: 170.77, Max: 179.11, Min: 37.57, T-max: 1000
# Episode: 137, Score: 149.56, Max: 179.11, Min: 37.57, T-max: 1000
# Episode: 138, Score: 156.19, Max: 179.11, Min: 37.57, T-max: 1000
# Episode: 139, Score: 193.60, Max: 193.60, Min: 37.57, T-max: 1000
# Episode: 140, Score: 174.73, Max: 193.60, Min: 37.57, T-max: 1000
# *** Episode 140 	 Average Score (over agents): 174.73 	 Average Score on 100 Episode: 109.15, Time: 00:24:22***
# Episode: 141, Score: 169.61, Max: 193.60, Min: 37.57, T-max: 1000
# Episode: 142, Score: 187.16, Max: 193.60, Min: 37.57, T-max: 1000
# Episode: 143, Score: 175.34, Max: 193.60, Min: 37.57, T-max: 1000
# Episode: 144, Score: 178.73, Max: 193.60, Min: 37.57, T-max: 1000
# Episode: 145, Score: 182.42, Max: 193.60, Min: 37.57, T-max: 1000
# Episode: 146, Score: 167.68, Max: 193.60, Min: 37.57, T-max: 1000
# Episode: 147, Score: 190.10, Max: 193.60, Min: 37.57, T-max: 1000
# Episode: 148, Score: 186.26, Max: 193.60, Min: 37.57, T-max: 1000
# Episode: 149, Score: 174.20, Max: 193.60, Min: 37.57, T-max: 1000
# Episode: 150, Score: 190.94, Max: 193.60, Min: 37.57, T-max: 1000
# *** Episode 150 	 Average Score (over agents): 190.94 	 Average Score on 100 Episode: 120.53, Time: 00:26:08***
# Episode: 151, Score: 205.72, Max: 205.72, Min: 37.57, T-max: 1000
# Episode: 152, Score: 187.32, Max: 205.72, Min: 37.57, T-max: 1000
# Episode: 153, Score: 200.18, Max: 205.72, Min: 37.57, T-max: 1000
# Episode: 154, Score: 204.44, Max: 205.72, Min: 37.57, T-max: 1000
# Episode: 155, Score: 202.28, Max: 205.72, Min: 37.57, T-max: 1000
# Episode: 156, Score: 203.44, Max: 205.72, Min: 37.57, T-max: 1000
# Episode: 157, Score: 211.98, Max: 211.98, Min: 37.57, T-max: 1000
# Episode: 158, Score: 217.77, Max: 217.77, Min: 37.57, T-max: 1000
# Episode: 159, Score: 217.06, Max: 217.77, Min: 37.57, T-max: 1000
# Episode: 160, Score: 191.89, Max: 217.77, Min: 37.57, T-max: 1000
# *** Episode 160 	 Average Score (over agents): 191.89 	 Average Score on 100 Episode: 133.88, Time: 00:27:53***
# Episode: 161, Score: 201.79, Max: 217.77, Min: 37.57, T-max: 1000
# Episode: 162, Score: 215.51, Max: 217.77, Min: 37.57, T-max: 1000
# Episode: 163, Score: 209.59, Max: 217.77, Min: 37.57, T-max: 1000
# Episode: 164, Score: 216.99, Max: 217.77, Min: 37.57, T-max: 1000
# Episode: 165, Score: 216.43, Max: 217.77, Min: 37.57, T-max: 1000
# Episode: 166, Score: 214.37, Max: 217.77, Min: 37.57, T-max: 1000
# Episode: 167, Score: 235.99, Max: 235.99, Min: 37.57, T-max: 1000
# Episode: 168, Score: 212.97, Max: 235.99, Min: 37.57, T-max: 1000
# Episode: 169, Score: 242.88, Max: 242.88, Min: 37.57, T-max: 1000
# Episode: 170, Score: 234.99, Max: 242.88, Min: 37.57, T-max: 1000
# *** Episode 170 	 Average Score (over agents): 234.99 	 Average Score on 100 Episode: 147.98, Time: 00:29:38***
# Episode: 171, Score: 233.46, Max: 242.88, Min: 37.57, T-max: 1000
# Episode: 172, Score: 232.23, Max: 242.88, Min: 37.57, T-max: 1000
# Episode: 173, Score: 242.20, Max: 242.88, Min: 37.57, T-max: 1000
# Episode: 174, Score: 236.02, Max: 242.88, Min: 37.57, T-max: 1000
# Episode: 175, Score: 259.00, Max: 259.00, Min: 37.57, T-max: 1000
# Episode: 176, Score: 261.06, Max: 261.06, Min: 37.57, T-max: 1000
# Episode: 177, Score: 247.32, Max: 261.06, Min: 37.57, T-max: 1000
# Episode: 178, Score: 255.07, Max: 261.06, Min: 37.57, T-max: 1000
# Episode: 179, Score: 242.04, Max: 261.06, Min: 37.57, T-max: 1000
# Episode: 180, Score: 235.57, Max: 261.06, Min: 37.57, T-max: 1000
# *** Episode 180 	 Average Score (over agents): 235.57 	 Average Score on 100 Episode: 163.76, Time: 00:31:24***
# Episode: 181, Score: 268.82, Max: 268.82, Min: 37.57, T-max: 1000
# Episode: 182, Score: 277.69, Max: 277.69, Min: 37.57, T-max: 1000
# Episode: 183, Score: 257.23, Max: 277.69, Min: 37.57, T-max: 1000
# Episode: 184, Score: 258.00, Max: 277.69, Min: 37.57, T-max: 1000
# Episode: 185, Score: 250.10, Max: 277.69, Min: 37.57, T-max: 1000
# Episode: 186, Score: 253.86, Max: 277.69, Min: 37.57, T-max: 1000
# Episode: 187, Score: 265.53, Max: 277.69, Min: 37.57, T-max: 1000
# Episode: 188, Score: 267.67, Max: 277.69, Min: 37.57, T-max: 1000
# Episode: 189, Score: 267.75, Max: 277.69, Min: 37.57, T-max: 1000
# Episode: 190, Score: 276.20, Max: 277.69, Min: 37.57, T-max: 1000
# *** Episode 190 	 Average Score (over agents): 276.20 	 Average Score on 100 Episode: 180.64, Time: 00:33:08***
# Episode: 191, Score: 273.72, Max: 277.69, Min: 37.57, T-max: 1000
# Episode: 192, Score: 270.96, Max: 277.69, Min: 37.57, T-max: 1000
# Episode: 193, Score: 283.86, Max: 283.86, Min: 37.57, T-max: 1000
# Episode: 194, Score: 257.80, Max: 283.86, Min: 37.57, T-max: 1000
# Episode: 195, Score: 281.36, Max: 283.86, Min: 37.57, T-max: 1000
# Episode: 196, Score: 273.54, Max: 283.86, Min: 37.57, T-max: 1000
# Episode: 197, Score: 278.34, Max: 283.86, Min: 37.57, T-max: 1000
# Episode: 198, Score: 300.76, Max: 300.76, Min: 37.57, T-max: 1000
# Episode: 199, Score: 285.60, Max: 300.76, Min: 37.57, T-max: 1000
# Episode: 200, Score: 294.14, Max: 300.76, Min: 37.57, T-max: 1000
# *** Episode 200 	 Average Score (over agents): 294.14 	 Average Score on 100 Episode: 197.69, Time: 00:34:53***
# Episode: 201, Score: 277.91, Max: 300.76, Min: 37.57, T-max: 1000
# Episode: 202, Score: 287.45, Max: 300.76, Min: 37.57, T-max: 1000
# Episode: 203, Score: 304.00, Max: 304.00, Min: 37.57, T-max: 1000
# Episode: 204, Score: 313.89, Max: 313.89, Min: 37.57, T-max: 1000
# Episode: 205, Score: 316.54, Max: 316.54, Min: 37.57, T-max: 1000
# Episode: 206, Score: 315.66, Max: 316.54, Min: 37.57, T-max: 1000
# Episode: 207, Score: 325.70, Max: 325.70, Min: 37.57, T-max: 1000
# Episode: 208, Score: 320.21, Max: 325.70, Min: 37.57, T-max: 1000
# Episode: 209, Score: 339.56, Max: 339.56, Min: 37.57, T-max: 1000
# Episode: 210, Score: 313.01, Max: 339.56, Min: 37.57, T-max: 1000
# *** Episode 210 	 Average Score (over agents): 313.01 	 Average Score on 100 Episode: 216.56, Time: 00:36:21***
# Episode: 211, Score: 335.52, Max: 339.56, Min: 37.57, T-max: 1000
# Episode: 212, Score: 340.28, Max: 340.28, Min: 37.57, T-max: 1000
# Episode: 213, Score: 337.35, Max: 340.28, Min: 37.57, T-max: 1000
# Episode: 214, Score: 331.48, Max: 340.28, Min: 37.57, T-max: 1000
# Episode: 215, Score: 352.74, Max: 352.74, Min: 37.57, T-max: 1000
# Episode: 216, Score: 321.12, Max: 352.74, Min: 37.57, T-max: 1000
# Episode: 217, Score: 363.62, Max: 363.62, Min: 37.57, T-max: 1000
# Episode: 218, Score: 363.72, Max: 363.72, Min: 37.57, T-max: 1000
# Episode: 219, Score: 359.44, Max: 363.72, Min: 37.57, T-max: 1000
# Episode: 220, Score: 333.94, Max: 363.72, Min: 37.57, T-max: 1000
# *** Episode 220 	 Average Score (over agents): 333.94 	 Average Score on 100 Episode: 237.38, Time: 00:37:40***
# Episode: 221, Score: 341.86, Max: 363.72, Min: 37.57, T-max: 1000
# Episode: 222, Score: 358.55, Max: 363.72, Min: 37.57, T-max: 1000
# Episode: 223, Score: 386.19, Max: 386.19, Min: 37.57, T-max: 1000
# Episode: 224, Score: 382.03, Max: 386.19, Min: 37.57, T-max: 1000
# Episode: 225, Score: 378.84, Max: 386.19, Min: 37.57, T-max: 1000
# Episode: 226, Score: 355.44, Max: 386.19, Min: 37.57, T-max: 1000
# Episode: 227, Score: 362.81, Max: 386.19, Min: 37.57, T-max: 1000
# Episode: 228, Score: 340.44, Max: 386.19, Min: 37.57, T-max: 1000
# Episode: 229, Score: 390.85, Max: 390.85, Min: 37.57, T-max: 1000
# Episode: 230, Score: 366.53, Max: 390.85, Min: 37.57, T-max: 1000
# *** Episode 230 	 Average Score (over agents): 366.53 	 Average Score on 100 Episode: 258.43, Time: 00:39:17***
# Episode: 231, Score: 391.69, Max: 391.69, Min: 37.57, T-max: 1000
# Episode: 232, Score: 377.23, Max: 391.69, Min: 37.57, T-max: 1000
# Episode: 233, Score: 385.08, Max: 391.69, Min: 37.57, T-max: 1000
# Episode: 234, Score: 384.73, Max: 391.69, Min: 37.57, T-max: 1000
# Episode: 235, Score: 403.50, Max: 403.50, Min: 37.57, T-max: 1000
# Episode: 236, Score: 405.84, Max: 405.84, Min: 37.57, T-max: 1000
# Episode: 237, Score: 406.50, Max: 406.50, Min: 37.57, T-max: 1000
# Episode: 238, Score: 411.70, Max: 411.70, Min: 37.57, T-max: 1000
# Episode: 239, Score: 418.50, Max: 418.50, Min: 37.57, T-max: 1000
# Episode: 240, Score: 402.29, Max: 418.50, Min: 37.57, T-max: 1000
# *** Episode 240 	 Average Score (over agents): 402.29 	 Average Score on 100 Episode: 281.37, Time: 00:41:03***
# Episode: 241, Score: 407.02, Max: 418.50, Min: 37.57, T-max: 1000
# Episode: 242, Score: 426.42, Max: 426.42, Min: 37.57, T-max: 1000
# Episode: 243, Score: 430.10, Max: 430.10, Min: 37.57, T-max: 1000
# Episode: 244, Score: 432.68, Max: 432.68, Min: 37.57, T-max: 1000
# Episode: 245, Score: 441.61, Max: 441.61, Min: 37.57, T-max: 1000
# Episode: 246, Score: 437.04, Max: 441.61, Min: 37.57, T-max: 1000
# Episode: 247, Score: 441.73, Max: 441.73, Min: 37.57, T-max: 1000
# Episode: 248, Score: 418.80, Max: 441.73, Min: 37.57, T-max: 1000
# Episode: 249, Score: 438.14, Max: 441.73, Min: 37.57, T-max: 1000
# Episode: 250, Score: 457.30, Max: 457.30, Min: 37.57, T-max: 1000
# *** Episode 250 	 Average Score (over agents): 457.30 	 Average Score on 100 Episode: 306.65, Time: 00:42:47***
# Episode: 251, Score: 454.63, Max: 457.30, Min: 37.57, T-max: 1000
# Episode: 252, Score: 455.51, Max: 457.30, Min: 37.57, T-max: 1000
# Episode: 253, Score: 453.78, Max: 457.30, Min: 37.57, T-max: 1000
# Episode: 254, Score: 440.94, Max: 457.30, Min: 37.57, T-max: 1000
# Episode: 255, Score: 459.33, Max: 459.33, Min: 37.57, T-max: 1000
# Episode: 256, Score: 432.74, Max: 459.33, Min: 37.57, T-max: 1000
# Episode: 257, Score: 458.80, Max: 459.33, Min: 37.57, T-max: 1000
# Episode: 258, Score: 455.45, Max: 459.33, Min: 37.57, T-max: 1000
# Episode: 259, Score: 482.43, Max: 482.43, Min: 37.57, T-max: 1000
# Episode: 260, Score: 481.95, Max: 482.43, Min: 37.57, T-max: 1000
# *** Episode 260 	 Average Score (over agents): 481.95 	 Average Score on 100 Episode: 331.98, Time: 00:44:32***
# Episode: 261, Score: 477.29, Max: 482.43, Min: 37.57, T-max: 1000
# Episode: 262, Score: 479.46, Max: 482.43, Min: 37.57, T-max: 1000
# Episode: 263, Score: 482.34, Max: 482.43, Min: 37.57, T-max: 1000
# Episode: 264, Score: 478.09, Max: 482.43, Min: 37.57, T-max: 1000
# Episode: 265, Score: 476.81, Max: 482.43, Min: 37.57, T-max: 1000
# Episode: 266, Score: 474.36, Max: 482.43, Min: 37.57, T-max: 1000
# Episode: 267, Score: 476.53, Max: 482.43, Min: 37.57, T-max: 1000
# Episode: 268, Score: 493.34, Max: 493.34, Min: 37.57, T-max: 1000
# Episode: 269, Score: 485.59, Max: 493.34, Min: 37.57, T-max: 1000
# Episode: 270, Score: 469.48, Max: 493.34, Min: 37.57, T-max: 1000
# *** Episode 270 	 Average Score (over agents): 469.48 	 Average Score on 100 Episode: 357.90, Time: 00:46:18***
# Episode: 271, Score: 490.59, Max: 493.34, Min: 37.57, T-max: 1000
# Episode: 272, Score: 492.63, Max: 493.34, Min: 37.57, T-max: 1000
# Episode: 273, Score: 495.08, Max: 495.08, Min: 37.57, T-max: 1000
# Episode: 274, Score: 499.04, Max: 499.04, Min: 37.57, T-max: 1000
# Episode: 275, Score: 505.82, Max: 505.82, Min: 37.57, T-max: 1000
# Episode: 276, Score: 495.89, Max: 505.82, Min: 37.57, T-max: 1000
# Episode: 277, Score: 509.67, Max: 509.67, Min: 37.57, T-max: 1000
# Episode: 278, Score: 510.40, Max: 510.40, Min: 37.57, T-max: 1000
# Episode: 279, Score: 521.24, Max: 521.24, Min: 37.57, T-max: 1000
# Episode: 280, Score: 512.53, Max: 521.24, Min: 37.57, T-max: 1000
# *** Episode 280 	 Average Score (over agents): 512.53 	 Average Score on 100 Episode: 383.79, Time: 00:48:03***
# Episode: 281, Score: 520.34, Max: 521.24, Min: 37.57, T-max: 1000
# Episode: 282, Score: 504.34, Max: 521.24, Min: 37.57, T-max: 1000
# Episode: 283, Score: 509.50, Max: 521.24, Min: 37.57, T-max: 1000
# Episode: 284, Score: 484.58, Max: 521.24, Min: 37.57, T-max: 1000
# Episode: 285, Score: 512.70, Max: 521.24, Min: 37.57, T-max: 1000
# Episode: 286, Score: 527.85, Max: 527.85, Min: 37.57, T-max: 1000
# Episode: 287, Score: 531.26, Max: 531.26, Min: 37.57, T-max: 1000
# Episode: 288, Score: 528.93, Max: 531.26, Min: 37.57, T-max: 1000
# Episode: 289, Score: 537.64, Max: 537.64, Min: 37.57, T-max: 1000
# Episode: 290, Score: 1072.56, Max: 1072.56, Min: 37.57, T-max: 1999
# *** Episode 290 	 Average Score (over agents): 1072.56 	 Average Score on 100 Episode: 414.66, Time: 00:50:01***
# Episode: 291, Score: 541.41, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 292, Score: 500.84, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 293, Score: 541.01, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 294, Score: 553.03, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 295, Score: 557.43, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 296, Score: 558.17, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 297, Score: 569.25, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 298, Score: 564.43, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 299, Score: 555.34, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 300, Score: 566.64, Max: 1072.56, Min: 37.57, T-max: 1000
# *** Episode 300 	 Average Score (over agents): 566.64 	 Average Score on 100 Episode: 441.74, Time: 00:51:46***
# Episode: 301, Score: 574.17, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 302, Score: 568.33, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 303, Score: 582.72, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 304, Score: 578.38, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 305, Score: 573.18, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 306, Score: 596.10, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 307, Score: 588.64, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 308, Score: 592.54, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 309, Score: 598.15, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 310, Score: 588.14, Max: 1072.56, Min: 37.57, T-max: 1000
# *** Episode 310 	 Average Score (over agents): 588.14 	 Average Score on 100 Episode: 469.00, Time: 00:53:31***
# Episode: 311, Score: 591.33, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 312, Score: 602.98, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 313, Score: 599.16, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 314, Score: 601.57, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 315, Score: 612.38, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 316, Score: 607.06, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 317, Score: 610.59, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 318, Score: 618.43, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 319, Score: 604.99, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 320, Score: 609.26, Max: 1072.56, Min: 37.57, T-max: 1000
# *** Episode 320 	 Average Score (over agents): 609.26 	 Average Score on 100 Episode: 495.19, Time: 00:55:17***
# Episode: 321, Score: 609.70, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 322, Score: 607.13, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 323, Score: 615.83, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 324, Score: 611.98, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 325, Score: 614.89, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 326, Score: 614.73, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 327, Score: 620.00, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 328, Score: 578.36, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 329, Score: 616.36, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 330, Score: 618.22, Max: 1072.56, Min: 37.57, T-max: 1000
# *** Episode 330 	 Average Score (over agents): 618.22 	 Average Score on 100 Episode: 519.62, Time: 00:57:02***
# Episode: 331, Score: 620.66, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 332, Score: 617.36, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 333, Score: 629.49, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 334, Score: 618.08, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 335, Score: 616.95, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 336, Score: 626.23, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 337, Score: 631.12, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 338, Score: 627.25, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 339, Score: 635.60, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 340, Score: 636.62, Max: 1072.56, Min: 37.57, T-max: 1000
# *** Episode 340 	 Average Score (over agents): 636.62 	 Average Score on 100 Episode: 542.35, Time: 00:58:46***
# Episode: 341, Score: 633.95, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 342, Score: 641.94, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 343, Score: 644.56, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 344, Score: 643.76, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 345, Score: 643.06, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 346, Score: 656.49, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 347, Score: 632.28, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 348, Score: 652.90, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 349, Score: 654.74, Max: 1072.56, Min: 37.57, T-max: 1000
# Episode: 350, Score: 651.40, Max: 1072.56, Min: 37.57, T-max: 1000
# *** Episode 350 	 Average Score (over agents): 651.40 	 Average Score on 100 Episode: 563.59, Time: 01:00:31***
# Episode: 351, Score: 1295.86, Max: 1295.86, Min: 37.57, T-max: 1999
# Episode: 352, Score: 650.51, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 353, Score: 647.74, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 354, Score: 649.05, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 355, Score: 654.20, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 356, Score: 657.91, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 357, Score: 662.09, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 358, Score: 663.30, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 359, Score: 659.17, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 360, Score: 662.28, Max: 1295.86, Min: 37.57, T-max: 1000
# *** Episode 360 	 Average Score (over agents): 662.28 	 Average Score on 100 Episode: 589.85, Time: 01:02:24***
# Episode: 361, Score: 661.34, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 362, Score: 653.51, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 363, Score: 653.72, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 364, Score: 652.95, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 365, Score: 657.69, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 366, Score: 664.65, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 367, Score: 660.64, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 368, Score: 660.68, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 369, Score: 656.01, Max: 1295.86, Min: 37.57, T-max: 1000
# Episode: 370, Score: 658.49, Max: 1295.86, Min: 37.57, T-max: 1000
# *** Episode 370 	 Average Score (over agents): 658.49 	 Average Score on 100 Episode: 607.72, Time: 01:04:09***
# Episode: 371, Score: 1316.74, Max: 1316.74, Min: 37.57, T-max: 1999
# Episode: 372, Score: 659.48, Max: 1316.74, Min: 37.57, T-max: 1000
# Episode: 373, Score: 674.31, Max: 1316.74, Min: 37.57, T-max: 1000
# Episode: 374, Score: 671.70, Max: 1316.74, Min: 37.57, T-max: 1000
# Episode: 375, Score: 1348.96, Max: 1348.96, Min: 37.57, T-max: 1999
# Episode: 376, Score: 675.55, Max: 1348.96, Min: 37.57, T-max: 1000
# Episode: 377, Score: 1344.02, Max: 1348.96, Min: 37.57, T-max: 1999
# Episode: 378, Score: 678.40, Max: 1348.96, Min: 37.57, T-max: 1000
# Episode: 379, Score: 679.27, Max: 1348.96, Min: 37.57, T-max: 1000
# Episode: 380, Score: 674.45, Max: 1348.96, Min: 37.57, T-max: 1000
# *** Episode 380 	 Average Score (over agents): 674.45 	 Average Score on 100 Episode: 644.62, Time: 01:06:19***
# Episode: 381, Score: 654.52, Max: 1348.96, Min: 37.57, T-max: 1000
# Episode: 382, Score: 1353.95, Max: 1353.95, Min: 37.57, T-max: 1999
# Episode: 383, Score: 692.66, Max: 1353.95, Min: 37.57, T-max: 1000
# Episode: 384, Score: 680.85, Max: 1353.95, Min: 37.57, T-max: 1000
# Episode: 385, Score: 682.02, Max: 1353.95, Min: 37.57, T-max: 1000
# Episode: 386, Score: 683.27, Max: 1353.95, Min: 37.57, T-max: 1000
# Episode: 387, Score: 684.83, Max: 1353.95, Min: 37.57, T-max: 1000
# Episode: 388, Score: 1362.91, Max: 1362.91, Min: 37.57, T-max: 1999
# Episode: 389, Score: 679.88, Max: 1362.91, Min: 37.57, T-max: 1000
# Episode: 390, Score: 673.60, Max: 1362.91, Min: 37.57, T-max: 1000
# *** Episode 390 	 Average Score (over agents): 673.60 	 Average Score on 100 Episode: 668.80, Time: 01:07:48***
# Episode: 391, Score: 682.68, Max: 1362.91, Min: 37.57, T-max: 1000
# Episode: 392, Score: 682.34, Max: 1362.91, Min: 37.57, T-max: 1000
# Episode: 393, Score: 693.93, Max: 1362.91, Min: 37.57, T-max: 1000
# Episode: 394, Score: 685.44, Max: 1362.91, Min: 37.57, T-max: 1000
# Episode: 395, Score: 686.87, Max: 1362.91, Min: 37.57, T-max: 1000
# Episode: 396, Score: 687.88, Max: 1362.91, Min: 37.57, T-max: 1000
# Episode: 397, Score: 689.09, Max: 1362.91, Min: 37.57, T-max: 1000
# Episode: 398, Score: 694.76, Max: 1362.91, Min: 37.57, T-max: 1000
# Episode: 399, Score: 1371.30, Max: 1371.30, Min: 37.57, T-max: 1999
# Episode: 400, Score: 1380.63, Max: 1380.63, Min: 37.57, T-max: 1999
# *** Episode 400 	 Average Score (over agents): 1380.63 	 Average Score on 100 Episode: 696.28, Time: 01:09:26***
# Episode: 401, Score: 690.81, Max: 1380.63, Min: 37.57, T-max: 1000
# Episode: 402, Score: 691.92, Max: 1380.63, Min: 37.57, T-max: 1000
# Episode: 403, Score: 689.20, Max: 1380.63, Min: 37.57, T-max: 1000
# Episode: 404, Score: 691.28, Max: 1380.63, Min: 37.57, T-max: 1000
# Episode: 405, Score: 702.92, Max: 1380.63, Min: 37.57, T-max: 1000
# Episode: 406, Score: 697.99, Max: 1380.63, Min: 37.57, T-max: 1000
# Episode: 407, Score: 699.64, Max: 1380.63, Min: 37.57, T-max: 1000
# Episode: 408, Score: 708.85, Max: 1380.63, Min: 37.57, T-max: 1000
# Episode: 409, Score: 1403.34, Max: 1403.34, Min: 37.57, T-max: 1999
# Episode: 410, Score: 701.03, Max: 1403.34, Min: 37.57, T-max: 1000
# *** Episode 410 	 Average Score (over agents): 701.03 	 Average Score on 100 Episode: 714.64, Time: 01:11:12***
# Episode: 411, Score: 706.08, Max: 1403.34, Min: 37.57, T-max: 1000
# Episode: 412, Score: 698.63, Max: 1403.34, Min: 37.57, T-max: 1000
# Episode: 413, Score: 711.84, Max: 1403.34, Min: 37.57, T-max: 1000
# Episode: 414, Score: 716.81, Max: 1403.34, Min: 37.57, T-max: 1000
# Episode: 415, Score: 718.97, Max: 1403.34, Min: 37.57, T-max: 1000
# Episode: 416, Score: 1429.91, Max: 1429.91, Min: 37.57, T-max: 1999
# Episode: 417, Score: 723.17, Max: 1429.91, Min: 37.57, T-max: 1000
# Episode: 418, Score: 718.23, Max: 1429.91, Min: 37.57, T-max: 1000
# Episode: 419, Score: 711.93, Max: 1429.91, Min: 37.57, T-max: 1000
# Episode: 420, Score: 718.31, Max: 1429.91, Min: 37.57, T-max: 1000
# *** Episode 420 	 Average Score (over agents): 718.31 	 Average Score on 100 Episode: 732.61, Time: 01:13:06***
# Episode: 421, Score: 716.44, Max: 1429.91, Min: 37.57, T-max: 1000
# Episode: 422, Score: 731.51, Max: 1429.91, Min: 37.57, T-max: 1000
# Episode: 423, Score: 1434.74, Max: 1434.74, Min: 37.57, T-max: 1999
# Episode: 424, Score: 719.41, Max: 1434.74, Min: 37.57, T-max: 1000
# Episode: 425, Score: 722.52, Max: 1434.74, Min: 37.57, T-max: 1000
# Episode: 426, Score: 1433.04, Max: 1434.74, Min: 37.57, T-max: 1999
# Episode: 427, Score: 721.48, Max: 1434.74, Min: 37.57, T-max: 1000
# Episode: 428, Score: 721.87, Max: 1434.74, Min: 37.57, T-max: 1000
# Episode: 429, Score: 721.87, Max: 1434.74, Min: 37.57, T-max: 1000
# Episode: 430, Score: 1444.26, Max: 1444.26, Min: 37.57, T-max: 1999
# *** Episode 430 	 Average Score (over agents): 1444.26 	 Average Score on 100 Episode: 765.21, Time: 01:15:20***
# Episode: 431, Score: 724.50, Max: 1444.26, Min: 37.57, T-max: 1000
# Episode: 432, Score: 1408.80, Max: 1444.26, Min: 37.57, T-max: 1999
# Episode: 433, Score: 1436.40, Max: 1444.26, Min: 37.57, T-max: 1999
# Episode: 434, Score: 727.41, Max: 1444.26, Min: 37.57, T-max: 1000
# Episode: 435, Score: 1462.49, Max: 1462.49, Min: 37.57, T-max: 1999
# Episode: 436, Score: 667.47, Max: 1462.49, Min: 37.57, T-max: 1000
# Episode: 437, Score: 740.97, Max: 1462.49, Min: 37.57, T-max: 1000
# Episode: 438, Score: 741.23, Max: 1462.49, Min: 37.57, T-max: 1000
# Episode: 439, Score: 730.32, Max: 1462.49, Min: 37.57, T-max: 1000
# Episode: 440, Score: 738.74, Max: 1462.49, Min: 37.57, T-max: 1000
# *** Episode 440 	 Average Score (over agents): 738.74 	 Average Score on 100 Episode: 796.39, Time: 01:17:40***
# Episode: 441, Score: 1474.96, Max: 1474.96, Min: 37.57, T-max: 1999
#
#  End of PPO!

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %%
env.close()
